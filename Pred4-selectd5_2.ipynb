# %% [markdown]
# # Prediction with LSTM model (v4.5.2)
# <p style='text-align: right;'>with selectd5.csv</p>
#
# * history
#   * 2025/05/23 PM06:02 : 3번째 모델의 3번째 데이터를 사용
#   * 2025/05/27
#   * 2025/05/30 : v4.5.1 작성 시작
#   * 2025/06/04 : v4.5.2 last update

# %%
# !pip install scikit-learn
# !pip install tensorflow
# !pip install numpy pandas keras scikit-learn matplotlib scikeras
from datetime import datetime
print(f'restart kernel... {datetime.now()}')

# %%
def restart_kernel():
    # Restart the kernet after libraries are loaded.
    import IPython
    from datetime import datetime
    print(f'restart kernel... {datetime.now()}')
    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

restart_kernel()

import os
import sys
from datetime import datetime
cwd = os.getcwd()
sys.path.append(cwd)
print(sys.path)
# Out:
# restart kernel... 2025-06-04 13:35:20.751728
# ['/home/swhors/jupyter-workspace/LSTM/$PWD', '/home/swhors/jupyter-workspace/finance', '/home/swhors/jupyter-workspace/finance/venv/lib/python3.11/site-paches', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '', '/home/swhors/jupyter-workspace/finance/venv/lib/python3.11/site-packages', '/home/swhors/jupyter-workspace/LSTM']

# %%
# load dependacies
import os
import time
import resource
from datetime import datetime
from lib.globalvar import *
from lib.data_loader import DataLoader
from lib.small_predict import predict_small, print_predict_small
from lib.activation import ActivationOutput, RecurrentActivation
from lib.small_predict import build_and_predict, gen_multi_model, save_model, generate_metric
from lib.common_env_sets import lstm_units, dense_units, steps, metrics, dropout
from lib.common_env_sets import learning_rate, last_lstm_return_sequences
from lib.common_env_sets import loss, output_dense_activation, epochs, rand_seed


print(f"imported library. ({datetime.now()})")
# Out:
# imported library. (2025-06-04 17:11:07.414799)

# %%
##
## 모델링 환경 설정
##
window=1 # default = 1 , help = "time stamps"
data_dir='./csv/selectd5.csv'
    
mode='predict' # help = "back-test or predict")

mode2='sampling' # help = "greed or sampling")
verb='verbose' # help = "verbose or not_verb")
    
training_length=0.95 # default = 0.9)
from_pos = 0
last = [[8, 11, 14, 17, 36, 39],
        [1, 5, 18, 20, 30, 35],
        [7, 9, 24, 40, 42, 44],
        [3, 6, 7, 11, 12, 17],
        [3, 13, 28, 34, 38, 42],
        [5, 12, 24, 29, 32, 42]]
print(f"finished to set environemnt. ({datetime.now()})")
# Out:
# finished to set environemnt. (2025-06-04 17:11:57.548544)

# %%
dataset_dicts = {
    1: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=0,
                  verbose=False
                  ),
    2: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=300,
                  verbose=False
                  )
    }

print(f'completed to load data. {datetime.now()}')
# Out:
# completed to load data. 2025-06-04 17:11:59.828348

# %%
###########
## layers
## LSTM Neural 계층 선언
###########
datasets = [dataset_dicts[1], # 0
            dataset_dicts[2], # 1
           ]

lstm_args = {14: {"model":{"learning_rate": learning_rate[0],
                           "dropout": dropout[0],
                           "steps": steps[0], # last output elements count
                           "metrics": metrics[1],
                           "last_lstm_return_sequences": last_lstm_return_sequences[0],
                           "lstm_units": lstm_units[2],
                           "dense_units": dense_units[2],
                           "output_dense_activation": output_dense_activation[3],
                           "loss": loss[0],
                           "return_state": False,
                           "rand_seed": rand_seed[0] # rand_seed[0]
                           },
                 "train": {"epochs": epochs[2],
                           "is_shuffle": False,
                           "batch": 1,
                           "steps_per_epoch": 0 #100
                           },
                 "dataset": datasets[0]
                 },
             44: {"model":{"learning_rate": learning_rate[0],
                           "dropout": dropout[0],
                           "steps": steps[0], # last output elements count
                           "metrics": metrics[0],
                           "last_lstm_return_sequences": last_lstm_return_sequences[1],
                           "lstm_units": lstm_units[2],
                           "dense_units": dense_units[2],
                           "output_dense_activation": output_dense_activation[3],
                           "loss": loss[0],
                           "return_state": False,
                           "rand_seed": rand_seed[0] # rand_seed[0]
                           },
                 "train": {"epochs": epochs[3],
                           "is_shuffle": False,
                           "batch": 1,
                           "steps_per_epoch": 0 #100
                           },
                 "dataset": datasets[0]
                 },
             }


print(f'completed to set env for all models. {datetime.now()}')
# Out:
# completed to set env for all models. 2025-06-04 17:12:02.683994

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_1_5',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_1_6',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 1~12
# CPU 시간: 2200.087816 초
# 메모리 사용량: 3522592 KB
# generate_metric.02 args["version"]=1
# ********************
# working model_version = 1  2025-06-04 11:46:02.176899
# ********************
# start to train all models. 2025-06-04 11:46:02.176932
# 14's training. status=start 2025-06-04 11:46:02.176948
# 14's training. status=end 2025-06-04 11:46:52.199016
# 44's training. status=start 2025-06-04 11:46:52.199117
# 44's training. status=end 2025-06-04 11:48:22.071883
# completed to train all models. 2025-06-04 11:48:22.071984
# train to create model(1). 2025-06-04 11:48:25.072070
# CPU 시간: 2367.273756 초
# 메모리 사용량: 3598336 KB
# generate_metric.02 args["version"]=2
# ********************
# working model_version = 2  2025-06-04 11:48:54.057855
# ********************
# start to train all models. 2025-06-04 11:48:54.057893
# 14's training. status=start 2025-06-04 11:48:54.057909
# 14's training. status=end 2025-06-04 11:49:45.087441
# 44's training. status=start 2025-06-04 11:49:45.087537
# 44's training. status=end 2025-06-04 11:51:16.129006
# completed to train all models. 2025-06-04 11:51:16.129104
# train to create model(2). 2025-06-04 11:51:19.129191
# CPU 시간: 2535.779658 초
# 메모리 사용량: 3919552 KB
# generate_metric.02 args["version"]=3
# ********************
# working model_version = 3  2025-06-04 11:51:47.029417
# ********************
# start to train all models. 2025-06-04 11:51:47.029453
# 14's training. status=start 2025-06-04 11:51:47.029469
# 14's training. status=end 2025-06-04 11:52:35.823801
# 44's training. status=start 2025-06-04 11:52:35.823899
# 44's training. status=end 2025-06-04 11:54:11.354819
# completed to train all models. 2025-06-04 11:54:11.354917
# train to create model(3). 2025-06-04 11:54:14.354996
# CPU 시간: 2707.558525 초
# 메모리 사용량: 4078288 KB
# generate_metric.02 args["version"]=4
# ********************
# working model_version = 4  2025-06-04 11:54:44.586496
# ********************
# start to train all models. 2025-06-04 11:54:44.586532
# 14's training. status=start 2025-06-04 11:54:44.586548
# 14's training. status=end 2025-06-04 11:55:36.054244
# 44's training. status=start 2025-06-04 11:55:36.054522
# 44's training. status=end 2025-06-04 11:57:09.849318
# completed to train all models. 2025-06-04 11:57:09.849416
# train to create model(4). 2025-06-04 11:57:12.849505
# CPU 시간: 2875.605196 초
# 메모리 사용량: 4289888 KB
# generate_metric.02 args["version"]=5
# ********************
# working model_version = 5  2025-06-04 11:57:41.589886
# ********************
# start to train all models. 2025-06-04 11:57:41.589921
# 14's training. status=start 2025-06-04 11:57:41.589938
# 14's training. status=end 2025-06-04 11:58:32.855602
# 44's training. status=start 2025-06-04 11:58:32.855700
# 44's training. status=end 2025-06-04 12:00:03.335730
# completed to train all models. 2025-06-04 12:00:03.335832
# train to create model(5). 2025-06-04 12:00:06.335909
# CPU 시간: 3043.637528 초
# 메모리 사용량: 4622352 KB
# generate_metric.02 args["version"]=6
# ********************
# working model_version = 6  2025-06-04 12:00:34.444664
# ********************
# start to train all models. 2025-06-04 12:00:34.444700
# 14's training. status=start 2025-06-04 12:00:34.444715
# 14's training. status=end 2025-06-04 12:01:23.557707
# 44's training. status=start 2025-06-04 12:01:23.557808
# 44's training. status=end 2025-06-04 12:02:58.327564
# completed to train all models. 2025-06-04 12:02:58.327663
# train to create model(6). 2025-06-04 12:03:01.327743
# CPU 시간: 3217.630062 초
# 메모리 사용량: 4913008 KB
# generate_metric.02 args["version"]=7
# ********************
# working model_version = 7  2025-06-04 12:03:36.465250
# ********************
# start to train all models. 2025-06-04 12:03:36.465287
# 14's training. status=start 2025-06-04 12:03:36.465303
# 14's training. status=end 2025-06-04 12:04:27.118420
# 44's training. status=start 2025-06-04 12:04:27.118849
# 44's training. status=end 2025-06-04 12:05:56.972216
# completed to train all models. 2025-06-04 12:05:56.972321
# train to create model(7). 2025-06-04 12:05:59.972401
# CPU 시간: 3386.772512 초
# 메모리 사용량: 4913008 KB
# generate_metric.02 args["version"]=8
# ********************
# working model_version = 8  2025-06-04 12:06:28.518088
# ********************
# start to train all models. 2025-06-04 12:06:28.518125
# 14's training. status=start 2025-06-04 12:06:28.518141
# 14's training. status=end 2025-06-04 12:07:17.525679
# 44's training. status=start 2025-06-04 12:07:17.525793
# 44's training. status=end 2025-06-04 12:08:50.417916
# completed to train all models. 2025-06-04 12:08:50.418015
# train to create model(8). 2025-06-04 12:08:53.418102
# CPU 시간: 3556.247301 초
# 메모리 사용량: 5160736 KB
# generate_metric.02 args["version"]=9
# ********************
# working model_version = 9  2025-06-04 12:09:21.953004
# ********************
# start to train all models. 2025-06-04 12:09:21.953043
# 14's training. status=start 2025-06-04 12:09:21.953059
# 14's training. status=end 2025-06-04 12:10:13.138424
# 44's training. status=start 2025-06-04 12:10:13.138525
# 44's training. status=end 2025-06-04 12:11:43.014699
# completed to train all models. 2025-06-04 12:11:43.014794
# train to create model(9). 2025-06-04 12:11:46.014877
# CPU 시간: 3724.713691 초
# 메모리 사용량: 5451584 KB
# generate_metric.02 args["version"]=10
# ********************
# working model_version = 10  2025-06-04 12:12:14.122361
# ********************
# start to train all models. 2025-06-04 12:12:14.122396
# 14's training. status=start 2025-06-04 12:12:14.122412
# 14's training. status=end 2025-06-04 12:13:05.872476
# 44's training. status=start 2025-06-04 12:13:05.872572
# 44's training. status=end 2025-06-04 12:14:45.143059
# completed to train all models. 2025-06-04 12:14:45.143155
# train to create model(10). 2025-06-04 12:14:48.143251
# CPU 시간: 3902.696767 초
# 메모리 사용량: 5573984 KB
# generate_metric.02 args["version"]=11
# ********************
# working model_version = 11  2025-06-04 12:15:16.454286
# ********************
# start to train all models. 2025-06-04 12:15:16.454313
# 14's training. status=start 2025-06-04 12:15:16.454324
# 14's training. status=end 2025-06-04 12:16:08.101614
# 44's training. status=start 2025-06-04 12:16:08.101904
# 44's training. status=end 2025-06-04 12:17:40.840101
# completed to train all models. 2025-06-04 12:17:40.840204
# train to create model(11). 2025-06-04 12:17:43.840286
# CPU 시간: 4071.243522 초
# 메모리 사용량: 5573984 KB
# generate_metric.02 args["version"]=12
# ********************
# working model_version = 12  2025-06-04 12:18:11.954116
# ********************
# start to train all models. 2025-06-04 12:18:11.954151
# 14's training. status=start 2025-06-04 12:18:11.954167
# 14's training. status=end 2025-06-04 12:19:00.953063
# 44's training. status=start 2025-06-04 12:19:00.954296
# 44's training. status=end 2025-06-04 12:20:33.915097
# completed to train all models. 2025-06-04 12:20:33.916782
# train to create model(12). 2025-06-04 12:20:36.916865
# CPU 시간: 4240.505116 초
# 메모리 사용량: 5715232 KB

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_1_7',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 1~12
# CPU 시간: 4.837977 초
# 메모리 사용량: 618384 KB
# generate_metric.02 args["version"]=1
# ********************
# working model_version = 1  2025-06-04 12:51:54.015578
# ********************
# start to train all models. 2025-06-04 12:51:54.015598
# 14's training. status=start 2025-06-04 12:51:54.015609
# 14's training. status=end 2025-06-04 12:52:41.910738
# 44's training. status=start 2025-06-04 12:52:41.910839
# 44's training. status=end 2025-06-04 12:54:10.902881
# completed to train all models. 2025-06-04 12:54:10.902979
# train to create model(1). 2025-06-04 12:54:13.903064
# CPU 시간: 169.825622 초
# 메모리 사용량: 1035776 KB
# generate_metric.02 args["version"]=2
# ********************
# working model_version = 2  2025-06-04 12:54:42.054545
# ********************
# start to train all models. 2025-06-04 12:54:42.054580
# 14's training. status=start 2025-06-04 12:54:42.054596
# 14's training. status=end 2025-06-04 12:55:31.500487
# 44's training. status=start 2025-06-04 12:55:31.500587
# 44's training. status=end 2025-06-04 12:57:03.328576
# completed to train all models. 2025-06-04 12:57:03.328675
# train to create model(2). 2025-06-04 12:57:06.328760
# CPU 시간: 337.019077 초
# 메모리 사용량: 1221504 KB
# generate_metric.02 args["version"]=3
# ********************
# working model_version = 3  2025-06-04 12:57:34.100741
# ********************
# start to train all models. 2025-06-04 12:57:34.100778
# 14's training. status=start 2025-06-04 12:57:34.100795
# 14's training. status=end 2025-06-04 12:58:24.281866
# 44's training. status=start 2025-06-04 12:58:24.281969
# 44's training. status=end 2025-06-04 12:59:55.423518
# completed to train all models. 2025-06-04 12:59:55.423810
# train to create model(3). 2025-06-04 12:59:58.423897
# CPU 시간: 504.461011 초
# 메모리 사용량: 1409024 KB
# generate_metric.02 args["version"]=4
# ********************
# working model_version = 4  2025-06-04 13:00:28.131567
# ********************
# start to train all models. 2025-06-04 13:00:28.131601
# 14's training. status=start 2025-06-04 13:00:28.131617
# 14's training. status=end 2025-06-04 13:01:17.664762
# 44's training. status=start 2025-06-04 13:01:17.664860
# 44's training. status=end 2025-06-04 13:02:47.786935
# completed to train all models. 2025-06-04 13:02:47.787034
# train to create model(4). 2025-06-04 13:02:50.787124
# CPU 시간: 670.84047 초
# 메모리 사용량: 1595312 KB
# generate_metric.02 args["version"]=5
# ********************
# working model_version = 5  2025-06-04 13:03:18.451318
# ********************
# start to train all models. 2025-06-04 13:03:18.451352
# 14's training. status=start 2025-06-04 13:03:18.451368
# 14's training. status=end 2025-06-04 13:04:08.939525
# 44's training. status=start 2025-06-04 13:04:08.939624
# 44's training. status=end 2025-06-04 13:05:41.176158
# completed to train all models. 2025-06-04 13:05:41.176259
# train to create model(5). 2025-06-04 13:05:44.176343
# CPU 시간: 838.544044 초
# 메모리 사용량: 1779904 KB
# generate_metric.02 args["version"]=6
# ********************
# working model_version = 6  2025-06-04 13:06:12.636385
# ********************
# start to train all models. 2025-06-04 13:06:12.636419
# 14's training. status=start 2025-06-04 13:06:12.636435
# 14's training. status=end 2025-06-04 13:07:03.596193
# 44's training. status=start 2025-06-04 13:07:03.596486
# 44's training. status=end 2025-06-04 13:08:36.653955
# completed to train all models. 2025-06-04 13:08:36.654053
# train to create model(6). 2025-06-04 13:08:39.654141
# CPU 시간: 1007.811668 초
# 메모리 사용량: 1967600 KB
# generate_metric.02 args["version"]=7
# ********************
# working model_version = 7  2025-06-04 13:09:08.857773
# ********************
# start to train all models. 2025-06-04 13:09:08.857808
# 14's training. status=start 2025-06-04 13:09:08.857825
# 14's training. status=end 2025-06-04 13:09:58.286924
# 44's training. status=start 2025-06-04 13:09:58.287021
# 44's training. status=end 2025-06-04 13:11:30.909755
# completed to train all models. 2025-06-04 13:11:30.909855
# train to create model(7). 2025-06-04 13:11:33.909938
# CPU 시간: 1177.278659 초
# 메모리 사용량: 2281200 KB
# generate_metric.02 args["version"]=8
# ********************
# working model_version = 8  2025-06-04 13:12:04.332364
# ********************
# start to train all models. 2025-06-04 13:12:04.332398
# 14's training. status=start 2025-06-04 13:12:04.332414
# 14's training. status=end 2025-06-04 13:12:53.106166
# 44's training. status=start 2025-06-04 13:12:53.106261
# 44's training. status=end 2025-06-04 13:14:26.032336
# completed to train all models. 2025-06-04 13:14:26.032443
# train to create model(8). 2025-06-04 13:14:29.032528
# CPU 시간: 1345.430216 초
# 메모리 사용량: 2485280 KB
# generate_metric.02 args["version"]=9
# ********************
# working model_version = 9  2025-06-04 13:14:56.998964
# ********************
# start to train all models. 2025-06-04 13:14:56.998998
# 14's training. status=start 2025-06-04 13:14:56.999014
# 14's training. status=end 2025-06-04 13:15:47.836673
# 44's training. status=start 2025-06-04 13:15:47.836768
# 44's training. status=end 2025-06-04 13:17:20.669482
# completed to train all models. 2025-06-04 13:17:20.669582
# train to create model(9). 2025-06-04 13:17:23.669662
# CPU 시간: 1515.420767 초
# 메모리 사용량: 2644992 KB
# generate_metric.02 args["version"]=10
# ********************
# working model_version = 10  2025-06-04 13:17:51.717876
# ********************
# start to train all models. 2025-06-04 13:17:51.717909
# 14's training. status=start 2025-06-04 13:17:51.717925
# 14's training. status=end 2025-06-04 13:18:43.723837
# 44's training. status=start 2025-06-04 13:18:43.723941
# 44's training. status=end 2025-06-04 13:20:16.263176
# completed to train all models. 2025-06-04 13:20:16.263278
# train to create model(10). 2025-06-04 13:20:19.263358
# CPU 시간: 1683.244911 초
# 메모리 사용량: 2857184 KB
# generate_metric.02 args["version"]=11
# ********************
# working model_version = 11  2025-06-04 13:20:47.875501
# ********************
# start to train all models. 2025-06-04 13:20:47.875532
# 14's training. status=start 2025-06-04 13:20:47.875547
# 14's training. status=end 2025-06-04 13:21:39.563306
# 44's training. status=start 2025-06-04 13:21:39.563407
# 44's training. status=end 2025-06-04 13:23:09.005780
# completed to train all models. 2025-06-04 13:23:09.005875
# train to create model(11). 2025-06-04 13:23:12.005961
# CPU 시간: 1853.90351 초
# 메모리 사용량: 2899328 KB
# generate_metric.02 args["version"]=12
# ********************
# working model_version = 12  2025-06-04 13:23:39.797556
# ********************
# start to train all models. 2025-06-04 13:23:39.797590
# 14's training. status=start 2025-06-04 13:23:39.797606
# 14's training. status=end 2025-06-04 13:24:29.967832
# 44's training. status=start 2025-06-04 13:24:29.967931
# 44's training. status=end 2025-06-04 13:26:01.709324
# completed to train all models. 2025-06-04 13:26:01.709423
# train to create model(12). 2025-06-04 13:26:04.709499
# CPU 시간: 2022.241561 초
# 메모리 사용량: 3226896 KB

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_1_8',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 1~12
# CPU 시간: 283.362079 초
# 메모리 사용량: 1197120 KB
# generate_metric.02 args["version"]=1
# ********************
# working model_version = 1  2025-06-04 13:41:16.049749
# ********************
# start to train all models. 2025-06-04 13:41:16.049782
# 14's training. status=start 2025-06-04 13:41:16.049798
# 14's training. status=end 2025-06-04 13:42:04.231960
# 44's training. status=start 2025-06-04 13:42:04.232059
# 44's training. status=end 2025-06-04 13:43:37.213625
# completed to train all models. 2025-06-04 13:43:37.213728
# train to create model(1). 2025-06-04 13:43:40.213808
# CPU 시간: 450.774086 초
# 메모리 사용량: 1532800 KB
# generate_metric.02 args["version"]=2
# ********************
# working model_version = 2  2025-06-04 13:44:09.012384
# ********************
# start to train all models. 2025-06-04 13:44:09.012421
# 14's training. status=start 2025-06-04 13:44:09.012438
# 14's training. status=end 2025-06-04 13:44:57.416854
# 44's training. status=start 2025-06-04 13:44:57.416954
# 44's training. status=end 2025-06-04 13:46:27.488714
# completed to train all models. 2025-06-04 13:46:27.488810
# train to create model(2). 2025-06-04 13:46:30.488896
# CPU 시간: 618.552507 초
# 메모리 사용량: 1719024 KB
# generate_metric.02 args["version"]=3
# ********************
# working model_version = 3  2025-06-04 13:46:58.067274
# ********************
# start to train all models. 2025-06-04 13:46:58.067309
# 14's training. status=start 2025-06-04 13:46:58.067325
# 14's training. status=end 2025-06-04 13:47:51.901228
# 44's training. status=start 2025-06-04 13:47:51.901320
# 44's training. status=end 2025-06-04 13:49:24.781096
# completed to train all models. 2025-06-04 13:49:24.781194
# train to create model(3). 2025-06-04 13:49:27.781273
# CPU 시간: 787.007481 초
# 메모리 사용량: 1905056 KB
# generate_metric.02 args["version"]=4
# ********************
# working model_version = 4  2025-06-04 13:49:55.360760
# ********************
# start to train all models. 2025-06-04 13:49:55.360798
# 14's training. status=start 2025-06-04 13:49:55.360814
# 14's training. status=end 2025-06-04 13:50:46.419728
# 44's training. status=start 2025-06-04 13:50:46.419827
# 44's training. status=end 2025-06-04 13:52:17.642309
# completed to train all models. 2025-06-04 13:52:17.642402
# train to create model(4). 2025-06-04 13:52:20.642484
# CPU 시간: 956.315688 초
# 메모리 사용량: 2212560 KB
# generate_metric.02 args["version"]=5
# ********************
# working model_version = 5  2025-06-04 13:52:51.154702
# ********************
# start to train all models. 2025-06-04 13:52:51.154738
# 14's training. status=start 2025-06-04 13:52:51.154754
# 14's training. status=end 2025-06-04 13:53:40.928049
# 44's training. status=start 2025-06-04 13:53:40.928149
# 44's training. status=end 2025-06-04 13:55:10.642737
# completed to train all models. 2025-06-04 13:55:10.642834
# train to create model(5). 2025-06-04 13:55:13.642916
# CPU 시간: 1123.016477 초
# 메모리 사용량: 2421216 KB
# generate_metric.02 args["version"]=6
# ********************
# working model_version = 6  2025-06-04 13:55:41.906457
# ********************
# start to train all models. 2025-06-04 13:55:41.906493
# 14's training. status=start 2025-06-04 13:55:41.906509
# 14's training. status=end 2025-06-04 13:56:31.707560
# 44's training. status=start 2025-06-04 13:56:31.707661
# 44's training. status=end 2025-06-04 13:58:03.617787
# completed to train all models. 2025-06-04 13:58:03.617887
# train to create model(6). 2025-06-04 13:58:06.617966
# CPU 시간: 1293.213902 초
# 메모리 사용량: 2581952 KB
# generate_metric.02 args["version"]=7
# ********************
# working model_version = 7  2025-06-04 13:58:34.679991
# ********************
# start to train all models. 2025-06-04 13:58:34.680026
# 14's training. status=start 2025-06-04 13:58:34.680042
# 14's training. status=end 2025-06-04 13:59:23.572917
# 44's training. status=start 2025-06-04 13:59:23.573013
# 44's training. status=end 2025-06-04 14:00:58.355443
# completed to train all models. 2025-06-04 14:00:58.355540
# train to create model(7). 2025-06-04 14:01:01.355625
# CPU 시간: 1461.398994 초
# 메모리 사용량: 2796432 KB
# generate_metric.02 args["version"]=8
# ********************
# working model_version = 8  2025-06-04 14:01:29.584274
# ********************
# start to train all models. 2025-06-04 14:01:29.584311
# 14's training. status=start 2025-06-04 14:01:29.584326
# 14's training. status=end 2025-06-04 14:02:21.177041
# 44's training. status=start 2025-06-04 14:02:21.177139
# 44's training. status=end 2025-06-04 14:03:51.411664
# completed to train all models. 2025-06-04 14:03:51.411761
# train to create model(8). 2025-06-04 14:03:54.411847
# CPU 시간: 1631.455669 초
# 메모리 사용량: 2836656 KB
# generate_metric.02 args["version"]=9
# ********************
# working model_version = 9  2025-06-04 14:04:22.695938
# ********************
# start to train all models. 2025-06-04 14:04:22.695974
# 14's training. status=start 2025-06-04 14:04:22.695990
# 14's training. status=end 2025-06-04 14:05:12.372188
# 44's training. status=start 2025-06-04 14:05:12.372286
# 44's training. status=end 2025-06-04 14:06:42.915079
# completed to train all models. 2025-06-04 14:06:42.915189
# train to create model(9). 2025-06-04 14:06:45.915275
# CPU 시간: 1798.720092 초
# 메모리 사용량: 3167104 KB
# generate_metric.02 args["version"]=10
# ********************
# working model_version = 10  2025-06-04 14:07:13.932142
# ********************
# start to train all models. 2025-06-04 14:07:13.932174
# 14's training. status=start 2025-06-04 14:07:13.932189
# 14's training. status=end 2025-06-04 14:08:08.093929
# 44's training. status=start 2025-06-04 14:08:08.094034
# 44's training. status=end 2025-06-04 14:09:41.415285
# completed to train all models. 2025-06-04 14:09:41.415395
# train to create model(10). 2025-06-04 14:09:44.415483
# CPU 시간: 1969.636868 초
# 메모리 사용량: 3209424 KB
# generate_metric.02 args["version"]=11
# ********************
# working model_version = 11  2025-06-04 14:10:12.183506
# ********************
# start to train all models. 2025-06-04 14:10:12.183540
# 14's training. status=start 2025-06-04 14:10:12.183556
# 14's training. status=end 2025-06-04 14:11:02.141656
# 44's training. status=start 2025-06-04 14:11:02.141753
# 44's training. status=end 2025-06-04 14:12:32.121806
# completed to train all models. 2025-06-04 14:12:32.121910
# train to create model(11). 2025-06-04 14:12:35.121987
# CPU 시간: 2137.235455 초
# 메모리 사용량: 3543408 KB
# generate_metric.02 args["version"]=12
# ********************
# working model_version = 12  2025-06-04 14:13:03.525270
# ********************
# start to train all models. 2025-06-04 14:13:03.525305
# 14's training. status=start 2025-06-04 14:13:03.525320
# 14's training. status=end 2025-06-04 14:13:57.133190
# 44's training. status=start 2025-06-04 14:13:57.133536
# 44's training. status=end 2025-06-04 14:15:28.962034
# completed to train all models. 2025-06-04 14:15:28.962136
# train to create model(12). 2025-06-04 14:15:31.962216
# CPU 시간: 2310.222372 초
# 메모리 사용량: 3703744 KB

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_1_9',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 1~12
# CPU 시간: 2313.326615 초
# 메모리 사용량: 3703744 KB
# generate_metric.02 args["version"]=1
# ********************
# working model_version = 1  2025-06-04 14:16:02.812993
# ********************
# start to train all models. 2025-06-04 14:16:02.813018
# 14's training. status=start 2025-06-04 14:16:02.813027
# 14's training. status=end 2025-06-04 14:16:54.228937
# 44's training. status=start 2025-06-04 14:16:54.229035
# 44's training. status=end 2025-06-04 14:18:26.152364
# completed to train all models. 2025-06-04 14:18:26.152472
# train to create model(1). 2025-06-04 14:18:29.152560
# CPU 시간: 2482.217556 초
# 메모리 사용량: 3774304 KB
# generate_metric.02 args["version"]=2
# ********************
# working model_version = 2  2025-06-04 14:18:57.394679
# ********************
# start to train all models. 2025-06-04 14:18:57.394715
# 14's training. status=start 2025-06-04 14:18:57.394732
# 14's training. status=end 2025-06-04 14:19:47.268098
# 44's training. status=start 2025-06-04 14:19:47.268197
# 44's training. status=end 2025-06-04 14:21:19.243777
# completed to train all models. 2025-06-04 14:21:19.243884
# train to create model(2). 2025-06-04 14:21:22.243968
# CPU 시간: 2650.485528 초
# 메모리 사용량: 4103568 KB
# generate_metric.02 args["version"]=3
# ********************
# working model_version = 3  2025-06-04 14:21:50.848795
# ********************
# start to train all models. 2025-06-04 14:21:50.848832
# 14's training. status=start 2025-06-04 14:21:50.848849
# 14's training. status=end 2025-06-04 14:22:41.104106
# 44's training. status=start 2025-06-04 14:22:41.104211
# 44's training. status=end 2025-06-04 14:24:18.322068
# completed to train all models. 2025-06-04 14:24:18.322166
# train to create model(3). 2025-06-04 14:24:21.322251
# CPU 시간: 2824.825079 초
# 메모리 사용량: 4283968 KB
# generate_metric.02 args["version"]=4
# ********************
# working model_version = 4  2025-06-04 14:24:49.625487
# ********************
# start to train all models. 2025-06-04 14:24:49.625523
# 14's training. status=start 2025-06-04 14:24:49.625539
# 14's training. status=end 2025-06-04 14:25:38.440020
# 44's training. status=start 2025-06-04 14:25:38.440121
# 44's training. status=end 2025-06-04 14:27:11.051111
# completed to train all models. 2025-06-04 14:27:11.051214
# train to create model(4). 2025-06-04 14:27:14.051291
# CPU 시간: 2992.776223 초
# 메모리 사용량: 4475568 KB
# generate_metric.02 args["version"]=5
# ********************
# working model_version = 5  2025-06-04 14:27:43.052358
# ********************
# start to train all models. 2025-06-04 14:27:43.052394
# 14's training. status=start 2025-06-04 14:27:43.052410
# 14's training. status=end 2025-06-04 14:28:34.133694
# 44's training. status=start 2025-06-04 14:28:34.133981
# 44's training. status=end 2025-06-04 14:30:06.163378
# completed to train all models. 2025-06-04 14:30:06.163480
# train to create model(5). 2025-06-04 14:30:09.163561
# CPU 시간: 3160.178843 초
# 메모리 사용량: 4806672 KB
# generate_metric.02 args["version"]=6
# ********************
# working model_version = 6  2025-06-04 14:30:38.156860
# ********************
# start to train all models. 2025-06-04 14:30:38.156896
# 14's training. status=start 2025-06-04 14:30:38.156911
# 14's training. status=end 2025-06-04 14:31:29.521513
# 44's training. status=start 2025-06-04 14:31:29.521612
# 44's training. status=end 2025-06-04 14:33:00.834643
# completed to train all models. 2025-06-04 14:33:00.834743
# train to create model(6). 2025-06-04 14:33:03.834826
# CPU 시간: 3328.041865 초
# 메모리 사용량: 5145824 KB
# generate_metric.02 args["version"]=7
# ********************
# working model_version = 7  2025-06-04 14:33:31.873484
# ********************
# start to train all models. 2025-06-04 14:33:31.873521
# 14's training. status=start 2025-06-04 14:33:31.873537
# 14's training. status=end 2025-06-04 14:34:27.795151
# 44's training. status=start 2025-06-04 14:34:27.795255
# 44's training. status=end 2025-06-04 14:35:58.014564
# completed to train all models. 2025-06-04 14:35:58.014664
# train to create model(7). 2025-06-04 14:36:01.014747
# CPU 시간: 3502.958447 초
# 메모리 사용량: 5145824 KB
# generate_metric.02 args["version"]=8
# ********************
# working model_version = 8  2025-06-04 14:36:28.857430
# ********************
# start to train all models. 2025-06-04 14:36:28.857481
# 14's training. status=start 2025-06-04 14:36:28.857499
# 14's training. status=end 2025-06-04 14:37:19.009985
# 44's training. status=start 2025-06-04 14:37:19.010085
# 44's training. status=end 2025-06-04 14:38:49.915087
# completed to train all models. 2025-06-04 14:38:49.915190
# train to create model(8). 2025-06-04 14:38:52.915274
# CPU 시간: 3671.379543 초
# 메모리 사용량: 5223344 KB
# generate_metric.02 args["version"]=9
# ********************
# working model_version = 9  2025-06-04 14:39:20.847080
# ********************
# start to train all models. 2025-06-04 14:39:20.847116
# 14's training. status=start 2025-06-04 14:39:20.847135
# 14's training. status=end 2025-06-04 14:40:10.980284
# 44's training. status=start 2025-06-04 14:40:10.980383
# 44's training. status=end 2025-06-04 14:41:44.068246
# completed to train all models. 2025-06-04 14:41:44.068345
# train to create model(9). 2025-06-04 14:41:47.068421
# CPU 시간: 3840.08206 초
# 메모리 사용량: 5543072 KB
# generate_metric.02 args["version"]=10
# ********************
# working model_version = 10  2025-06-04 14:42:15.090075
# ********************
# start to train all models. 2025-06-04 14:42:15.090111
# 14's training. status=start 2025-06-04 14:42:15.090126
# 14's training. status=end 2025-06-04 14:43:04.259534
# 44's training. status=start 2025-06-04 14:43:04.259632
# 44's training. status=end 2025-06-04 14:44:46.088791
# completed to train all models. 2025-06-04 14:44:46.088891
# train to create model(10). 2025-06-04 14:44:49.088970
# CPU 시간: 4019.529098 초
# 메모리 사용량: 5843792 KB
# generate_metric.02 args["version"]=11
# ********************
# working model_version = 11  2025-06-04 14:45:17.599183
# ********************
# start to train all models. 2025-06-04 14:45:17.599217
# 14's training. status=start 2025-06-04 14:45:17.599233
# 14's training. status=end 2025-06-04 14:46:08.155008
# 44's training. status=start 2025-06-04 14:46:08.155307
# 44's training. status=end 2025-06-04 14:47:42.388407
# completed to train all models. 2025-06-04 14:47:42.388515
# train to create model(11). 2025-06-04 14:47:45.388599
# CPU 시간: 4188.856505 초
# 메모리 사용량: 5843792 KB
# generate_metric.02 args["version"]=12
# ********************
# working model_version = 12  2025-06-04 14:48:13.233967
# ********************
# start to train all models. 2025-06-04 14:48:13.234003
# 14's training. status=start 2025-06-04 14:48:13.234019
# 14's training. status=end 2025-06-04 14:49:04.774196
# 44's training. status=start 2025-06-04 14:49:04.774293
# 44's training. status=end 2025-06-04 14:50:37.320650
# completed to train all models. 2025-06-04 14:50:37.320748
# train to create model(12). 2025-06-04 14:50:40.320832
# CPU 시간: 4358.326581 초
# 메모리 사용량: 6103552 KB

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_1_10',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 1~12
# CPU 시간: 4.827452 초
# 메모리 사용량: 617232 KB
# generate_metric.02 args["version"]=1
# ********************
# working model_version = 1  2025-06-04 15:19:28.553995
# ********************
# start to train all models. 2025-06-04 15:19:28.554026
# 14's training. status=start 2025-06-04 15:19:28.554041
# 14's training. status=end 2025-06-04 15:20:17.007576
# 44's training. status=start 2025-06-04 15:20:17.007673
# 44's training. status=end 2025-06-04 15:21:46.750864
# completed to train all models. 2025-06-04 15:21:46.750963
# train to create model(1). 2025-06-04 15:21:49.751045
# CPU 시간: 171.71175 초
# 메모리 사용량: 1034704 KB
# generate_metric.02 args["version"]=2
# ********************
# working model_version = 2  2025-06-04 15:22:18.149388
# ********************
# start to train all models. 2025-06-04 15:22:18.149425
# 14's training. status=start 2025-06-04 15:22:18.149442
# 14's training. status=end 2025-06-04 15:23:07.685132
# 44's training. status=start 2025-06-04 15:23:07.685233
# 44's training. status=end 2025-06-04 15:24:40.560937
# completed to train all models. 2025-06-04 15:24:40.561034
# train to create model(2). 2025-06-04 15:24:43.561120
# CPU 시간: 339.620927 초
# 메모리 사용량: 1221840 KB
# generate_metric.02 args["version"]=3
# ********************
# working model_version = 3  2025-06-04 15:25:11.902279
# ********************
# start to train all models. 2025-06-04 15:25:11.902314
# 14's training. status=start 2025-06-04 15:25:11.902333
# 14's training. status=end 2025-06-04 15:26:03.816822
# 44's training. status=start 2025-06-04 15:26:03.816923
# 44's training. status=end 2025-06-04 15:27:33.613413
# completed to train all models. 2025-06-04 15:27:33.613513
# train to create model(3). 2025-06-04 15:27:36.613597
# CPU 시간: 508.323202 초
# 메모리 사용량: 1407696 KB
# generate_metric.02 args["version"]=4
# ********************
# working model_version = 4  2025-06-04 15:28:05.349529
# ********************
# start to train all models. 2025-06-04 15:28:05.349564
# 14's training. status=start 2025-06-04 15:28:05.349581
# 14's training. status=end 2025-06-04 15:28:55.245832
# 44's training. status=start 2025-06-04 15:28:55.245931
# 44's training. status=end 2025-06-04 15:30:25.425839
# completed to train all models. 2025-06-04 15:30:25.425935
# train to create model(4). 2025-06-04 15:30:28.426020
# CPU 시간: 676.783049 초
# 메모리 사용량: 1594736 KB
# generate_metric.02 args["version"]=5
# ********************
# working model_version = 5  2025-06-04 15:30:58.993911
# ********************
# start to train all models. 2025-06-04 15:30:58.993946
# 14's training. status=start 2025-06-04 15:30:58.993962
# 14's training. status=end 2025-06-04 15:31:48.641655
# 44's training. status=start 2025-06-04 15:31:48.641958
# 44's training. status=end 2025-06-04 15:33:20.559334
# completed to train all models. 2025-06-04 15:33:20.559431
# train to create model(5). 2025-06-04 15:33:23.559511
# CPU 시간: 846.126404 초
# 메모리 사용량: 1779056 KB
# generate_metric.02 args["version"]=6
# ********************
# working model_version = 6  2025-06-04 15:33:52.037081
# ********************
# start to train all models. 2025-06-04 15:33:52.037117
# 14's training. status=start 2025-06-04 15:33:52.037133
# 14's training. status=end 2025-06-04 15:34:40.644011
# 44's training. status=start 2025-06-04 15:34:40.644105
# 44's training. status=end 2025-06-04 15:36:14.020082
# completed to train all models. 2025-06-04 15:36:14.020181
# train to create model(6). 2025-06-04 15:36:17.020259
# CPU 시간: 1015.662732 초
# 메모리 사용량: 1965840 KB
# generate_metric.02 args["version"]=7
# ********************
# working model_version = 7  2025-06-04 15:36:45.193359
# ********************
# start to train all models. 2025-06-04 15:36:45.193394
# 14's training. status=start 2025-06-04 15:36:45.193410
# 14's training. status=end 2025-06-04 15:37:35.016240
# 44's training. status=start 2025-06-04 15:37:35.016345
# 44's training. status=end 2025-06-04 15:39:08.868056
# completed to train all models. 2025-06-04 15:39:08.868157
# train to create model(7). 2025-06-04 15:39:11.868246
# CPU 시간: 1186.268878 초
# 메모리 사용량: 2279808 KB
# generate_metric.02 args["version"]=8
# ********************
# working model_version = 8  2025-06-04 15:39:42.429452
# ********************
# start to train all models. 2025-06-04 15:39:42.429487
# 14's training. status=start 2025-06-04 15:39:42.429503
# 14's training. status=end 2025-06-04 15:40:32.451842
# 44's training. status=start 2025-06-04 15:40:32.451937
# 44's training. status=end 2025-06-04 15:42:05.636637
# completed to train all models. 2025-06-04 15:42:05.636733
# train to create model(8). 2025-06-04 15:42:08.636812
# CPU 시간: 1355.181846 초
# 메모리 사용량: 2484944 KB
# generate_metric.02 args["version"]=9
# ********************
# working model_version = 9  2025-06-04 15:42:36.520966
# ********************
# start to train all models. 2025-06-04 15:42:36.521001
# 14's training. status=start 2025-06-04 15:42:36.521018
# 14's training. status=end 2025-06-04 15:43:27.690210
# 44's training. status=start 2025-06-04 15:43:27.690308
# 44's training. status=end 2025-06-04 15:45:03.110506
# completed to train all models. 2025-06-04 15:45:03.110798
# train to create model(9). 2025-06-04 15:45:06.110884
# CPU 시간: 1527.507312 초
# 메모리 사용량: 2645056 KB
# generate_metric.02 args["version"]=10
# ********************
# working model_version = 10  2025-06-04 15:45:35.276531
# ********************
# start to train all models. 2025-06-04 15:45:35.276565
# 14's training. status=start 2025-06-04 15:45:35.276581
# 14's training. status=end 2025-06-04 15:46:24.147711
# 44's training. status=start 2025-06-04 15:46:24.147813
# 44's training. status=end 2025-06-04 15:47:56.497946
# completed to train all models. 2025-06-04 15:47:56.498046
# train to create model(10). 2025-06-04 15:47:59.498131
# CPU 시간: 1695.271035 초
# 메모리 사용량: 2857728 KB
# generate_metric.02 args["version"]=11
# ********************
# working model_version = 11  2025-06-04 15:48:27.991367
# ********************
# start to train all models. 2025-06-04 15:48:27.991401
# 14's training. status=start 2025-06-04 15:48:27.991417
# 14's training. status=end 2025-06-04 15:49:20.082839
# 44's training. status=start 2025-06-04 15:49:20.082933
# 44's training. status=end 2025-06-04 15:50:51.311486
# completed to train all models. 2025-06-04 15:50:51.311595
# train to create model(11). 2025-06-04 15:50:54.311683
# CPU 시간: 1867.215563 초
# 메모리 사용량: 2902896 KB
# generate_metric.02 args["version"]=12
# ********************
# working model_version = 12  2025-06-04 15:51:22.307712
# ********************
# start to train all models. 2025-06-04 15:51:22.307748
# 14's training. status=start 2025-06-04 15:51:22.307764
# 14's training. status=end 2025-06-04 15:52:12.569632
# 44's training. status=start 2025-06-04 15:52:12.569732
# 44's training. status=end 2025-06-04 15:53:44.252602
# completed to train all models. 2025-06-04 15:53:44.252700
# train to create model(12). 2025-06-04 15:53:47.252781
# CPU 시간: 2037.118393 초
# 메모리 사용량: 3226064 KB

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_1_11',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 1~12
# CPU 시간: 2040.049733 초
# 메모리 사용량: 3226064 KB
# generate_metric.02 args["version"]=1
# ********************
# working model_version = 1  2025-06-04 15:58:38.312586
# ********************
# start to train all models. 2025-06-04 15:58:38.312616
# 14's training. status=start 2025-06-04 15:58:38.312631
# 14's training. status=end 2025-06-04 15:59:27.608884
# 44's training. status=start 2025-06-04 15:59:27.608983
# 44's training. status=end 2025-06-04 16:01:01.025411
# completed to train all models. 2025-06-04 16:01:01.025513
# train to create model(1). 2025-06-04 16:01:04.025601
# CPU 시간: 2209.631604 초
# 메모리 사용량: 3279136 KB
# generate_metric.02 args["version"]=2
# ********************
# working model_version = 2  2025-06-04 16:01:32.160127
# ********************
# start to train all models. 2025-06-04 16:01:32.160163
# 14's training. status=start 2025-06-04 16:01:32.160180
# 14's training. status=end 2025-06-04 16:02:21.287871
# 44's training. status=start 2025-06-04 16:02:21.287972
# 44's training. status=end 2025-06-04 16:03:53.747775
# completed to train all models. 2025-06-04 16:03:53.747877
# train to create model(2). 2025-06-04 16:03:56.747958
# CPU 시간: 2378.835973 초
# 메모리 사용량: 3606896 KB
# generate_metric.02 args["version"]=3
# ********************
# working model_version = 3  2025-06-04 16:04:24.531080
# ********************
# start to train all models. 2025-06-04 16:04:24.531133
# 14's training. status=start 2025-06-04 16:04:24.531152
# 14's training. status=end 2025-06-04 16:05:17.761042
# 44's training. status=start 2025-06-04 16:05:17.761140
# 44's training. status=end 2025-06-04 16:06:52.260662
# completed to train all models. 2025-06-04 16:06:52.260759
# train to create model(3). 2025-06-04 16:06:55.260844
# CPU 시간: 2553.575726 초
# 메모리 사용량: 3660000 KB
# generate_metric.02 args["version"]=4
# ********************
# working model_version = 4  2025-06-04 16:07:27.252932
# ********************
# start to train all models. 2025-06-04 16:07:27.252967
# 14's training. status=start 2025-06-04 16:07:27.252983
# 14's training. status=end 2025-06-04 16:08:16.554462
# 44's training. status=start 2025-06-04 16:08:16.554561
# 44's training. status=end 2025-06-04 16:09:48.650052
# completed to train all models. 2025-06-04 16:09:48.650153
# train to create model(4). 2025-06-04 16:09:51.650232
# CPU 시간: 2722.729045 초
# 메모리 사용량: 3981088 KB
# generate_metric.02 args["version"]=5
# ********************
# working model_version = 5  2025-06-04 16:10:19.466119
# ********************
# start to train all models. 2025-06-04 16:10:19.466154
# 14's training. status=start 2025-06-04 16:10:19.466170
# 14's training. status=end 2025-06-04 16:11:08.582519
# 44's training. status=start 2025-06-04 16:11:08.582615
# 44's training. status=end 2025-06-04 16:12:41.337551
# completed to train all models. 2025-06-04 16:12:41.337649
# train to create model(5). 2025-06-04 16:12:44.337729
# CPU 시간: 2892.652717 초
# 메모리 사용량: 4311696 KB
# generate_metric.02 args["version"]=6
# ********************
# working model_version = 6  2025-06-04 16:13:14.235565
# ********************
# start to train all models. 2025-06-04 16:13:14.235592
# 14's training. status=start 2025-06-04 16:13:14.235602
# 14's training. status=end 2025-06-04 16:14:08.459014
# 44's training. status=start 2025-06-04 16:14:08.459128
# 44's training. status=end 2025-06-04 16:15:42.875047
# completed to train all models. 2025-06-04 16:15:42.875183
# train to create model(6). 2025-06-04 16:15:45.875273
# CPU 시간: 3068.270046 초
# 메모리 사용량: 4313232 KB
# generate_metric.02 args["version"]=7
# ********************
# working model_version = 7  2025-06-04 16:16:14.582728
# ********************
# start to train all models. 2025-06-04 16:16:14.582765
# 14's training. status=start 2025-06-04 16:16:14.582782
# 14's training. status=end 2025-06-04 16:17:05.166521
# 44's training. status=start 2025-06-04 16:17:05.166619
# 44's training. status=end 2025-06-04 16:18:37.409625
# completed to train all models. 2025-06-04 16:18:37.409723
# train to create model(7). 2025-06-04 16:18:40.409813
# CPU 시간: 3239.104159 초
# 메모리 사용량: 4534432 KB
# generate_metric.02 args["version"]=8
# ********************
# working model_version = 8  2025-06-04 16:19:08.313164
# ********************
# start to train all models. 2025-06-04 16:19:08.313198
# 14's training. status=start 2025-06-04 16:19:08.313215
# 14's training. status=end 2025-06-04 16:20:02.440725
# 44's training. status=start 2025-06-04 16:20:02.441023
# 44's training. status=end 2025-06-04 16:21:32.436354
# completed to train all models. 2025-06-04 16:21:32.436644
# train to create model(8). 2025-06-04 16:21:35.436731
# CPU 시간: 3408.837012 초
# 메모리 사용량: 4874256 KB
# generate_metric.02 args["version"]=9
# ********************
# working model_version = 9  2025-06-04 16:22:03.464131
# ********************
# start to train all models. 2025-06-04 16:22:03.464166
# 14's training. status=start 2025-06-04 16:22:03.464182
# 14's training. status=end 2025-06-04 16:23:01.581238
# 44's training. status=start 2025-06-04 16:23:01.581341
# 44's training. status=end 2025-06-04 16:24:33.287891
# completed to train all models. 2025-06-04 16:24:33.287994
# train to create model(9). 2025-06-04 16:24:36.288077
# CPU 시간: 3585.667545 초
# 메모리 사용량: 4894656 KB
# generate_metric.02 args["version"]=10
# ********************
# working model_version = 10  2025-06-04 16:25:04.642261
# ********************
# start to train all models. 2025-06-04 16:25:04.642296
# 14's training. status=start 2025-06-04 16:25:04.642312
# 14's training. status=end 2025-06-04 16:25:58.441161
# 44's training. status=start 2025-06-04 16:25:58.441259
# 44's training. status=end 2025-06-04 16:27:30.106013
# completed to train all models. 2025-06-04 16:27:30.106317
# train to create model(10). 2025-06-04 16:27:33.106410
# CPU 시간: 3755.781411 초
# 메모리 사용량: 5100992 KB
# generate_metric.02 args["version"]=11
# ********************
# working model_version = 11  2025-06-04 16:28:01.045339
# ********************
# start to train all models. 2025-06-04 16:28:01.045375
# 14's training. status=start 2025-06-04 16:28:01.045392
# 14's training. status=end 2025-06-04 16:28:53.060774
# 44's training. status=start 2025-06-04 16:28:53.060871
# 44's training. status=end 2025-06-04 16:30:25.638225
# completed to train all models. 2025-06-04 16:30:25.638376
# train to create model(11). 2025-06-04 16:30:28.638465
# CPU 시간: 3925.639206 초
# 메모리 사용량: 5430352 KB
# generate_metric.02 args["version"]=12
# ********************
# working model_version = 12  2025-06-04 16:30:56.677101
# ********************
# start to train all models. 2025-06-04 16:30:56.677137
# 14's training. status=start 2025-06-04 16:30:56.677154
# 14's training. status=end 2025-06-04 16:31:48.831616
# 44's training. status=start 2025-06-04 16:31:48.831710
# 44's training. status=end 2025-06-04 16:33:21.522136
# completed to train all models. 2025-06-04 16:33:21.522236
# train to create model(12). 2025-06-04 16:33:24.522314
# CPU 시간: 4096.829394 초
# 메모리 사용량: 5747376 KB

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_1_12',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 1~12
# CPU 시간: 54.643778 초
# 메모리 사용량: 862880 KB
# generate_metric.02 args["version"]=1
# ********************
# working model_version = 1  2025-06-04 17:13:35.072909
# ********************
# start to train all models. 2025-06-04 17:13:35.072942
# 14's training. status=start 2025-06-04 17:13:35.072958
# 14's training. status=end 2025-06-04 17:14:25.366775
# 44's training. status=start 2025-06-04 17:14:25.367075
# 44's training. status=end 2025-06-04 17:15:54.346660
# completed to train all models. 2025-06-04 17:15:54.346762
# train to create model(1). 2025-06-04 17:15:57.346842
# CPU 시간: 219.337198 초
# 메모리 사용량: 1199664 KB
# generate_metric.02 args["version"]=2
# ********************
# working model_version = 2  2025-06-04 17:16:24.950454
# ********************
# start to train all models. 2025-06-04 17:16:24.950488
# 14's training. status=start 2025-06-04 17:16:24.950504
# 14's training. status=end 2025-06-04 17:17:15.527679
# 44's training. status=start 2025-06-04 17:17:15.527779
# 44's training. status=end 2025-06-04 17:18:42.637913
# completed to train all models. 2025-06-04 17:18:42.638014
# train to create model(2). 2025-06-04 17:18:45.638098
# CPU 시간: 384.623978 초
# 메모리 사용량: 1388112 KB
# generate_metric.02 args["version"]=3
# ********************
# working model_version = 3  2025-06-04 17:19:13.130095
# ********************
# start to train all models. 2025-06-04 17:19:13.130133
# 14's training. status=start 2025-06-04 17:19:13.130150
# 14's training. status=end 2025-06-04 17:20:02.106641
# 44's training. status=start 2025-06-04 17:20:02.106740
# 44's training. status=end 2025-06-04 17:21:32.517659
# completed to train all models. 2025-06-04 17:21:32.517760
# train to create model(3). 2025-06-04 17:21:35.517846
# CPU 시간: 549.275894 초
# 메모리 사용량: 1574352 KB
# generate_metric.02 args["version"]=4
# ********************
# working model_version = 4  2025-06-04 17:22:04.782112
# ********************
# start to train all models. 2025-06-04 17:22:04.782138
# 14's training. status=start 2025-06-04 17:22:04.782149
# 14's training. status=end 2025-06-04 17:22:54.910344
# 44's training. status=start 2025-06-04 17:22:54.910438
# 44's training. status=end 2025-06-04 17:24:25.854331
# completed to train all models. 2025-06-04 17:24:25.854431
# train to create model(4). 2025-06-04 17:24:28.854512
# CPU 시간: 715.917579 초
# 메모리 사용량: 1759936 KB
# generate_metric.02 args["version"]=5
# ********************
# working model_version = 5  2025-06-04 17:24:58.319027
# ********************
# start to train all models. 2025-06-04 17:24:58.319064
# 14's training. status=start 2025-06-04 17:24:58.319080
# 14's training. status=end 2025-06-04 17:25:46.216653
# 44's training. status=start 2025-06-04 17:25:46.216754
# 44's training. status=end 2025-06-04 17:27:15.728829
# completed to train all models. 2025-06-04 17:27:15.728933
# train to create model(5). 2025-06-04 17:27:18.729019
# CPU 시간: 880.963655 초
# 메모리 사용량: 2085136 KB
# generate_metric.02 args["version"]=6
# ********************
# working model_version = 6  2025-06-04 17:27:47.729556
# ********************
# start to train all models. 2025-06-04 17:27:47.729592
# 14's training. status=start 2025-06-04 17:27:47.729608
# 14's training. status=end 2025-06-04 17:28:40.017906
# 44's training. status=start 2025-06-04 17:28:40.018005
# 44's training. status=end 2025-06-04 17:30:09.774251
# completed to train all models. 2025-06-04 17:30:09.774351
# train to create model(6). 2025-06-04 17:30:12.774434
# CPU 시간: 1047.33109 초
# 메모리 사용량: 2135888 KB
# generate_metric.02 args["version"]=7
# ********************
# working model_version = 7  2025-06-04 17:30:40.837971
# ********************
# start to train all models. 2025-06-04 17:30:40.838007
# 14's training. status=start 2025-06-04 17:30:40.838023
# 14's training. status=end 2025-06-04 17:31:31.099235
# 44's training. status=start 2025-06-04 17:31:31.099334
# 44's training. status=end 2025-06-04 17:33:03.435564
# completed to train all models. 2025-06-04 17:33:03.435668
# train to create model(7). 2025-06-04 17:33:06.435750
# CPU 시간: 1214.000267 초
# 메모리 사용량: 2321024 KB
# generate_metric.02 args["version"]=8
# ********************
# working model_version = 8  2025-06-04 17:33:36.821695
# ********************
# start to train all models. 2025-06-04 17:33:36.821731
# 14's training. status=start 2025-06-04 17:33:36.821748
# 14's training. status=end 2025-06-04 17:34:26.136770
# 44's training. status=start 2025-06-04 17:34:26.136866
# 44's training. status=end 2025-06-04 17:35:55.521014
# completed to train all models. 2025-06-04 17:35:55.521110
# train to create model(8). 2025-06-04 17:35:58.521193
# CPU 시간: 1379.36357 초
# 메모리 사용량: 2647440 KB
# generate_metric.02 args["version"]=9
# ********************
# working model_version = 9  2025-06-04 17:36:26.320485
# ********************
# start to train all models. 2025-06-04 17:36:26.320520
# 14's training. status=start 2025-06-04 17:36:26.320536
# 14's training. status=end 2025-06-04 17:37:17.403917
# 44's training. status=start 2025-06-04 17:37:17.404016
# 44's training. status=end 2025-06-04 17:38:48.388711
# completed to train all models. 2025-06-04 17:38:48.388813
# train to create model(9). 2025-06-04 17:38:51.388893
# CPU 시간: 1548.547393 초
# 메모리 사용량: 2689040 KB
# generate_metric.02 args["version"]=10
# ********************
# working model_version = 10  2025-06-04 17:39:19.224068
# ********************
# start to train all models. 2025-06-04 17:39:19.224104
# 14's training. status=start 2025-06-04 17:39:19.224120
# 14's training. status=end 2025-06-04 17:40:06.955187
# 44's training. status=start 2025-06-04 17:40:06.955286
# 44's training. status=end 2025-06-04 17:41:36.935530
# completed to train all models. 2025-06-04 17:41:36.935632
# train to create model(10). 2025-06-04 17:41:39.935713
# CPU 시간: 1712.543857 초
# 메모리 사용량: 3023920 KB
# generate_metric.02 args["version"]=11
# ********************
# working model_version = 11  2025-06-04 17:42:08.207400
# ********************
# start to train all models. 2025-06-04 17:42:08.207426
# 14's training. status=start 2025-06-04 17:42:08.207438
# 14's training. status=end 2025-06-04 17:42:59.165130
# 44's training. status=start 2025-06-04 17:42:59.165230
# 44's training. status=end 2025-06-04 17:44:27.432557
# completed to train all models. 2025-06-04 17:44:27.432654
# train to create model(11). 2025-06-04 17:44:30.432738
# CPU 시간: 1880.926556 초
# 메모리 사용량: 3064624 KB
# generate_metric.02 args["version"]=12
# ********************
# working model_version = 12  2025-06-04 17:44:59.179014
# ********************
# start to train all models. 2025-06-04 17:44:59.179050
# 14's training. status=start 2025-06-04 17:44:59.179065
# 14's training. status=end 2025-06-04 17:45:49.631266
# 44's training. status=start 2025-06-04 17:45:49.631366
# 44's training. status=end 2025-06-04 17:47:19.726920
# completed to train all models. 2025-06-04 17:47:19.727201
# train to create model(12). 2025-06-04 17:47:22.727286
# CPU 시간: 2046.928132 초
# 메모리 사용량: 3392640 KB

# %%
## end
