# %% [markdown]
# # DB에서 매트릭을 읽어서 그래프 그리기 (v4.5.2)
#
# <p>won@aimmo.co.kr(swhors@naver.com)</p>

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /opt/conda/lib/python3.12/site-packages (11.2.1)

# %%
def restart_kernel():
    # Restart the kernet after libraries are loaded.
    import IPython
    from datetime import datetime
    print(f'restart kernel... {datetime.now()}')
    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

restart_kernel()
# Out:
# restart kernel... 2025-06-04 17:32:25.255068

# %%
import os
import sys
from datetime import datetime
cwd = os.getcwd()
sys.path.append(cwd)
print(sys.path)

print(f'load_library step#1 {datetime.now()}')

from datetime import datetime
from lib.metrics_loader import load_data_by_version
from lib.graph_util import draw_data_graph
from lib.graph_util import draw_data_graph_v2
from lib.graph_util import load_image
from lib.graph_util import draw_graph_with_metric
from lib.graph_util import load_all_image
from lib.metric_analyze import load_data, draw_metric
from lib.metric_analyze import draw_graph, draw_graph_by_version
from lib.metric_analyze import load_data_matched_freq_v2
print(f'load_library step#2 {datetime.now()}')
# Out:
# ['/home/swhors/jupyter-workspace/LSTM/$PWD', '/home/swhors/jupyter-workspace/finance', '/home/swhors/jupyter-workspace/finance/venv/lib/python3.11/site-paches', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '', '/home/swhors/jupyter-workspace/finance/venv/lib/python3.11/site-packages', '/home/swhors/jupyter-workspace/LSTM']
# load_library step#1 2025-06-04 17:32:30.728952
# load_library step#2 2025-06-04 17:32:31.217596

# %% [markdown]
# #### Test P4_5_1_3

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_3'
draw_graph(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 1.422045 초
# 메모리 사용량: 239936 KB

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_3'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 2.391263 초
# 메모리 사용량: 239936 KB

# %% [markdown]
# #### Test P4_5_1_4

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_4'
draw_graph(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 2.67249 초
# 메모리 사용량: 239936 KB

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_4'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 3.025698 초
# 메모리 사용량: 239936 KB

# %% [markdown]
# #### Test P4_5_1_5

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_5'
draw_graph(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 4.046741 초
# 메모리 사용량: 239936 KB

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_5'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 3.659191 초
# 메모리 사용량: 239936 KB

# %% [markdown]
# #### Test P4_5_1_6

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_6'
draw_graph(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 9.269526 초
# 메모리 사용량: 239936 KB

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_6'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 9.685258 초
# 메모리 사용량: 239936 KB

# %% [markdown]
# #### Test P4_5_1_7

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_7'
draw_graph(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 3.207122 초
# 메모리 사용량: 211712 KB

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_7'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 3.533942 초
# 메모리 사용량: 211712 KB

# %% [markdown]
# #### Test P4_5_1_8

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_8'
draw_graph(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 9.487665 초
# 메모리 사용량: 211712 KB

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_8'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 11.057786 초
# 메모리 사용량: 211712 KB

# %% [markdown]
# #### Test P4_5_1_9

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_9'
draw_graph(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 11.457121 초
# 메모리 사용량: 211712 KB

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_9'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 11.762013 초
# 메모리 사용량: 211712 KB

# %% [markdown]
# #### Test P4_5_1_10

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_10'
draw_graph(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 12.946191 초
# 메모리 사용량: 211712 KB

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_10'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 13.398477 초
# 메모리 사용량: 211712 KB

# %% [markdown]
# #### Test ID P4_5_1_11

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_11'
draw_graph(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 9.269526 초
# 메모리 사용량: 239936 KB

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_11'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 9.685258 초
# 메모리 사용량: 239936 KB

# %% [markdown]
# #### Test P4_5_1_12

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_12'
draw_graph(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 6.840961 초
# 메모리 사용량: 211712 KB

# %%
model_ids = [14, 44]
test_id = 'P4_5_1_12'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.0_2 (model_id=44)
# read_db.10 complete (model_id=44)
# CPU 시간: 9.685258 초
# 메모리 사용량: 239936 KB

# %%
test_ids=['P4_5_1_8',
          'P4_5_1_9',
          'P4_5_1_10',
          'P4_5_1_11',
          'P4_5_1_12']
model_ids = [14, 44]
results = load_data_matched_freq_v2(test_ids=test_ids, model_ids=model_ids)
for result in results:
    print(f'{"*"*30}\nid={result["id"]}')
    print('   ** metric version:round')
    sorted_keys = sorted(result['metric'])
    for metric in sorted_keys:
        if len(result['metric'][metric]) > 2:
            print(metric,result['metric'][metric])
# Out:
# load_data_matched_freq_v2.read_db.01_01 (model_id=14, test_id=P4_5_1_8)
# load_data_matched_freq_v2.read_db.01_02 (model_id=14, test_id=P4_5_1_9)
# load_data_matched_freq_v2.read_db.01_03 (model_id=14, test_id=P4_5_1_10)
# load_data_matched_freq_v2.read_db.01_04 (model_id=14, test_id=P4_5_1_11)
# load_data_matched_freq_v2.read_db.01_05 (model_id=14, test_id=P4_5_1_12)
# load_data_matched_freq_v2.read_db.01_06 (model_id=44, test_id=P4_5_1_8)
# load_data_matched_freq_v2.read_db.01_07 (model_id=44, test_id=P4_5_1_9)
# load_data_matched_freq_v2.read_db.01_08 (model_id=44, test_id=P4_5_1_10)
# load_data_matched_freq_v2.read_db.01_09 (model_id=44, test_id=P4_5_1_11)
# load_data_matched_freq_v2.read_db.01_10 (model_id=44, test_id=P4_5_1_12)
# load_data_matched_freq_v2.read_db.10 complete (model_id=44)
# ******************************
# id=14
#    ** metric version:round
# 01:00 ['P4_5_1_8', 'P4_5_1_9', 'P4_5_1_11']
# 02:30 ['P4_5_1_8', 'P4_5_1_9', 'P4_5_1_12']
# 03:11 ['P4_5_1_9', 'P4_5_1_11', 'P4_5_1_12']
# 04:23 ['P4_5_1_8', 'P4_5_1_10', 'P4_5_1_12']
# 06:19 ['P4_5_1_10', 'P4_5_1_11', 'P4_5_1_12']
# 09:14 ['P4_5_1_9', 'P4_5_1_11', 'P4_5_1_12']
# 11:22 ['P4_5_1_8', 'P4_5_1_11', 'P4_5_1_12']
# 11:34 ['P4_5_1_9', 'P4_5_1_10', 'P4_5_1_12']
# ******************************
# id=44
#    ** metric version:round
# 02:32 ['P4_5_1_8', 'P4_5_1_9', 'P4_5_1_12']
# 07:23 ['P4_5_1_8', 'P4_5_1_9', 'P4_5_1_11']
# 08:40 ['P4_5_1_8', 'P4_5_1_9', 'P4_5_1_12']
# 09:15 ['P4_5_1_9', 'P4_5_1_10', 'P4_5_1_12']

# %%
test_ids=['P4_5_1_5',
          'P4_5_1_6',
          'P4_5_1_7',
          'P4_5_1_8',
          'P4_5_1_9',
          'P4_5_1_10',
          'P4_5_1_11',
          'P4_5_1_12']
model_ids = [14, 44]
results = load_data_matched_freq_v2(test_ids=test_ids, model_ids=model_ids)
for result in results:
    print(f'{"*"*30}\nid={result["id"]}')
    print('   ** metric version:round')
    sorted_keys = sorted(result['metric'])
    for metric in sorted_keys:
        if len(result['metric'][metric]) > 2:
            print(metric,result['metric'][metric])
# Out:
# load_data_matched_freq_v2.read_db.01_01 (model_id=14, test_id=P4_5_1_5)
# load_data_matched_freq_v2.read_db.01_02 (model_id=14, test_id=P4_5_1_6)
# load_data_matched_freq_v2.read_db.01_03 (model_id=14, test_id=P4_5_1_7)
# load_data_matched_freq_v2.read_db.01_04 (model_id=14, test_id=P4_5_1_8)
# load_data_matched_freq_v2.read_db.01_05 (model_id=14, test_id=P4_5_1_9)
# load_data_matched_freq_v2.read_db.01_06 (model_id=14, test_id=P4_5_1_10)
# load_data_matched_freq_v2.read_db.01_07 (model_id=14, test_id=P4_5_1_11)
# load_data_matched_freq_v2.read_db.01_08 (model_id=14, test_id=P4_5_1_12)
# load_data_matched_freq_v2.read_db.01_09 (model_id=44, test_id=P4_5_1_5)
# load_data_matched_freq_v2.read_db.01_10 (model_id=44, test_id=P4_5_1_6)
# load_data_matched_freq_v2.read_db.01_11 (model_id=44, test_id=P4_5_1_7)
# load_data_matched_freq_v2.read_db.01_12 (model_id=44, test_id=P4_5_1_8)
# load_data_matched_freq_v2.read_db.01_13 (model_id=44, test_id=P4_5_1_9)
# load_data_matched_freq_v2.read_db.01_14 (model_id=44, test_id=P4_5_1_10)
# load_data_matched_freq_v2.read_db.01_15 (model_id=44, test_id=P4_5_1_11)
# load_data_matched_freq_v2.read_db.01_16 (model_id=44, test_id=P4_5_1_12)
# load_data_matched_freq_v2.read_db.10 complete (model_id=44)
# ******************************
# id=14
#    ** metric version:round
# 01:00 ['P4_5_1_8', 'P4_5_1_9', 'P4_5_1_11']
# 01:30 ['P4_5_1_6', 'P4_5_1_7', 'P4_5_1_9']
# 01:36 ['P4_5_1_5', 'P4_5_1_6', 'P4_5_1_11']
# 02:20 ['P4_5_1_7', 'P4_5_1_8', 'P4_5_1_11']
# 02:30 ['P4_5_1_8', 'P4_5_1_9', 'P4_5_1_12']
# 03:02 ['P4_5_1_6', 'P4_5_1_9', 'P4_5_1_11']
# 03:11 ['P4_5_1_9', 'P4_5_1_11', 'P4_5_1_12']
# 03:17 ['P4_5_1_7', 'P4_5_1_8', 'P4_5_1_11']
# 03:23 ['P4_5_1_5', 'P4_5_1_6', 'P4_5_1_7']
# 03:25 ['P4_5_1_5', 'P4_5_1_10', 'P4_5_1_11']
# 03:31 ['P4_5_1_6', 'P4_5_1_9', 'P4_5_1_11']
# 03:35 ['P4_5_1_5', 'P4_5_1_7', 'P4_5_1_11']
# 04:23 ['P4_5_1_8', 'P4_5_1_10', 'P4_5_1_12']
# 05:12 ['P4_5_1_5', 'P4_5_1_6', 'P4_5_1_7']
# 05:34 ['P4_5_1_5', 'P4_5_1_6', 'P4_5_1_10', 'P4_5_1_11']
# 05:40 ['P4_5_1_6', 'P4_5_1_10', 'P4_5_1_12']
# 06:19 ['P4_5_1_10', 'P4_5_1_11', 'P4_5_1_12']
# 06:21 ['P4_5_1_7', 'P4_5_1_8', 'P4_5_1_11']
# 06:25 ['P4_5_1_5', 'P4_5_1_6', 'P4_5_1_12']
# 06:34 ['P4_5_1_6', 'P4_5_1_11', 'P4_5_1_12']
# 07:40 ['P4_5_1_5', 'P4_5_1_6', 'P4_5_1_8', 'P4_5_1_10']
# 08:03 ['P4_5_1_6', 'P4_5_1_8', 'P4_5_1_12']
# 08:24 ['P4_5_1_6', 'P4_5_1_7', 'P4_5_1_11']
# 08:27 ['P4_5_1_7', 'P4_5_1_8', 'P4_5_1_11']
# 09:14 ['P4_5_1_9', 'P4_5_1_11', 'P4_5_1_12']
# 09:23 ['P4_5_1_6', 'P4_5_1_8', 'P4_5_1_10']
# 10:04 ['P4_5_1_7', 'P4_5_1_10', 'P4_5_1_12']
# 10:21 ['P4_5_1_5', 'P4_5_1_8', 'P4_5_1_9']
# 10:31 ['P4_5_1_5', 'P4_5_1_7', 'P4_5_1_10']
# 11:22 ['P4_5_1_8', 'P4_5_1_11', 'P4_5_1_12']
# 11:29 ['P4_5_1_7', 'P4_5_1_8', 'P4_5_1_12']
# 11:34 ['P4_5_1_9', 'P4_5_1_10', 'P4_5_1_12']
# 12:06 ['P4_5_1_5', 'P4_5_1_7', 'P4_5_1_8', 'P4_5_1_10']
# ******************************
# id=44
#    ** metric version:round
# 01:32 ['P4_5_1_5', 'P4_5_1_7', 'P4_5_1_9']
# 02:32 ['P4_5_1_6', 'P4_5_1_8', 'P4_5_1_9', 'P4_5_1_12']
# 03:22 ['P4_5_1_5', 'P4_5_1_7', 'P4_5_1_11']
# 04:02 ['P4_5_1_5', 'P4_5_1_6', 'P4_5_1_7']
# 04:19 ['P4_5_1_6', 'P4_5_1_7', 'P4_5_1_8']
# 04:23 ['P4_5_1_6', 'P4_5_1_8', 'P4_5_1_9']
# 04:24 ['P4_5_1_5', 'P4_5_1_6', 'P4_5_1_9', 'P4_5_1_12']
# 06:24 ['P4_5_1_7', 'P4_5_1_8', 'P4_5_1_12']
# 06:26 ['P4_5_1_7', 'P4_5_1_9', 'P4_5_1_12']
# 07:13 ['P4_5_1_6', 'P4_5_1_7', 'P4_5_1_8']
# 07:16 ['P4_5_1_6', 'P4_5_1_9', 'P4_5_1_11']
# 07:23 ['P4_5_1_6', 'P4_5_1_8', 'P4_5_1_9', 'P4_5_1_11']
# 08:14 ['P4_5_1_7', 'P4_5_1_9', 'P4_5_1_10']
# 08:40 ['P4_5_1_7', 'P4_5_1_8', 'P4_5_1_9', 'P4_5_1_12']
# 09:15 ['P4_5_1_9', 'P4_5_1_10', 'P4_5_1_12']
# 09:32 ['P4_5_1_7', 'P4_5_1_8', 'P4_5_1_9']
# 10:03 ['P4_5_1_5', 'P4_5_1_10', 'P4_5_1_11']
# 10:07 ['P4_5_1_6', 'P4_5_1_9', 'P4_5_1_12']
# 10:13 ['P4_5_1_5', 'P4_5_1_6', 'P4_5_1_10', 'P4_5_1_12']
# 11:18 ['P4_5_1_5', 'P4_5_1_6', 'P4_5_1_11', 'P4_5_1_12']
# 12:13 ['P4_5_1_6', 'P4_5_1_7', 'P4_5_1_8', 'P4_5_1_11']
