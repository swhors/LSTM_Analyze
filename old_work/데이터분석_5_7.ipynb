# %% [markdown]
# # DB에서 매트릭을 읽어서 그래프 그리기 (v4.5.7)
#
# <p>won@aimmo.co.kr(swhors@naver.com)</p>

# %%
# !pip install pillow

# %%
def restart_kernel():
    # Restart the kernet after libraries are loaded.
    import IPython
    from datetime import datetime
    print(f'restart kernel... {datetime.now()}')
    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

restart_kernel()
# Out:
# restart kernel... 2025-06-05 15:16:21.830569

# %%
import os
import sys
from datetime import datetime
cwd = os.getcwd()
sys.path.append(cwd)
print(sys.path)

print(f'load_library step#1 {datetime.now()}')

from datetime import datetime
from lib.metrics_loader import load_data_by_version
from lib.graph_util import draw_data_graph
from lib.graph_util import draw_data_graph_v2
from lib.graph_util import load_image
from lib.graph_util import draw_graph_with_metric
from lib.graph_util import load_all_image
from lib.metric_analyze import load_data, draw_metric
from lib.metric_analyze import draw_graph, draw_graph_by_version
from lib.metric_analyze import load_data_matched_freq_v2
from lib.metric_analyze import load_all_matched_info
from lib.metric_analyze import draw_graph_matched_size
from lib.metric_analyze import get_matched_case_by_round
print(f'load_library step#2 {datetime.now()}')

model_ids = [2]
# Out:
# ['/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/home/simpson/.local/lib/python3.8/site-packages', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/home/simpson/jupyter-workspace/LSTM_Analyze']
# load_library step#1 2025-06-05 23:56:00.549193
# load_library step#2 2025-06-05 23:56:01.038851

# %% [markdown]
# #### Test P4_5_6_1

# %%
test_id = 'P4_5_6_1'
draw_graph(test_id=test_id,
           model_ids=model_ids,
           del_res=True,
           width=60, height=30)
# Out:
# read_db.0_1 (model_id=14)
# read_db.10 complete (model_id=14)
# CPU 시간: 1.582976 초
# 메모리 사용량: 230944 KB

# %%
test_id = 'P4_5_6_1'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14, test_id=P4_5_5_1)
# read_db.10 complete (model_id=14)
# CPU 시간: 1.744729 초
# 메모리 사용량: 230944 KB

# %% [markdown]
# #### Test P4_5_6_2

# %%
test_id = 'P4_5_6_2'
draw_graph(test_id=test_id,
           model_ids=model_ids,
           del_res=True,
           width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.10 complete (model_id=14)
# CPU 시간: 1.8927 초
# 메모리 사용량: 230944 KB

# %%
test_id = 'P4_5_6_2'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14, test_id=P4_5_5_2)
# read_db.10 complete (model_id=14)
# CPU 시간: 2.038162 초
# 메모리 사용량: 230944 KB

# %% [markdown]
# #### Test P4_5_6_2 #2

# %%
test_id="P4_5_6_2"
draw_graph_matched_size(test_ids=[test_id], model_ids=model_ids, from_pos=0, to_pos=1000)
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_5_2)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)

# %% [markdown]
# #### Test P4_5_6_3 #2

# %%
test_id="P4_5_6_3"
draw_graph_matched_size(test_ids=[test_id], model_ids=model_ids, from_pos=0, to_pos=1000)
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_5_3)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)

# %% [markdown]
# #### Test P4_5_6_4 #2

# %%
test_id="P4_5_6_4"
draw_graph_matched_size(test_ids=[test_id], model_ids=model_ids, from_pos=0, to_pos=1000)
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_5_4)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)

# %%
test_ids=['P4_5_7_2',
          'P4_5_7_3',
          'P4_5_7_4',
          'P4_5_7_5',
          'P4_5_7_6',
          'P4_5_7_7',
          'P4_5_7_8']
draw_graph_matched_size(test_ids=test_ids, model_ids=model_ids, from_pos=0, to_pos=1001)
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_6_2)
# load_all_matched.read_db.01_02 (model_id=<built-in function id>, test_id=P4_5_6_3)
# load_all_matched.read_db.01_03 (model_id=<built-in function id>, test_id=P4_5_6_4)
# load_all_matched.read_db.01_04 (model_id=<built-in function id>, test_id=P4_5_6_5)
# load_all_matched.read_db.01_05 (model_id=<built-in function id>, test_id=P4_5_6_6)
# load_all_matched.read_db.01_06 (model_id=<built-in function id>, test_id=P4_5_6_7)
# load_all_matched.read_db.01_07 (model_id=<built-in function id>, test_id=P4_5_6_8)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)

# %%
test_ids=['P4_5_7_2',
          'P4_5_7_3',
          'P4_5_7_4',
          'P4_5_7_5',
          'P4_5_7_6',
          'P4_5_7_7',
          'P4_5_7_8']
draw_graph_matched_size(test_ids=test_ids, model_ids=model_ids, from_pos=0, to_pos=1001)
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_6_2)
# load_all_matched.read_db.01_02 (model_id=<built-in function id>, test_id=P4_5_6_3)
# load_all_matched.read_db.01_03 (model_id=<built-in function id>, test_id=P4_5_6_4)
# load_all_matched.read_db.01_04 (model_id=<built-in function id>, test_id=P4_5_6_5)
# load_all_matched.read_db.01_05 (model_id=<built-in function id>, test_id=P4_5_6_6)
# load_all_matched.read_db.01_06 (model_id=<built-in function id>, test_id=P4_5_6_7)
# load_all_matched.read_db.01_07 (model_id=<built-in function id>, test_id=P4_5_6_8)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)

# %%
test_ids=['P4_5_7_2',
          'P4_5_7_3',
          'P4_5_7_4',
          'P4_5_7_5',
          'P4_5_7_6',
          'P4_5_7_7',
          'P4_5_7_8']
results2 = get_matched_case_by_round(test_ids=test_ids, model_ids=model_ids, min_val=2)
sorted_results2 = sorted(results2.items())
results3 = get_matched_case_by_round(test_ids=test_ids, model_ids=model_ids, min_val=3)
sorted_results3 = sorted(results3.items())
print(f'Now = {datetime.now()}')
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_7_2)
# load_all_matched.read_db.01_02 (model_id=<built-in function id>, test_id=P4_5_7_3)
# load_all_matched.read_db.01_03 (model_id=<built-in function id>, test_id=P4_5_7_4)
# load_all_matched.read_db.01_04 (model_id=<built-in function id>, test_id=P4_5_7_5)
# load_all_matched.read_db.01_05 (model_id=<built-in function id>, test_id=P4_5_7_6)
# load_all_matched.read_db.01_06 (model_id=<built-in function id>, test_id=P4_5_7_7)
# load_all_matched.read_db.01_07 (model_id=<built-in function id>, test_id=P4_5_7_8)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_7_2)
# load_all_matched.read_db.01_02 (model_id=<built-in function id>, test_id=P4_5_7_3)
# load_all_matched.read_db.01_03 (model_id=<built-in function id>, test_id=P4_5_7_4)
# load_all_matched.read_db.01_04 (model_id=<built-in function id>, test_id=P4_5_7_5)
# load_all_matched.read_db.01_05 (model_id=<built-in function id>, test_id=P4_5_7_6)
# load_all_matched.read_db.01_06 (model_id=<built-in function id>, test_id=P4_5_7_7)
# load_all_matched.read_db.01_07 (model_id=<built-in function id>, test_id=P4_5_7_8)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)
# Now = 2025-06-05 23:56:11.482446

# %%
cnt = 0
for result in sorted_results2:
    if len(result[1]) >= 4:
        print(result)
        cnt += 1
print(f'total count = {cnt}')
# Out:
# (48, ['P4_5_7_3', 'P4_5_7_4', 'P4_5_7_5', 'P4_5_7_8'])
# (103, ['P4_5_7_4', 'P4_5_7_5', 'P4_5_7_7', 'P4_5_7_8'])
# (156, ['P4_5_7_2', 'P4_5_7_3', 'P4_5_7_4', 'P4_5_7_6'])
# (162, ['P4_5_7_2', 'P4_5_7_3', 'P4_5_7_5', 'P4_5_7_7'])
# (215, ['P4_5_7_3', 'P4_5_7_4', 'P4_5_7_6', 'P4_5_7_7'])
# (245, ['P4_5_7_2', 'P4_5_7_4', 'P4_5_7_6', 'P4_5_7_8'])
# (251, ['P4_5_7_2', 'P4_5_7_3', 'P4_5_7_5', 'P4_5_7_6'])
# (347, ['P4_5_7_3', 'P4_5_7_4', 'P4_5_7_6', 'P4_5_7_8'])
# (355, ['P4_5_7_3', 'P4_5_7_4', 'P4_5_7_7', 'P4_5_7_8'])
# (363, ['P4_5_7_2', 'P4_5_7_4', 'P4_5_7_5', 'P4_5_7_6'])
# (460, ['P4_5_7_3', 'P4_5_7_4', 'P4_5_7_6', 'P4_5_7_7', 'P4_5_7_8'])
# (544, ['P4_5_7_2', 'P4_5_7_3', 'P4_5_7_6', 'P4_5_7_7'])
# (624, ['P4_5_7_2', 'P4_5_7_3', 'P4_5_7_4', 'P4_5_7_5'])
# (726, ['P4_5_7_2', 'P4_5_7_5', 'P4_5_7_7', 'P4_5_7_8'])
# (751, ['P4_5_7_3', 'P4_5_7_4', 'P4_5_7_5', 'P4_5_7_7'])
# (761, ['P4_5_7_5', 'P4_5_7_6', 'P4_5_7_7', 'P4_5_7_8'])
# (763, ['P4_5_7_2', 'P4_5_7_6', 'P4_5_7_7', 'P4_5_7_8'])
# (770, ['P4_5_7_2', 'P4_5_7_3', 'P4_5_7_4', 'P4_5_7_5'])
# (771, ['P4_5_7_5', 'P4_5_7_6', 'P4_5_7_7', 'P4_5_7_8'])
# (805, ['P4_5_7_2', 'P4_5_7_5', 'P4_5_7_7', 'P4_5_7_8'])
# (844, ['P4_5_7_2', 'P4_5_7_6', 'P4_5_7_7', 'P4_5_7_8'])
# (854, ['P4_5_7_2', 'P4_5_7_5', 'P4_5_7_6', 'P4_5_7_8'])
# (901, ['P4_5_7_3', 'P4_5_7_6', 'P4_5_7_7', 'P4_5_7_8'])
# (916, ['P4_5_7_3', 'P4_5_7_4', 'P4_5_7_5', 'P4_5_7_8'])
# (935, ['P4_5_7_3', 'P4_5_7_4', 'P4_5_7_5', 'P4_5_7_8'])
# (937, ['P4_5_7_3', 'P4_5_7_4', 'P4_5_7_6', 'P4_5_7_8'])
# (959, ['P4_5_7_2', 'P4_5_7_5', 'P4_5_7_6', 'P4_5_7_8'])
# (973, ['P4_5_7_3', 'P4_5_7_5', 'P4_5_7_7', 'P4_5_7_8'])
# total count = 28

# %%
cnt = 0
for result in sorted_results3:
    if len(result[1]) > 1:
        print(result)
        cnt += 1
print(f'total count = {cnt}')
# Out:
# (35, ['P4_5_7_6', 'P4_5_7_8'])
# (111, ['P4_5_7_3', 'P4_5_7_5'])
# (126, ['P4_5_7_4', 'P4_5_7_8'])
# (162, ['P4_5_7_3', 'P4_5_7_5'])
# (241, ['P4_5_7_5', 'P4_5_7_8'])
# (409, ['P4_5_7_4', 'P4_5_7_6'])
# (411, ['P4_5_7_3', 'P4_5_7_6'])
# (414, ['P4_5_7_4', 'P4_5_7_7'])
# (506, ['P4_5_7_2', 'P4_5_7_4'])
# (561, ['P4_5_7_4', 'P4_5_7_8'])
# (569, ['P4_5_7_3', 'P4_5_7_4'])
# (726, ['P4_5_7_5', 'P4_5_7_7'])
# (754, ['P4_5_7_2', 'P4_5_7_3'])
# (945, ['P4_5_7_2', 'P4_5_7_7'])
# total count = 14

# %%
for result in sorted_results:
    if len(result[1])>=(len(test_ids)-1):
        print(result)

# %% [markdown]
# - *876, 877, 879, 880*
# ```
# (162, ['P4_5_7_2', 'P4_5_7_3'*, 'P4_5_7_5'*, 'P4_5_7_7'])
# (726, ['P4_5_7_2', 'P4_5_7_5'*, 'P4_5_7_7'*, 'P4_5_7_8'])
# ```

# %%
test_ids=['P4_5_5_2',
          'P4_5_5_3',
          'P4_5_5_4',
          'P4_5_5_5',
          'P4_5_5_6',
          'P4_5_5_7',
          'P4_5_5_8']
# results = load_data_matched_freq_v2(test_ids=test_ids, model_ids=model_ids)
# for result in results:
#     print(f'{"*"*30}\nid={result["id"]}')
#     print('   ** metric version:round')
#     sorted_keys = sorted(result['metric'])
#     for metric in sorted_keys:
#         if len(result['metric'][metric]) > 2:
#             print(metric,result['metric'][metric])
