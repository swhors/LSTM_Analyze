# %% [markdown]
# # Prediction with LSTM model (v.4.4.3)
# <p style='text-align: right;'>with selectd4.csv</p>
#
# * history
#   * 2025/05/23 PM06:02 : 3번째 모델의 3번째 데이터를 사용

# %%
# !pip install scikit-learn
# !pip install tensorflow
from datetime import datetime
print(f'restart kernel... {datetime.now()}')

# %%
def restart_kernel():
    # Restart the kernet after libraries are loaded.
    import IPython
    from datetime import datetime
    print(f'restart kernel... {datetime.now()}')
    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

restart_kernel()
# Out:
# restart kernel... 2025-05-28 00:57:09.487633

# %%
# load dependacies
import os
import time
import resource
from datetime import datetime
from lib.globalvar import *
from lib.data_loader import DataLoader
from lib.small_predict import predict_small, print_predict_small
from lib.activation import ActivationOutput, RecurrentActivation
from lib.small_predict import build_and_predict, gen_multi_model, save_model

print(f"imported library. ({datetime.now()})")
# Out:
# imported library. (2025-05-28 00:57:19.172198)

# %%
##
## 모델링 환경 설정
##
window=1 # default = 1 , help = "time stamps"
data_dir='./csv/selectd4.csv'
    
mode='predict' # help = "back-test or predict")

mode2='sampling' # help = "greed or sampling")
verb='verbose' # help = "verbose or not_verb")
    
trial=20 # help = "how much trials to generate")
training_length=0.95 # default = 0.9)
epoch=20 # default = 3
batch=1 # default = 1
model_type='lstm4' # help = "lstm1 or lstm2")
hid_dim = 50
from_pos = 0
last = [[1, 5, 18, 20, 30, 35],
        [7, 9, 24, 40, 42, 44],
        [3, 6, 7, 11, 12, 17],
        [3, 13, 28, 34, 38, 42],
        [5, 12, 24, 29, 32, 42]]
print(f"finished to set environemnt. ({datetime.now()})")
# Out:
# finished to set environemnt. (2025-05-28 00:57:19.179109)

# %%
import tensorflow as tf
print(f'{tf.version}')
# Out:
# <module 'tensorflow._api.v2.version' from '/home/swhors/jupyter-workspace/finance/venv/lib/python3.11/site-packages/tensorflow/_api/v2/version/__init__.py'>

# %%
dataset_dicts = {
    1: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=0,
                  verbose=False
                  ),
    2: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=300,
                  verbose=False
                  )
    }

print(f'completed to load data. {datetime.now()}')
# Out:
# completed to load data. 2025-05-28 00:57:19.218376

# %%
###########
## layers
## LSTM Neural 계층 선언
###########
"""
Activation (Output):
    linear: No activation, output is directly passed through.
    relu: Rectified Linear Unit, max(x, 0).
    sigmoid: Sigmoid function, output between 0 and 1.
    tanh: Hyperbolic tangent, output between -1 and 1.
    softmax: Normalizes output to a probability distribution.
    elu: Exponential Linear Unit.
    selu: Scaled Exponential Linear Unit.

Recurrent Activation:
    sigmoid: Commonly used for gates in LSTM.
    hard_sigmoid: A faster, less computationally expensive version of sigmoid.
    tanh: Can be used, but sigmoid is more typical for gates.
"""
datasets = [dataset_dicts[1], # 0
            dataset_dicts[2], # 1
           ]

lstm_units=[[(45, ActivationOutput.selu.name),   # 0
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.sigmoid.name),
             (45, ActivationOutput.elu.name)
             ],
            [(45, ActivationOutput.selu.name),   # 1
             (45, ActivationOutput.selu.name)
             ],
            [(45, ActivationOutput.selu.name),   # 2
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.sigmoid.name),
             (45, ActivationOutput.sigmoid.name),
             (45, ActivationOutput.elu.name)
             ],
            [(45, ActivationOutput.tanh.name),   # 3
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name)
             ],
            [(45, ActivationOutput.tanh.name),   # 4
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name),
             ],
            [(45, ActivationOutput.tanh.name)    # 5
             ],
            ]
dense_units = [[(45, ActivationOutput.selu.name),   # 0
                (45, ActivationOutput.elu.name),
                (45, ActivationOutput.elu.name),],
               [(45, ActivationOutput.selu.name),], # 1
               [(45, ActivationOutput.selu.name),   # 2
                (45, ActivationOutput.elu.name),
                (45, ActivationOutput.elu.name),],
               [(45, ActivationOutput.tanh.name),   # 3
               ],
               []                                   # 4
              ]
sel_date = datetime(2025, 5, 24, 20, 35)
sel_date_ts = (sel_date.timestamp() / 10000000)
steps = [45, 45,]
metrics = [["accuracy"]]
dropout = [0, 0]
learning_rate = [0.01, 0.05]
last_lstm_return_sequences = [False]
loss = ["binary_crossentropy", "mse"]
output_dense_activation = [ActivationOutput.elu.name, #0
                           ActivationOutput.selu.name, #1
                           ActivationOutput.sigmoid.name, #2
                           ActivationOutput.tanh.name, #3
                           ActivationOutput.softmax.name, #4
                           ActivationOutput.relu.name, #5
                           ActivationOutput.linear.name #6
                          ]
epochs = [10, #0
          20, #1
          25, #2
          50, #3
          100] #4

rand_seed=[sel_date_ts, datetime.now().timestamp(), 0]


lstm_args = {2: {"model":{"learning_rate": learning_rate[0],
                          "dropout": dropout[0],
                          "steps": steps[0], # last output elements count
                          "metrics": metrics[0],
                          "last_lstm_return_sequences": last_lstm_return_sequences[0],
                          "lstm_units": lstm_units[1],
                          "dense_units": dense_units[1],
                          "output_dense_activation": output_dense_activation[0],
                          "loss": loss[0],
                          "rand_seed": rand_seed[0]
                          },
                 "train": {"epochs": epochs[1],
                           "is_shuffle": False,
                           "batch": 1,
                           "steps_per_epoch": 1
                           },
                 "dataset": datasets[0]
                 },
             6: {"model":{"learning_rate": learning_rate[0],
                          "dropout": dropout[1],
                          "steps": steps[0], # last output elements count
                          "metrics": metrics[0],
                          "last_lstm_return_sequences": last_lstm_return_sequences[0],
                          "lstm_units": lstm_units[5],
                          "dense_units": dense_units[4],
                          "output_dense_activation": output_dense_activation[3],
                          "loss": loss[1],
                          "return_state": False,
                          "lstm_model": "Bidirectional",
                          "rand_seed": rand_seed[0] # rand_seed[0]
                          },
                 "train": {"epochs": epochs[3],
                           "is_shuffle": False,
                           "batch": 3,
                           "steps_per_epoch": 90 #100
                           },
                 "dataset": datasets[0]
                 }
             }


models = [None for i in range(MAX_MODEL_CNT)]

matched_cnts = {}
selected_fives = {}
matched_list = {}
predicted_all = {}

print(f'completed to set evn for all models. {datetime.now()}')
# Out:
# completed to set evn for all models. 2025-05-28 00:57:19.233217

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 20

for version in range(model_version_from, model_version_end+1):
    args = {'test_id': 'P4_4_3_1',
        'version': version,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
       }
    build_and_predict(args=args, lstm_args=lstm_args, sleep_time=3, verbose=False)
    time.sleep(10)

    usage = resource.getrusage(resource.RUSAGE_SELF)
    print(f"CPU 시간: {usage.ru_utime} 초")
    print(f"메모리 사용량: {usage.ru_maxrss} KB")
    clear_output_this_02 = False
    if clear_output_this_02:
        from IPython.display import clear_output
        clear_output() # Clears the output
# Out:
# ********************
# working model_version = 1  2025-05-28 00:57:54.642309
# ********************
# start to train all models. 2025-05-28 00:57:54.642859
# 2's training. status=start 2025-05-28 00:57:54.642882
# 2's training. status=end 2025-05-28 00:58:13.725173
# 6's training. status=start 2025-05-28 00:58:13.725270
# 6's training. status=end 2025-05-28 00:58:31.744750
# completed to train all models. 2025-05-28 00:58:31.744849
# train to create model(1). 2025-05-28 00:58:34.744931
# CPU 시간: 56.789277 초
# 메모리 사용량: 735568 KB
# ********************
# working model_version = 2  2025-05-28 00:58:55.679310
# ********************
# start to train all models. 2025-05-28 00:58:55.679348
# 2's training. status=start 2025-05-28 00:58:55.679365
# 2's training. status=end 2025-05-28 00:59:15.874563
# 6's training. status=start 2025-05-28 00:59:15.874857
# 6's training. status=end 2025-05-28 00:59:33.673902
# completed to train all models. 2025-05-28 00:59:33.674001
# train to create model(2). 2025-05-28 00:59:36.674088
# CPU 시간: 109.275389 초
# 메모리 사용량: 814416 KB
# ********************
# working model_version = 3  2025-05-28 00:59:56.616346
# ********************
# start to train all models. 2025-05-28 00:59:56.616383
# 2's training. status=start 2025-05-28 00:59:56.616399
# 2's training. status=end 2025-05-28 01:00:17.453413
# 6's training. status=start 2025-05-28 01:00:17.453512
# 6's training. status=end 2025-05-28 01:00:35.275699
# completed to train all models. 2025-05-28 01:00:35.275799
# train to create model(3). 2025-05-28 01:00:38.275889
# CPU 시간: 162.585588 초
# 메모리 사용량: 818752 KB
# ********************
# working model_version = 4  2025-05-28 01:00:59.927885
# ********************
# start to train all models. 2025-05-28 01:00:59.927922
# 2's training. status=start 2025-05-28 01:00:59.927939
# 2's training. status=end 2025-05-28 01:01:19.705980
# 6's training. status=start 2025-05-28 01:01:19.706076
# 6's training. status=end 2025-05-28 01:01:38.154660
# completed to train all models. 2025-05-28 01:01:38.154763
# train to create model(4). 2025-05-28 01:01:41.154849
# CPU 시간: 215.904996 초
# 메모리 사용량: 858848 KB
# ********************
# working model_version = 5  2025-05-28 01:02:01.170752
# ********************
# start to train all models. 2025-05-28 01:02:01.170790
# 2's training. status=start 2025-05-28 01:02:01.170806
# 2's training. status=end 2025-05-28 01:02:21.086147
# 6's training. status=start 2025-05-28 01:02:21.086245
# 6's training. status=end 2025-05-28 01:02:38.961402
# completed to train all models. 2025-05-28 01:02:38.961502
# train to create model(5). 2025-05-28 01:02:41.961581
# CPU 시간: 268.974004 초
# 메모리 사용량: 936560 KB
# ********************
# working model_version = 6  2025-05-28 01:03:01.939294
# ********************
# start to train all models. 2025-05-28 01:03:01.939330
# 2's training. status=start 2025-05-28 01:03:01.939346
# 2's training. status=end 2025-05-28 01:03:21.374509
# 6's training. status=start 2025-05-28 01:03:21.374605
# 6's training. status=end 2025-05-28 01:03:40.035121
# completed to train all models. 2025-05-28 01:03:40.035221
# train to create model(6). 2025-05-28 01:03:43.035310
# CPU 시간: 322.856979 초
# 메모리 사용량: 975376 KB
# ********************
# working model_version = 7  2025-05-28 01:04:03.100799
# ********************
# start to train all models. 2025-05-28 01:04:03.100836
# 2's training. status=start 2025-05-28 01:04:03.100853
# 2's training. status=end 2025-05-28 01:04:22.540423
# 6's training. status=start 2025-05-28 01:04:22.540523
# 6's training. status=end 2025-05-28 01:04:40.412239
# completed to train all models. 2025-05-28 01:04:40.412338
# train to create model(7). 2025-05-28 01:04:43.412420
# CPU 시간: 375.825167 초
# 메모리 사용량: 1018080 KB
# ********************
# working model_version = 8  2025-05-28 01:05:04.741014
# ********************
# start to train all models. 2025-05-28 01:05:04.741049
# 2's training. status=start 2025-05-28 01:05:04.741064
# 2's training. status=end 2025-05-28 01:05:25.964938
# 6's training. status=start 2025-05-28 01:05:25.965037
# 6's training. status=end 2025-05-28 01:05:49.396609
# completed to train all models. 2025-05-28 01:05:49.396739
# train to create model(8). 2025-05-28 01:05:52.396835
# CPU 시간: 429.58859 초
# 메모리 사용량: 1057744 KB
# ********************
# working model_version = 9  2025-05-28 01:06:12.578453
# ********************
# start to train all models. 2025-05-28 01:06:12.578489
# 2's training. status=start 2025-05-28 01:06:12.578505
# 2's training. status=end 2025-05-28 01:06:33.081690
# 6's training. status=start 2025-05-28 01:06:33.081788
# 6's training. status=end 2025-05-28 01:06:51.028721
# completed to train all models. 2025-05-28 01:06:51.028824
# train to create model(9). 2025-05-28 01:06:54.028917
# CPU 시간: 482.709203 초
# 메모리 사용량: 1099952 KB
# ********************
# working model_version = 10  2025-05-28 01:07:14.043185
# ********************
# start to train all models. 2025-05-28 01:07:14.043221
# 2's training. status=start 2025-05-28 01:07:14.043236
# 2's training. status=end 2025-05-28 01:07:33.876255
# 6's training. status=start 2025-05-28 01:07:33.876352
# 6's training. status=end 2025-05-28 01:07:51.881297
# completed to train all models. 2025-05-28 01:07:51.881393
# train to create model(10). 2025-05-28 01:07:54.881476
# CPU 시간: 535.753585 초
# 메모리 사용량: 1178160 KB
# ********************
# working model_version = 11  2025-05-28 01:08:14.841652
# ********************
# start to train all models. 2025-05-28 01:08:14.841690
# 2's training. status=start 2025-05-28 01:08:14.841707
# 2's training. status=end 2025-05-28 01:08:36.688850
# 6's training. status=start 2025-05-28 01:08:36.688949
# 6's training. status=end 2025-05-28 01:08:59.489536
# completed to train all models. 2025-05-28 01:08:59.489670
# train to create model(11). 2025-05-28 01:09:02.489759
# CPU 시간: 590.210987 초
# 메모리 사용량: 1178672 KB
# ********************
# working model_version = 12  2025-05-28 01:09:22.518474
# ********************
# start to train all models. 2025-05-28 01:09:22.518510
# 2's training. status=start 2025-05-28 01:09:22.518526
# 2's training. status=end 2025-05-28 01:09:42.377314
# 6's training. status=start 2025-05-28 01:09:42.377410
# 6's training. status=end 2025-05-28 01:10:00.311377
# completed to train all models. 2025-05-28 01:10:00.311476
# train to create model(12). 2025-05-28 01:10:03.311561
# CPU 시간: 643.069595 초
# 메모리 사용량: 1222960 KB
# ********************
# working model_version = 13  2025-05-28 01:10:23.615674
# ********************
# start to train all models. 2025-05-28 01:10:23.615710
# 2's training. status=start 2025-05-28 01:10:23.615728
# 2's training. status=end 2025-05-28 01:10:44.787805
# 6's training. status=start 2025-05-28 01:10:44.787906
# 6's training. status=end 2025-05-28 01:11:02.552009
# completed to train all models. 2025-05-28 01:11:02.552107
# train to create model(13). 2025-05-28 01:11:05.552189
# CPU 시간: 696.994672 초
# 메모리 사용량: 1293744 KB
# ********************
# working model_version = 14  2025-05-28 01:11:26.820833
# ********************
# start to train all models. 2025-05-28 01:11:26.820869
# 2's training. status=start 2025-05-28 01:11:26.820885
# 2's training. status=end 2025-05-28 01:11:47.289224
# 6's training. status=start 2025-05-28 01:11:47.289334
# 6's training. status=end 2025-05-28 01:12:05.306077
# completed to train all models. 2025-05-28 01:12:05.306173
# train to create model(14). 2025-05-28 01:12:08.306256
# CPU 시간: 750.173054 초
# 메모리 사용량: 1303472 KB
# ********************
# working model_version = 15  2025-05-28 01:12:28.333197
# ********************
# start to train all models. 2025-05-28 01:12:28.333233
# 2's training. status=start 2025-05-28 01:12:28.333250
# 2's training. status=end 2025-05-28 01:12:48.236578
# 6's training. status=start 2025-05-28 01:12:48.236679
# 6's training. status=end 2025-05-28 01:13:06.205567
# completed to train all models. 2025-05-28 01:13:06.205683
# train to create model(15). 2025-05-28 01:13:09.205763
# CPU 시간: 803.134323 초
# 메모리 사용량: 1381504 KB
# ********************
# working model_version = 16  2025-05-28 01:13:29.208996
# ********************
# start to train all models. 2025-05-28 01:13:29.209033
# 2's training. status=start 2025-05-28 01:13:29.209049
# 2's training. status=end 2025-05-28 01:13:49.010173
# 6's training. status=start 2025-05-28 01:13:49.010276
# 6's training. status=end 2025-05-28 01:14:06.983549
# completed to train all models. 2025-05-28 01:14:06.983649
# train to create model(16). 2025-05-28 01:14:09.983734
# CPU 시간: 856.148292 초
# 메모리 사용량: 1461328 KB
# ********************
# working model_version = 17  2025-05-28 01:14:30.000520
# ********************
# start to train all models. 2025-05-28 01:14:30.000560
# 2's training. status=start 2025-05-28 01:14:30.000577
# 2's training. status=end 2025-05-28 01:14:50.883015
# 6's training. status=start 2025-05-28 01:14:50.883114
# 6's training. status=end 2025-05-28 01:15:08.923180
# completed to train all models. 2025-05-28 01:15:08.923291
# train to create model(17). 2025-05-28 01:15:11.923375
# CPU 시간: 910.772944 초
# 메모리 사용량: 1462352 KB
# ********************
# working model_version = 18  2025-05-28 01:15:32.001661
# ********************
# start to train all models. 2025-05-28 01:15:32.001699
# 2's training. status=start 2025-05-28 01:15:32.001714
# 2's training. status=end 2025-05-28 01:15:52.010857
# 6's training. status=start 2025-05-28 01:15:52.010951
# 6's training. status=end 2025-05-28 01:16:10.175757
# completed to train all models. 2025-05-28 01:16:10.175851
# train to create model(18). 2025-05-28 01:16:13.175932
# CPU 시간: 964.162697 초
# 메모리 사용량: 1469872 KB
# ********************
# working model_version = 19  2025-05-28 01:16:33.221658
# ********************
# start to train all models. 2025-05-28 01:16:33.221695
# 2's training. status=start 2025-05-28 01:16:33.221710
# 2's training. status=end 2025-05-28 01:16:54.157345
# 6's training. status=start 2025-05-28 01:16:54.157446
# 6's training. status=end 2025-05-28 01:17:12.100139
# completed to train all models. 2025-05-28 01:17:12.100235
# train to create model(19). 2025-05-28 01:17:15.100319
# CPU 시간: 1017.527948 초
# 메모리 사용량: 1545360 KB
# ********************
# working model_version = 20  2025-05-28 01:17:37.518243
# ********************
# start to train all models. 2025-05-28 01:17:37.518278
# 2's training. status=start 2025-05-28 01:17:37.518294
# 2's training. status=end 2025-05-28 01:17:57.014650
# 6's training. status=start 2025-05-28 01:17:57.014749
# 6's training. status=end 2025-05-28 01:18:14.976943
# completed to train all models. 2025-05-28 01:18:14.977044
# train to create model(20). 2025-05-28 01:18:17.977122
# CPU 시간: 1072.440364 초
# 메모리 사용량: 1616352 KB

# %%
view_model_info = False
if view_model_info:
    for i in range(MAX_MODEL_CNT):
        print(models[i][0].model.summary())

# %%
# all : save model
for model in models:
    if model is not None:
        model[0].save()
