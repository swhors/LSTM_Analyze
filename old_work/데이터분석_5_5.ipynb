# %% [markdown]
# # DB에서 매트릭을 읽어서 그래프 그리기 (v4.5.5)
#
# <p>won@aimmo.co.kr(swhors@naver.com)</p>

# %%
# !pip install pillow

# %%
def restart_kernel():
    # Restart the kernet after libraries are loaded.
    import IPython
    from datetime import datetime
    print(f'restart kernel... {datetime.now()}')
    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

restart_kernel()
# Out:
# restart kernel... 2025-06-05 17:17:54.875257

# %%
import os
import sys
from datetime import datetime
cwd = os.getcwd()
sys.path.append(cwd)
print(sys.path)

print(f'load_library step#1 {datetime.now()}')

from datetime import datetime
from lib.metrics_loader import load_data_by_version
from lib.graph_util import draw_data_graph
from lib.graph_util import draw_data_graph_v2
from lib.graph_util import load_image
from lib.graph_util import draw_graph_with_metric
from lib.graph_util import load_all_image
from lib.metric_analyze import load_data, draw_metric
from lib.metric_analyze import draw_graph, draw_graph_by_version
from lib.metric_analyze import load_data_matched_freq_v2
from lib.metric_analyze import load_all_matched_info
from lib.metric_analyze import draw_graph_matched_size
from lib.metric_analyze import get_matched_case_by_round
print(f'load_library step#2 {datetime.now()}')

model_ids = [14]
# Out:
# ['/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/home/simpson/.local/lib/python3.8/site-packages', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/home/simpson/jupyter-workspace/LSTM_Analyze']
# load_library step#1 2025-06-05 23:54:06.071035
# load_library step#2 2025-06-05 23:54:06.632079

# %% [markdown]
# #### Test P4_5_5_1

# %%
test_id = 'P4_5_5_1'
draw_graph(test_id=test_id,
           model_ids=model_ids,
           del_res=True,
           width=60, height=30)
# Out:
# read_db.0_1 (model_id=14)
# read_db.10 complete (model_id=14)
# CPU 시간: 1.582976 초
# 메모리 사용량: 230944 KB

# %%
test_id = 'P4_5_5_1'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14, test_id=P4_5_5_1)
# read_db.10 complete (model_id=14)
# CPU 시간: 1.744729 초
# 메모리 사용량: 230944 KB

# %% [markdown]
# #### Test P4_5_5_2

# %%
test_id = 'P4_5_5_2'
draw_graph(test_id=test_id,
           model_ids=model_ids,
           del_res=True,
           width=100, height=100)
# Out:
# read_db.0_1 (model_id=14)
# read_db.10 complete (model_id=14)
# CPU 시간: 1.8927 초
# 메모리 사용량: 230944 KB

# %%
test_id = 'P4_5_5_2'
draw_graph_by_version(test_id=test_id,
                      model_ids=model_ids,
                      del_res=True,
                      width=100, height=100)
# Out:
# read_db.0_1 (model_id=14, test_id=P4_5_5_2)
# read_db.10 complete (model_id=14)
# CPU 시간: 2.038162 초
# 메모리 사용량: 230944 KB

# %% [markdown]
# #### Test P4_5_5_2 #2

# %%
test_id="P4_5_5_2"
draw_graph_matched_size(test_ids=[test_id], model_ids=model_ids, from_pos=0, to_pos=1000)
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_5_2)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)

# %% [markdown]
# #### Test P4_5_5_3 #2

# %%
test_id="P4_5_5_3"
draw_graph_matched_size(test_ids=[test_id], model_ids=model_ids, from_pos=0, to_pos=1000)
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_5_3)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)

# %% [markdown]
# #### Test P4_5_5_4 #2

# %%
test_id="P4_5_5_4"
draw_graph_matched_size(test_ids=[test_id], model_ids=model_ids, from_pos=0, to_pos=1000)
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_5_4)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)

# %%
test_ids=['P4_5_5_2',
          'P4_5_5_3',
          'P4_5_5_4',
          'P4_5_5_5',
          'P4_5_5_6',
          'P4_5_5_7',
          'P4_5_5_8']
draw_graph_matched_size(test_ids=test_ids, model_ids=model_ids, from_pos=0, to_pos=1001)
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_5_2)
# load_all_matched.read_db.01_02 (model_id=<built-in function id>, test_id=P4_5_5_3)
# load_all_matched.read_db.01_03 (model_id=<built-in function id>, test_id=P4_5_5_4)
# load_all_matched.read_db.01_04 (model_id=<built-in function id>, test_id=P4_5_5_5)
# load_all_matched.read_db.01_05 (model_id=<built-in function id>, test_id=P4_5_5_6)
# load_all_matched.read_db.01_06 (model_id=<built-in function id>, test_id=P4_5_5_7)
# load_all_matched.read_db.01_07 (model_id=<built-in function id>, test_id=P4_5_5_8)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)

# %%
test_ids=['P4_5_5_2',
          'P4_5_5_3',
          'P4_5_5_4',
          'P4_5_5_5',
          'P4_5_5_6',
          'P4_5_5_7',
          'P4_5_5_8']
draw_graph_matched_size(test_ids=test_ids, model_ids=model_ids, from_pos=0, to_pos=1001)
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_5_2)
# load_all_matched.read_db.01_02 (model_id=<built-in function id>, test_id=P4_5_5_3)
# load_all_matched.read_db.01_03 (model_id=<built-in function id>, test_id=P4_5_5_4)
# load_all_matched.read_db.01_04 (model_id=<built-in function id>, test_id=P4_5_5_5)
# load_all_matched.read_db.01_05 (model_id=<built-in function id>, test_id=P4_5_5_6)
# load_all_matched.read_db.01_06 (model_id=<built-in function id>, test_id=P4_5_5_7)
# load_all_matched.read_db.01_07 (model_id=<built-in function id>, test_id=P4_5_5_8)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)

# %%
test_ids=['P4_5_5_2',
          'P4_5_5_3',
          'P4_5_5_4',
          'P4_5_5_5',
          'P4_5_5_6',
          'P4_5_5_7',
          'P4_5_5_8']
results2 = get_matched_case_by_round(test_ids=test_ids, model_ids=model_ids, min_val=2)
sorted_results2 = sorted(results2.items())
results3 = get_matched_case_by_round(test_ids=test_ids, model_ids=model_ids, min_val=3)
sorted_results3 = sorted(results3.items())
print(f'Now = {datetime.now()}')
# Out:
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_5_2)
# load_all_matched.read_db.01_02 (model_id=<built-in function id>, test_id=P4_5_5_3)
# load_all_matched.read_db.01_03 (model_id=<built-in function id>, test_id=P4_5_5_4)
# load_all_matched.read_db.01_04 (model_id=<built-in function id>, test_id=P4_5_5_5)
# load_all_matched.read_db.01_05 (model_id=<built-in function id>, test_id=P4_5_5_6)
# load_all_matched.read_db.01_06 (model_id=<built-in function id>, test_id=P4_5_5_7)
# load_all_matched.read_db.01_07 (model_id=<built-in function id>, test_id=P4_5_5_8)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)
# load_all_matched.read_db.01_01 (model_id=<built-in function id>, test_id=P4_5_5_2)
# load_all_matched.read_db.01_02 (model_id=<built-in function id>, test_id=P4_5_5_3)
# load_all_matched.read_db.01_03 (model_id=<built-in function id>, test_id=P4_5_5_4)
# load_all_matched.read_db.01_04 (model_id=<built-in function id>, test_id=P4_5_5_5)
# load_all_matched.read_db.01_05 (model_id=<built-in function id>, test_id=P4_5_5_6)
# load_all_matched.read_db.01_06 (model_id=<built-in function id>, test_id=P4_5_5_7)
# load_all_matched.read_db.01_07 (model_id=<built-in function id>, test_id=P4_5_5_8)
# load_data_matched_freq_v2.read_db.10 complete (model_id=<built-in function id>)
# Now = 2025-06-05 23:54:19.749999

# %%
cnt = 0
for result in sorted_results2:
    if len(result[1]) >= 4:
        print(result)
        cnt += 1
print(f'total count = {cnt}')
# Out:
# (108, ['P4_5_5_5', 'P4_5_5_6', 'P4_5_5_7', 'P4_5_5_8'])
# (166, ['P4_5_5_3', 'P4_5_5_4', 'P4_5_5_6', 'P4_5_5_7'])
# (214, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_6', 'P4_5_5_8'])
# (232, ['P4_5_5_2', 'P4_5_5_4', 'P4_5_5_7', 'P4_5_5_8'])
# (269, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_5', 'P4_5_5_6'])
# (283, ['P4_5_5_2', 'P4_5_5_4', 'P4_5_5_5', 'P4_5_5_6'])
# (293, ['P4_5_5_3', 'P4_5_5_4', 'P4_5_5_6', 'P4_5_5_7'])
# (352, ['P4_5_5_2', 'P4_5_5_4', 'P4_5_5_5', 'P4_5_5_8'])
# (394, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_5', 'P4_5_5_7'])
# (410, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_4', 'P4_5_5_6', 'P4_5_5_8'])
# (415, ['P4_5_5_2', 'P4_5_5_4', 'P4_5_5_6', 'P4_5_5_8'])
# (452, ['P4_5_5_3', 'P4_5_5_4', 'P4_5_5_6', 'P4_5_5_8'])
# (498, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_5', 'P4_5_5_8'])
# (544, ['P4_5_5_2', 'P4_5_5_4', 'P4_5_5_5', 'P4_5_5_6', 'P4_5_5_7'])
# (562, ['P4_5_5_5', 'P4_5_5_6', 'P4_5_5_7', 'P4_5_5_8'])
# (626, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_7', 'P4_5_5_8'])
# (641, ['P4_5_5_3', 'P4_5_5_4', 'P4_5_5_7', 'P4_5_5_8'])
# (764, ['P4_5_5_3', 'P4_5_5_5', 'P4_5_5_7', 'P4_5_5_8'])
# (796, ['P4_5_5_3', 'P4_5_5_5', 'P4_5_5_6', 'P4_5_5_7'])
# (920, ['P4_5_5_2', 'P4_5_5_6', 'P4_5_5_7', 'P4_5_5_8'])
# (967, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_5', 'P4_5_5_6'])
# total count = 21

# %%
cnt = 0
for result in sorted_results3:
    if len(result[1]) > 1:
        print(result)
        cnt += 1
print(f'total count = {cnt}')
# Out:
# (85, ['P4_5_5_2', 'P4_5_5_6'])
# (108, ['P4_5_5_5', 'P4_5_5_8'])
# (157, ['P4_5_5_4', 'P4_5_5_6'])
# (269, ['P4_5_5_5', 'P4_5_5_6'])
# (359, ['P4_5_5_4', 'P4_5_5_6'])
# (386, ['P4_5_5_4', 'P4_5_5_6'])
# (522, ['P4_5_5_2', 'P4_5_5_8'])
# (552, ['P4_5_5_3', 'P4_5_5_6'])
# (618, ['P4_5_5_2', 'P4_5_5_4'])
# (657, ['P4_5_5_2', 'P4_5_5_6'])
# (779, ['P4_5_5_3', 'P4_5_5_7'])
# (870, ['P4_5_5_3', 'P4_5_5_5', 'P4_5_5_6'])
# total count = 12

# %% [markdown]
# - *876, 877, 879, 880*
# ```
# (85, ['P4_5_5_2', 'P4_5_5_6'])
# (157, ['P4_5_5_4', 'P4_5_5_6'])
# (359, ['P4_5_5_4', 'P4_5_5_6'])
# (386, ['P4_5_5_4', 'P4_5_5_6'])
# (522, ['P4_5_5_2', 'P4_5_5_8'])
# (552, ['P4_5_5_3', 'P4_5_5_6'])
# (618, ['P4_5_5_2', 'P4_5_5_4'])
# (657, ['P4_5_5_2', 'P4_5_5_6'])
# (779, ['P4_5_5_3', 'P4_5_5_7'])
#
# (108, ['P4_5_5_5'*, 'P4_5_5_6'*, 'P4_5_5_7', 'P4_5_5_8'])
# (269, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_5'*, 'P4_5_5_6'*])
# (410, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_4', 'P4_5_5_6', 'P4_5_5_8'])
# (544, ['P4_5_5_2', 'P4_5_5_4', 'P4_5_5_5', 'P4_5_5_6', 'P4_5_5_7'])
# (870, ['P4_5_5_3'*, 'P4_5_5_5'*, 'P4_5_5_6'*])
# ```

# %%
test_ids=['P4_5_5_2',
          'P4_5_5_3',
          'P4_5_5_4',
          'P4_5_5_5',
          'P4_5_5_6',
          'P4_5_5_7',
          'P4_5_5_8']
# results = load_data_matched_freq_v2(test_ids=test_ids, model_ids=model_ids)
# for result in results:
#     print(f'{"*"*30}\nid={result["id"]}')
#     print('   ** metric version:round')
#     sorted_keys = sorted(result['metric'])
#     for metric in sorted_keys:
#         if len(result['metric'][metric]) > 2:
#             print(metric,result['metric'][metric])

# %% [markdown]
# ```last
# (573, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_4', 'P4_5_5_5', 'P4_5_5_7', 'P4_5_5_8'])
# (574, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_4', 'P4_5_5_5', 'P4_5_5_6', 'P4_5_5_7', 'P4_5_5_8'])
# (611, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_4', 'P4_5_5_6', 'P4_5_5_7', 'P4_5_5_8'])
# (612, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_4', 'P4_5_5_5', 'P4_5_5_6', 'P4_5_5_7', 'P4_5_5_8'])
# (613, ['P4_5_5_2', 'P4_5_5_3', 'P4_5_5_4', 'P4_5_5_5', 'P4_5_5_6', 'P4_5_5_7', 'P4_5_5_8'])
# ```
#
# ```last 01
#   5| 4, 9,26,28,42,44|
#  35|17,22,23,33,40,43|17
# 612| 3,30,31,33,39,43|39
# 613| 3, 6,27,38,39,44|39
# 614| 5, 7,12,14,29,37|14
# ```
