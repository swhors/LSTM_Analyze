# %% [markdown]
# # Prediction with LSTM model (v.03)
# <p style='text-align: right;'>with selectd4.csv</p>
#
# * history
#   * 2025/05/23 PM06:02 : 3번째 모델의 3번째 데이터를 사용

# %%
# !pip install scikit-learn
# !pip install tensorflow
from datetime import datetime
print(f'restart kernel... {datetime.now()}')

# %%
def restart_kernel():
    # Restart the kernet after libraries are loaded.
    import IPython
    from datetime import datetime
    print(f'restart kernel... {datetime.now()}')
    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

restart_kernel()
# Out:
# restart kernel... 2025-05-27 18:58:19.143585

# %%
# load dependacies
import os
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from matplotlib import pyplot
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Input

from lib.globalvar import *
from lib.data_loader import DataLoader
from lib.model1 import PredictLSTM1
from lib.model2 import PredictLSTM2
from lib.model3 import PredictLSTM3
from lib.model4 import PredictLSTM4

import argparse
import matplotlib.pyplot as plt

from lib.util_pred import print_data
from lib.util_pred import flat_data_with_sum, flat_data, get_frequency
from lib.util_pred import save_model, import_mode
from lib.util_pred import get_random_in_list
from lib.util_pred import print_data_with_sort
from lib.util_pred import get_sorted_n_values
from lib.util_pred import dict_key_count
from lib.util_pred import print_list
from lib.util_pred import print_dict_list
from lib.util_pred import print_title
from lib.util_pred import listinlist_2_strinlist
from lib.util_pred import change_matched_info
from lib.json_util import write_json

from lib.small_predict import predict_small, print_predict_small

from lib.activation import ActivationOutput, RecurrentActivation
from datetime import datetime

""" db """
from lib.db_operate import conn_db, close_db
from lib.db_operate import init_metric, init_models
from lib.db_operate import select_metric, delete_all_metric
from lib.db_operate import insert_metric
from lib.db_operate import select_model, insert_model

from lib.operate import create_model, create_model_v1, get_predicted, create_model_v2

print(f"imported library. ({datetime.now()})")
# Out:
# imported library. (2025-05-27 21:52:51.321668)

# %%
##
## 모델링 환경 설정
##
window=1 # default = 1 , help = "time stamps"
data_dir='./csv/selectd4.csv'
    
mode='predict' # help = "back-test or predict")

mode2='sampling' # help = "greed or sampling")
verb='verbose' # help = "verbose or not_verb")
    
trial=20 # help = "how much trials to generate")
training_length=0.95 # default = 0.9)
epoch=20 # default = 3
batch=1 # default = 1
model_type='lstm4' # help = "lstm1 or lstm2")
hid_dim = 50
from_pos = 0
last = [[1, 5, 18, 20, 30, 35],
        [7, 9, 24, 40, 42, 44],
        [3, 6, 7, 11, 12, 17],
        [3, 13, 28, 34, 38, 42],
        [5, 12, 24, 29, 32, 42]]
print(f"finished to set environemnt. ({datetime.now()})")
MAX_MODEL_CNT = 3

write_to_db = True
# Out:
# finished to set environemnt. (2025-05-27 21:52:51.328188)

# %%
import tensorflow as tf
print(f'{tf.version}')
# Out:
# <module 'tensorflow._api.v2.version' from '/home/swhors/jupyter-workspace/finance/venv/lib/python3.11/site-packages/tensorflow/_api/v2/version/__init__.py'>

# %%
dataset_dicts = {
    1: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=0,
                  verbose=False
                  ),
    2: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=300,
                  verbose=False
                  )
    }
#print(f'test_X = {dataset_dicts[1].test_X}')
print(f'completed to load data. {datetime.now()}')
# Out:
# completed to load data. 2025-05-27 21:52:51.392337

# %%
###########
## layers
## LSTM Neural 계층 선언
###########
"""
Activation (Output):
    linear: No activation, output is directly passed through.
    relu: Rectified Linear Unit, max(x, 0).
    sigmoid: Sigmoid function, output between 0 and 1.
    tanh: Hyperbolic tangent, output between -1 and 1.
    softmax: Normalizes output to a probability distribution.
    elu: Exponential Linear Unit.
    selu: Scaled Exponential Linear Unit.

Recurrent Activation:
    sigmoid: Commonly used for gates in LSTM.
    hard_sigmoid: A faster, less computationally expensive version of sigmoid.
    tanh: Can be used, but sigmoid is more typical for gates.
"""
datasets = [dataset_dicts[1], # 0
            dataset_dicts[2], # 1
           ]

lstm_units=[[(45, ActivationOutput.selu.name),   # 0
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.sigmoid.name),
             (45, ActivationOutput.elu.name)
             ],
            [(45, ActivationOutput.selu.name),   # 1
             (45, ActivationOutput.selu.name)
             ],
            [(45, ActivationOutput.selu.name),   # 2
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.selu.name),
             (45, ActivationOutput.sigmoid.name),
             (45, ActivationOutput.sigmoid.name),
             (45, ActivationOutput.elu.name)
             ],
            [(45, ActivationOutput.tanh.name),   # 3
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name)
             ],
            [(45, ActivationOutput.tanh.name),   # 4
             (45, ActivationOutput.tanh.name),
             (45, ActivationOutput.tanh.name),
             ],
            [(45, ActivationOutput.tanh.name)    # 5
             ],
            ]
dense_units = [[(45, ActivationOutput.selu.name),   # 0
                (45, ActivationOutput.elu.name),
                (45, ActivationOutput.elu.name),],
               [(45, ActivationOutput.selu.name),], # 1
               [(45, ActivationOutput.selu.name),   # 2
                (45, ActivationOutput.elu.name),
                (45, ActivationOutput.elu.name),],
               [(45, ActivationOutput.tanh.name),   # 3
               ],
               []                                   # 4
              ]
sel_date = datetime(2025, 5, 24, 20, 35)
sel_date_ts = (sel_date.timestamp() / 10000000)
steps = [45, 45,]
metrics = [["accuracy"]]
dropout = [0, 0]
learning_rate = [0.01, 0.05]
last_lstm_return_sequences = [False]
loss = ["binary_crossentropy", "mse"]
output_dense_activation = [ActivationOutput.elu.name, #0
                           ActivationOutput.selu.name, #1
                           ActivationOutput.sigmoid.name, #2
                           ActivationOutput.tanh.name, #3
                           ActivationOutput.softmax.name, #4
                           ActivationOutput.relu.name, #5
                           ActivationOutput.linear.name #6
                          ]
epochs = [10, #0
          20, #1
          25, #2
          50, #3
          100] #4

rand_seed=[sel_date_ts, datetime.now().timestamp(), 0]


lstm_args = {1: {"model":{"learning_rate": learning_rate[0],
                          "dropout": dropout[0],
                          "steps": steps[0], # last output elements count
                          "metrics": metrics[0],
                          "last_lstm_return_sequences": last_lstm_return_sequences[0],
                          "lstm_units": lstm_units[1],
                          "dense_units": dense_units[1],
                          "output_dense_activation": output_dense_activation[0],
                          "loss": loss[0],
                          "rand_seed": rand_seed[0]
                          },
                 "train": {"epochs": epochs[1],
                           "is_shuffle": False,
                           "batch": 1,
                           "steps_per_epoch": 1
                           },
                 "dataset": datasets[0]
                 },
             2: {"model":{"learning_rate": learning_rate[0],
                          "dropout": dropout[1],
                          "steps": steps[0], # last output elements count
                          "metrics": metrics[0],
                          "last_lstm_return_sequences": last_lstm_return_sequences[0],
                          "lstm_units": lstm_units[5],
                          "dense_units": dense_units[4],
                          "output_dense_activation": output_dense_activation[3],
                          "loss": loss[1],
                          "return_state": False,
                          "lstm_model": "Bidirectional",
                          "rand_seed": rand_seed[0] # rand_seed[0]
                          },
                 "train": {"epochs": epochs[3],
                           "is_shuffle": False,
                           "batch": 3,
                           "steps_per_epoch": 90 #100
                           },
                 "dataset": datasets[0]
                 }
             }


models = [None for i in range(MAX_MODEL_CNT)]

matched_cnts = {}
selected_fives = {}
matched_list = {}
predicted_all = {}

print(f'completed to set evn for all models. {datetime.now()}')
# Out:
# completed to set evn for all models. 2025-05-27 21:52:51.407892

# %%
def save_model(test_id, version, models, verbose=False):
    from lib.db_operate import insert_model
    import pickle
    conn = conn_db('./db/metrics.db')
    init_models(conn)
    model_id = 1
    date = datetime.now()
    for model in models:
        model_bin = pickle.dumps(model[0].model)
        insert_model(conn=conn,
                     test_id=test_id,
                     version=version,
                     model_id=model_id,
                     date=date,
                     model=model_bin,
                     verbose=verbose
                    )
        model_id += 1
    close_db(conn)

def gen_multi_model(test_id, lstm_args, version, max_model_cnt, verbose=False):
    """ gen_multi_model """
    models = []
    print(f'start to train all models. {datetime.now()}')
    # for i in range(max_model_cnt):
    for i in lstm_args.keys():
        print(f'{i+1}\'s training. status=start {datetime.now()}')
        model = create_model_v2(id=i,
                                model_type="lstm4",
                                lstm_info=lstm_args[i],
                                dataset=lstm_args[i]["dataset"],
                                verbose=verbose
                                )
        models.append((model, lstm_args[i]))
        print(f'{i+1}\'s training. status=end {datetime.now()}')
    print(f'completed to train all models. {datetime.now()}')
    return models

# %%
def build_and_predict(args: dict, lstm_args, verbose=False):
    if 'test_id' not in args:
        return
    test_id = args['test_id']
    version = args['version']
    max_model_cnt = args['max_model_cnt']
    write_to_db = args['write_to_db']
    last = args['last']
    db_file_name = args['db_file_name']
    if 'mode2' not in args:
        mode2 = "sampling"
    else:
        mode2 = args['mode2']
    if 'gen_num' not in args:
        gen_num = 5
    else:
        gen_num = args['gen_num']

    if 'round_limit' not in args:
        round_limit = 40
    else:
        round_limit = args['round_limit']
    print(f'working model_version = {version}')
    print(f'open model version file {datetime.now()}')
    models = gen_multi_model(test_id=test_id,
                             lstm_args=lstm_args,
                             version=version,
                             max_model_cnt=max_model_cnt,
                             verbose=verbose
                            )
    print(f'check to create model({version}). {datetime.now()}')
    predict_small(test_id=test_id,
                  version=version,
                  models=models,
                  write_to_db=write_to_db,
                  round_limit=round_limit,
                  last=last,
                  gen_num=gen_num,
                  db_file_name=db_file_name,
                  mode2=mode2,
                  max_model_cnt=len(models),
                  verbose=verbose
                  )
    save_model(test_id=test_id, version=version, models=models, verbose=False)

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#

model_version_limit = 20
max_model_cnt = 2 # 위에 정리 된 모델의 수
for version in range(1, model_version_limit+1):
    args = {'test_id': 'P4_4_4',
        'version': version,
        'max_model_cnt': max_model_cnt,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
       }
    build_and_predict(args=args, lstm_args=lstm_args, verbose=False)
    import time
    time.sleep(1)
    import resource
    usage = resource.getrusage(resource.RUSAGE_SELF)
    print(f"CPU 시간: {usage.ru_utime} 초")
    print(f"메모리 사용량: {usage.ru_maxrss} KB")
    # clear_output_this_02 = True
    # if clear_output_this_02:
    #     from IPython.display import clear_output
    #     clear_output() # Clears the output
# Out:
# working model_version = 1
# open model version file 2025-05-27 21:53:07.922710
# start to train all models. 2025-05-27 21:53:07.922740
# 2's training. status=start 2025-05-27 21:53:07.922759
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 21:53:27.590034
# 3's training. status=start 2025-05-27 21:53:27.590131
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_1, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 21:53:45.502599
# completed to train all models. 2025-05-27 21:53:45.502697
# check to create model(1). 2025-05-27 21:53:45.502711
# CPU 시간: 57.081015 초
# 메모리 사용량: 732976 KB
# working model_version = 2
# open model version file 2025-05-27 21:53:56.473199
# start to train all models. 2025-05-27 21:53:56.473224
# 2's training. status=start 2025-05-27 21:53:56.473235
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_2, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 21:54:16.190878
# 3's training. status=start 2025-05-27 21:54:16.190974
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_3, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 21:54:34.084928
# completed to train all models. 2025-05-27 21:54:34.085028
# check to create model(2). 2025-05-27 21:54:34.085040
# CPU 시간: 109.876259 초
# 메모리 사용량: 810304 KB
# working model_version = 3
# open model version file 2025-05-27 21:54:45.040337
# start to train all models. 2025-05-27 21:54:45.040363
# 2's training. status=start 2025-05-27 21:54:45.040374
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_4, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 21:55:04.783550
# 3's training. status=start 2025-05-27 21:55:04.783654
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_5, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 21:55:22.551656
# completed to train all models. 2025-05-27 21:55:22.551751
# check to create model(3). 2025-05-27 21:55:22.551763
# CPU 시간: 163.178628 초
# 메모리 사용량: 814992 KB
# working model_version = 4
# open model version file 2025-05-27 21:55:33.571111
# start to train all models. 2025-05-27 21:55:33.571138
# 2's training. status=start 2025-05-27 21:55:33.571149
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_6, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 21:55:53.296799
# 3's training. status=start 2025-05-27 21:55:53.296895
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_7, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 21:56:11.601731
# completed to train all models. 2025-05-27 21:56:11.601828
# check to create model(4). 2025-05-27 21:56:11.601841
# CPU 시간: 216.604702 초
# 메모리 사용량: 855744 KB
# working model_version = 5
# open model version file 2025-05-27 21:56:22.634905
# start to train all models. 2025-05-27 21:56:22.634931
# 2's training. status=start 2025-05-27 21:56:22.634941
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_8, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 21:56:42.440441
# 3's training. status=start 2025-05-27 21:56:42.440543
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_9, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 21:57:00.365945
# completed to train all models. 2025-05-27 21:57:00.366046
# check to create model(5). 2025-05-27 21:57:00.366060
# CPU 시간: 269.582222 초
# 메모리 사용량: 932976 KB
# working model_version = 6
# open model version file 2025-05-27 21:57:11.351704
# start to train all models. 2025-05-27 21:57:11.351730
# 2's training. status=start 2025-05-27 21:57:11.351740
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_10, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 21:57:31.590488
# 3's training. status=start 2025-05-27 21:57:31.590587
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_11, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 21:57:50.380316
# completed to train all models. 2025-05-27 21:57:50.380412
# check to create model(6). 2025-05-27 21:57:50.380426
# CPU 시간: 323.287234 초
# 메모리 사용량: 972736 KB
# working model_version = 7
# open model version file 2025-05-27 21:58:02.177318
# start to train all models. 2025-05-27 21:58:02.177344
# 2's training. status=start 2025-05-27 21:58:02.177354
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_12, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 21:58:21.545086
# 3's training. status=start 2025-05-27 21:58:21.545185
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_13, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 21:58:39.346920
# completed to train all models. 2025-05-27 21:58:39.347020
# check to create model(7). 2025-05-27 21:58:39.347033
# CPU 시간: 376.396929 초
# 메모리 사용량: 1014128 KB
# working model_version = 8
# open model version file 2025-05-27 21:58:50.308833
# start to train all models. 2025-05-27 21:58:50.308859
# 2's training. status=start 2025-05-27 21:58:50.308870
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_14, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 21:59:10.580532
# 3's training. status=start 2025-05-27 21:59:10.580629
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_15, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 21:59:29.346724
# completed to train all models. 2025-05-27 21:59:29.346827
# check to create model(8). 2025-05-27 21:59:29.346842
# CPU 시간: 430.436257 초
# 메모리 사용량: 1055472 KB
# working model_version = 9
# open model version file 2025-05-27 21:59:40.852903
# start to train all models. 2025-05-27 21:59:40.852929
# 2's training. status=start 2025-05-27 21:59:40.852940
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_16, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:00:01.212720
# 3's training. status=start 2025-05-27 22:00:01.212817
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_17, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:00:19.131991
# completed to train all models. 2025-05-27 22:00:19.132087
# check to create model(9). 2025-05-27 22:00:19.132100
# CPU 시간: 483.672215 초
# 메모리 사용량: 1096992 KB
# working model_version = 10
# open model version file 2025-05-27 22:00:30.846960
# start to train all models. 2025-05-27 22:00:30.846983
# 2's training. status=start 2025-05-27 22:00:30.846993
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_18, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:00:50.843134
# 3's training. status=start 2025-05-27 22:00:50.843230
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_19, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:01:08.657127
# completed to train all models. 2025-05-27 22:01:08.657223
# check to create model(10). 2025-05-27 22:01:08.657235
# CPU 시간: 536.937468 초
# 메모리 사용량: 1174896 KB
# working model_version = 11
# open model version file 2025-05-27 22:01:20.316029
# start to train all models. 2025-05-27 22:01:20.316054
# 2's training. status=start 2025-05-27 22:01:20.316064
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_20, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:01:41.078553
# 3's training. status=start 2025-05-27 22:01:41.078652
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_21, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:01:59.148015
# completed to train all models. 2025-05-27 22:01:59.148112
# check to create model(11). 2025-05-27 22:01:59.148125
# CPU 시간: 591.981473 초
# 메모리 사용량: 1175408 KB
# working model_version = 12
# open model version file 2025-05-27 22:02:10.185266
# start to train all models. 2025-05-27 22:02:10.185293
# 2's training. status=start 2025-05-27 22:02:10.185303
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_22, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:02:30.510702
# 3's training. status=start 2025-05-27 22:02:30.510805
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_23, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:02:48.483406
# completed to train all models. 2025-05-27 22:02:48.483506
# check to create model(12). 2025-05-27 22:02:48.483518
# CPU 시간: 645.190121 초
# 메모리 사용량: 1221232 KB
# working model_version = 13
# open model version file 2025-05-27 22:03:01.051006
# start to train all models. 2025-05-27 22:03:01.051031
# 2's training. status=start 2025-05-27 22:03:01.051041
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_24, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:03:20.310563
# 3's training. status=start 2025-05-27 22:03:20.310669
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_25, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:03:38.178420
# completed to train all models. 2025-05-27 22:03:38.178522
# check to create model(13). 2025-05-27 22:03:38.178535
# CPU 시간: 699.847959 초
# 메모리 사용량: 1295504 KB
# working model_version = 14
# open model version file 2025-05-27 22:03:52.187291
# start to train all models. 2025-05-27 22:03:52.187317
# 2's training. status=start 2025-05-27 22:03:52.187327
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_26, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:04:11.802805
# 3's training. status=start 2025-05-27 22:04:11.802903
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_27, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:04:29.841454
# completed to train all models. 2025-05-27 22:04:29.841550
# check to create model(14). 2025-05-27 22:04:29.841562
# CPU 시간: 753.535606 초
# 메모리 사용량: 1300928 KB
# working model_version = 15
# open model version file 2025-05-27 22:04:41.648210
# start to train all models. 2025-05-27 22:04:41.648246
# 2's training. status=start 2025-05-27 22:04:41.648262
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_28, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:05:01.903440
# 3's training. status=start 2025-05-27 22:05:01.903536
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_29, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:05:19.901909
# completed to train all models. 2025-05-27 22:05:19.902006
# check to create model(15). 2025-05-27 22:05:19.902018
# CPU 시간: 806.479055 초
# 메모리 사용량: 1377536 KB
# working model_version = 16
# open model version file 2025-05-27 22:05:30.947510
# start to train all models. 2025-05-27 22:05:30.947537
# 2's training. status=start 2025-05-27 22:05:30.947548
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_30, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:05:50.807691
# 3's training. status=start 2025-05-27 22:05:50.807787
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_31, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:06:08.656046
# completed to train all models. 2025-05-27 22:06:08.656147
# check to create model(16). 2025-05-27 22:06:08.656161
# CPU 시간: 859.712761 초
# 메모리 사용량: 1456656 KB
# working model_version = 17
# open model version file 2025-05-27 22:06:20.422220
# start to train all models. 2025-05-27 22:06:20.422246
# 2's training. status=start 2025-05-27 22:06:20.422257
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_32, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:06:41.809935
# 3's training. status=start 2025-05-27 22:06:41.810032
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_33, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:07:00.383953
# completed to train all models. 2025-05-27 22:07:00.384053
# check to create model(17). 2025-05-27 22:07:00.384066
# CPU 시간: 914.920512 초
# 메모리 사용량: 1458192 KB
# working model_version = 18
# open model version file 2025-05-27 22:07:11.706718
# start to train all models. 2025-05-27 22:07:11.706743
# 2's training. status=start 2025-05-27 22:07:11.706754
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_34, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:07:31.144882
# 3's training. status=start 2025-05-27 22:07:31.144979
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_35, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:07:49.534259
# completed to train all models. 2025-05-27 22:07:49.534361
# check to create model(18). 2025-05-27 22:07:49.534373
# CPU 시간: 968.248275 초
# 메모리 사용량: 1465584 KB
# working model_version = 19
# open model version file 2025-05-27 22:08:00.645917
# start to train all models. 2025-05-27 22:08:00.645942
# 2's training. status=start 2025-05-27 22:08:00.645953
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_36, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:08:20.968541
# 3's training. status=start 2025-05-27 22:08:20.968636
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_37, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:08:38.870609
# completed to train all models. 2025-05-27 22:08:38.870710
# check to create model(19). 2025-05-27 22:08:38.870722
# CPU 시간: 1021.209284 초
# 메모리 사용량: 1542880 KB
# working model_version = 20
# open model version file 2025-05-27 22:08:50.765055
# start to train all models. 2025-05-27 22:08:50.765081
# 2's training. status=start 2025-05-27 22:08:50.765092
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_38, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-27 22:09:10.085106
# 3's training. status=start 2025-05-27 22:09:10.085215
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_39, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-27 22:09:27.976180
# completed to train all models. 2025-05-27 22:09:27.976278
# check to create model(20). 2025-05-27 22:09:27.976290
# CPU 시간: 1076.445261 초
# 메모리 사용량: 1617424 KB

# %%
view_model_info = False
if view_model_info:
    for i in range(MAX_MODEL_CNT):
        print(models[i][0].model.summary())

# %%
# all : save model
for model in models:
    if model is not None:
        model[0].save()
