# %% [markdown]
# # Prediction with LSTM model (v4.5.1)
# <p style='text-align: right;'>with selectd5.csv</p>
#
# * history
#   * 2025/05/23 PM06:02 : 3번째 모델의 3번째 데이터를 사용
#   * 2025/05/27
#   * 2025/05/30 : v4.5.1 작성 시작

# %%
# !pip install scikit-learn
# !pip install tensorflow
from datetime import datetime
print(f'restart kernel... {datetime.now()}')

# %%
def restart_kernel():
    # Restart the kernet after libraries are loaded.
    import IPython
    from datetime import datetime
    print(f'restart kernel... {datetime.now()}')
    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

restart_kernel()

# %%
# load dependacies
import os
import time
import resource
from datetime import datetime
from lib.globalvar import *
from lib.data_loader import DataLoader
from lib.small_predict import predict_small, print_predict_small
from lib.activation import ActivationOutput, RecurrentActivation
from lib.small_predict import build_and_predict, gen_multi_model, save_model, generate_metric
from lib.common_env_sets import lstm_units, dense_units, steps, metrics, dropout
from lib.common_env_sets import learning_rate, last_lstm_return_sequences
from lib.common_env_sets import loss, output_dense_activation, epochs, rand_seed


print(f"imported library. ({datetime.now()})")
# Out:
# imported library. (2025-05-30 17:36:35.450170)

# %%
##
## 모델링 환경 설정
##
window=1 # default = 1 , help = "time stamps"
data_dir='./csv/selectd5.csv'
    
mode='predict' # help = "back-test or predict")

mode2='sampling' # help = "greed or sampling")
verb='verbose' # help = "verbose or not_verb")
    
training_length=0.95 # default = 0.9)
from_pos = 0
last = [[1, 5, 18, 20, 30, 35],
        [7, 9, 24, 40, 42, 44],
        [3, 6, 7, 11, 12, 17],
        [3, 13, 28, 34, 38, 42],
        [5, 12, 24, 29, 32, 42]]
print(f"finished to set environemnt. ({datetime.now()})")
# Out:
# finished to set environemnt. (2025-05-30 17:36:52.772031)

# %%
dataset_dicts = {
    1: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=0,
                  verbose=False
                  ),
    2: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=300,
                  verbose=False
                  )
    }

print(f'completed to load data. {datetime.now()}')
# Out:
# completed to load data. 2025-05-30 17:36:56.477736

# %%
###########
## layers
## LSTM Neural 계층 선언
###########
datasets = [dataset_dicts[1], # 0
            dataset_dicts[2], # 1
           ]

lstm_args = {14: {"model":{"learning_rate": learning_rate[0],
                           "dropout": dropout[0],
                           "steps": steps[0], # last output elements count
                           "metrics": metrics[1],
                           "last_lstm_return_sequences": last_lstm_return_sequences[0],
                           "lstm_units": lstm_units[2],
                           "dense_units": dense_units[2],
                           "output_dense_activation": output_dense_activation[3],
                           "loss": loss[0],
                           "return_state": False,
                           "rand_seed": rand_seed[0] # rand_seed[0]
                           },
                 "train": {"epochs": epochs[2],
                           "is_shuffle": False,
                           "batch": 1,
                           "steps_per_epoch": 0 #100
                           },
                 "dataset": datasets[0]
                 },
             44: {"model":{"learning_rate": learning_rate[0],
                           "dropout": dropout[0],
                           "steps": steps[0], # last output elements count
                           "metrics": metrics[0],
                           "last_lstm_return_sequences": last_lstm_return_sequences[1],
                           "lstm_units": lstm_units[2],
                           "dense_units": dense_units[2],
                           "output_dense_activation": output_dense_activation[3],
                           "loss": loss[0],
                           "return_state": False,
                           "rand_seed": rand_seed[0] # rand_seed[0]
                           },
                 "train": {"epochs": epochs[3],
                           "is_shuffle": False,
                           "batch": 1,
                           "steps_per_epoch": 0 #100
                           },
                 "dataset": datasets[0]
                 },
             }


print(f'completed to set env for all models. {datetime.now()}')
# Out:
# completed to set env for all models. 2025-05-30 17:36:58.652997

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_1_1',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 1~12
# CPU 시간: 4.14696 초
# 메모리 사용량: 614480 KB
# generate_metric.02 args["version"]=1
# ********************
# working model_version = 1  2025-05-30 17:37:05.175212
# ********************
# start to train all models. 2025-05-30 17:37:05.175243
# 14's training. status=start 2025-05-30 17:37:05.175258
# 14's training. status=end 2025-05-30 17:37:53.071275
# 44's training. status=start 2025-05-30 17:37:53.071373
# 44's training. status=end 2025-05-30 17:39:23.199785
# completed to train all models. 2025-05-30 17:39:23.199879
# train to create model(1). 2025-05-30 17:39:26.199961
# CPU 시간: 170.813737 초
# 메모리 사용량: 1035872 KB
# generate_metric.02 args["version"]=2
# ********************
# working model_version = 2  2025-05-30 17:39:54.140227
# ********************
# start to train all models. 2025-05-30 17:39:54.140263
# 14's training. status=start 2025-05-30 17:39:54.140280
# 14's training. status=end 2025-05-30 17:40:42.767962
# 44's training. status=start 2025-05-30 17:40:42.768063
# 44's training. status=end 2025-05-30 17:42:15.116384
# completed to train all models. 2025-05-30 17:42:15.116497
# train to create model(2). 2025-05-30 17:42:18.116579
# CPU 시간: 339.42146 초
# 메모리 사용량: 1216416 KB
# generate_metric.02 args["version"]=3
# ********************
# working model_version = 3  2025-05-30 17:42:47.403706
# ********************
# start to train all models. 2025-05-30 17:42:47.403741
# 14's training. status=start 2025-05-30 17:42:47.403760
# 14's training. status=end 2025-05-30 17:43:39.139452
# 44's training. status=start 2025-05-30 17:43:39.139558
# 44's training. status=end 2025-05-30 17:45:12.232222
# completed to train all models. 2025-05-30 17:45:12.232318
# train to create model(3). 2025-05-30 17:45:15.232398
# CPU 시간: 508.391708 초
# 메모리 사용량: 1404752 KB
# generate_metric.02 args["version"]=4
# ********************
# working model_version = 4  2025-05-30 17:45:42.971580
# ********************
# start to train all models. 2025-05-30 17:45:42.971613
# 14's training. status=start 2025-05-30 17:45:42.971630
# 14's training. status=end 2025-05-30 17:46:33.774883
# 44's training. status=start 2025-05-30 17:46:33.775180
# 44's training. status=end 2025-05-30 17:48:05.942331
# completed to train all models. 2025-05-30 17:48:05.942426
# train to create model(4). 2025-05-30 17:48:08.942520
# CPU 시간: 677.801964 초
# 메모리 사용량: 1590368 KB
# generate_metric.02 args["version"]=5
# ********************
# working model_version = 5  2025-05-30 17:48:36.853678
# ********************
# start to train all models. 2025-05-30 17:48:36.853714
# 14's training. status=start 2025-05-30 17:48:36.853729
# 14's training. status=end 2025-05-30 17:49:25.466014
# 44's training. status=start 2025-05-30 17:49:25.466116
# 44's training. status=end 2025-05-30 17:50:57.741918
# completed to train all models. 2025-05-30 17:50:57.742034
# train to create model(5). 2025-05-30 17:51:00.742118
# CPU 시간: 847.366189 초
# 메모리 사용량: 1776608 KB
# generate_metric.02 args["version"]=6
# ********************
# working model_version = 6  2025-05-30 17:51:30.000206
# ********************
# start to train all models. 2025-05-30 17:51:30.000232
# 14's training. status=start 2025-05-30 17:51:30.000243
# 14's training. status=end 2025-05-30 17:52:18.620798
# 44's training. status=start 2025-05-30 17:52:18.621088
# 44's training. status=end 2025-05-30 17:53:52.177148
# completed to train all models. 2025-05-30 17:53:52.177246
# train to create model(6). 2025-05-30 17:53:55.177329
# CPU 시간: 1017.054523 초
# 메모리 사용량: 1962464 KB
# generate_metric.02 args["version"]=7
# ********************
# working model_version = 7  2025-05-30 17:54:23.639001
# ********************
# start to train all models. 2025-05-30 17:54:23.639035
# 14's training. status=start 2025-05-30 17:54:23.639049
# 14's training. status=end 2025-05-30 17:55:13.859803
# 44's training. status=start 2025-05-30 17:55:13.860094
# 44's training. status=end 2025-05-30 17:56:46.753103
# completed to train all models. 2025-05-30 17:56:46.753199
# train to create model(7). 2025-05-30 17:56:49.753286
# CPU 시간: 1185.325873 초
# 메모리 사용량: 2292304 KB
# generate_metric.02 args["version"]=8
# ********************
# working model_version = 8  2025-05-30 17:57:17.915526
# ********************
# start to train all models. 2025-05-30 17:57:17.915562
# 14's training. status=start 2025-05-30 17:57:17.915577
# 14's training. status=end 2025-05-30 17:58:10.240107
# 44's training. status=start 2025-05-30 17:58:10.240204
# 44's training. status=end 2025-05-30 17:59:41.149453
# completed to train all models. 2025-05-30 17:59:41.149550
# train to create model(8). 2025-05-30 17:59:44.149631
# CPU 시간: 1356.141376 초
# 메모리 사용량: 2336448 KB
# generate_metric.02 args["version"]=9
# ********************
# working model_version = 9  2025-05-30 18:00:11.615618
# ********************
# start to train all models. 2025-05-30 18:00:11.615653
# 14's training. status=start 2025-05-30 18:00:11.615669
# 14's training. status=end 2025-05-30 18:01:00.730361
# 44's training. status=start 2025-05-30 18:01:00.730454
# 44's training. status=end 2025-05-30 18:02:34.983551
# completed to train all models. 2025-05-30 18:02:34.983650
# train to create model(9). 2025-05-30 18:02:37.983739
# CPU 시간: 1526.907845 초
# 메모리 사용량: 2520032 KB
# generate_metric.02 args["version"]=10
# ********************
# working model_version = 10  2025-05-30 18:03:05.600329
# ********************
# start to train all models. 2025-05-30 18:03:05.600364
# 14's training. status=start 2025-05-30 18:03:05.600380
# 14's training. status=end 2025-05-30 18:03:55.650310
# 44's training. status=start 2025-05-30 18:03:55.650590
# 44's training. status=end 2025-05-30 18:05:29.738484
# completed to train all models. 2025-05-30 18:05:29.738580
# train to create model(10). 2025-05-30 18:05:32.738661
# CPU 시간: 1696.713182 초
# 메모리 사용량: 2852912 KB
# generate_metric.02 args["version"]=11
# ********************
# working model_version = 11  2025-05-30 18:06:00.390897
# ********************
# start to train all models. 2025-05-30 18:06:00.390933
# 14's training. status=start 2025-05-30 18:06:00.390949
# 14's training. status=end 2025-05-30 18:06:53.140672
# 44's training. status=start 2025-05-30 18:06:53.140771
# 44's training. status=end 2025-05-30 18:08:24.405714
# completed to train all models. 2025-05-30 18:08:24.405815
# train to create model(11). 2025-05-30 18:08:27.405901
# CPU 시간: 1868.45125 초
# 메모리 사용량: 2894736 KB
# generate_metric.02 args["version"]=12
# ********************
# working model_version = 12  2025-05-30 18:08:55.363454
# ********************
# start to train all models. 2025-05-30 18:08:55.363489
# 14's training. status=start 2025-05-30 18:08:55.363505
# 14's training. status=end 2025-05-30 18:09:47.727191
# 44's training. status=start 2025-05-30 18:09:47.727299
# 44's training. status=end 2025-05-30 18:11:19.210475
# completed to train all models. 2025-05-30 18:11:19.210573
# train to create model(12). 2025-05-30 18:11:22.210653
# CPU 시간: 2037.916001 초
# 메모리 사용량: 3221792 KB

# %%
## end
