# %%
#!pip install pandas
# !pip install scikit-learn
# !pip install tensorflow-cpu
# !pip install numpy pandas keras scikit-learn matplotlib scikeras

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import warnings
from datetime import datetime
from contextlib import closing


# 불필요한 경고 메시지를 숨깁니다.
warnings.filterwarnings('ignore')

print(f'completed to load library. [{datetime.now()}]')
# Out:
# completed to load library. [2025-06-12 23:20:53.496453]

# %%
def load_data_by_db(db_file_path, last_round, length, reverse=False):
    import sqlite3
    from contextlib import closing
    with closing(sqlite3.connect(db_file_path)) as conn:
        with closing(conn.cursor()) as cur:
            results = []
            first_bonus = 0
            query = f'select * from results where round>={last_round-length} and round <={last_round} '
            query += "order by round desc" if reverse else "order by round asc"
            datas = cur.execute(query).fetchall()
            for data in datas:
                if first_bonus == 0:
                    first_bonus = data[2]
                results.append((data[1], [int(i) for i in data[2].split(',')], data[3]))
            return results, first_bonus


def create_randomforest_db(db_file_path, verbose=1):
    columns = ["id INTEGER PRIMARY KEY AUTOINCREMENT",
               "n_estimator INTEGER",
               "data_length INTEGER",
               "random_state INTEGER",
               "rounds TEXT",
               "matched_cnts TEXT",
               "sum_val INTEGER",
               "version TEXT"]
    # (n_estimator, data_length, random_state, predict_lens[n_estimator][data_length][random_state], sum_val)
    query = f'CREATE TABLE IF NOT EXISTS rndforest ({",".join(columns)})'
    if verbose > 0:
        print('query=', query)
    import sqlite3
    from contextlib import closing
    with closing(sqlite3.connect(db_file_path)) as conn:
        conn.execute(query)


"""
(25, 400, 2400, [[1176, 1175, 1174, 1173], [1, 1, 3, 2]], 7)
"""
def insert_randomforest_db(db_file_path, version, db_datas, auto_commit=True, verbose=0):
    """ insert_randomforest_db """
    import sqlite3
    from contextlib import closing
    from datetime import datetime
    if version == 0:
        version = str(datetime.now().timestamp())
    with closing(sqlite3.connect(db_file_path)) as conn:
        col_dicts = {"n_estimator": db_datas[0],
                     "data_length": db_datas[1],
                     "random_state": db_datas[2],
                     "rounds": ",".join([str(i) for i in db_datas[3][0]]),
                     "matched_cnts": ",".join([str(i) for i in db_datas[3][1]]),
                     "sum_val": db_datas[4],
                     "version": version
                     }
        columns = col_dicts.keys()
        values=list(col_dicts.values())
        column_val=["?" for i in range(len(columns))]
        query = f"INSERT INTO rndforest ({','.join(columns)}) "\
                f"VALUES ({','.join(column_val)})"
        with closing(conn.cursor()) as cursor:
            if verbose > 0:
                print(f'query={query}')
                print('-'*30)
            cursor.execute(query, values)
        if auto_commit:
            conn.commit()

# %%
created_db = True
if created_db == False:
    create_randomforest_db('../db/metrics.db')

# %%
def predict(train_X, n_estimators=100, random_state=350, trial=5, verbose=0):
    # 데이터를 Pandas DataFrame으로 변환합니다.
    df = pd.DataFrame(train_X, columns=['회차', '번호1', '번호2', '번호3', '번호4', '번호5', '번호6'])
    df = df.sort_values(by='회차').reset_index(drop=True)

    if verbose > 0:
        print("--- 로또 당첨 번호 이력 ---")
        print(df)

    # 기계 학습을 위한 데이터 준비
    # 각 회차의 당첨 번호(X)와 바로 다음 회차의 당첨 번호(y)를 사용합니다.
    X = df[['번호1', '번호2', '번호3', '번호4', '번호5', '번호6']]
    y = df[['번호1', '번호2', '번호3', '번호4', '번호5', '번호6']].shift(-1)

    # 마지막 행은 다음 회차 데이터가 없으므로 제거합니다.
    X = X[:-1]
    y = y.dropna()
    
    if verbose > 0:
        print("\n--- 훈련 데이터 (X) ---")
        print(X.head())
        print("\n--- 정답 데이터 (y) ---")
        print(y.head())

    # 머신러닝 모델 선택 및 훈련
    # 랜덤 포레스트 회귀 모델을 사용합니다.
    # the random_state parameter is used to control the randomness of the algorithm, ensuring reproducibility of results. 
    # the n_estimators parameter specifies the number of decision trees in the forest. 
    model = RandomForestRegressor(n_estimators=n_estimators, random_state=random_state) # n_estimators: 만들 트리의 개수
    model.fit(X, y)

    # 예측할 회차의 이전 회차 데이터 (1173회차)
    last_draw = df.iloc[-1][['번호1', '번호2', '번호3', '번호4', '번호5', '번호6']].values.reshape(1, -1)

    if verbose > 0:
        print(f"\n--- {df.iloc[-1]['회차']}회차 데이터로 다음 회차 예측 ---")
        print(last_draw)

    # 다음 번호 예측
    predicted_numbers_set = []
    for i in range(trial):
        predicted_numbers_float = model.predict(last_draw)
        # 예측된 번호 처리
        # 1. 소수점을 반올림하여 정수로 만듭니다.
        # 2. 1~45 사이의 값으로 보정합니다.
        # 3. 중복된 번호를 제거하고 6개를 선택합니다.
        predicted_numbers = set()
        for num in predicted_numbers_float[0]:
            # 반올림하여 정수로 변환
            int_num = int(round(num))
            # 1보다 작으면 1로, 45보다 크면 45로 보정
            if int_num < 1:
                int_num = 1
            elif int_num > 45:
                int_num = 45
            predicted_numbers.add(int_num)
        # 중복 제거 후 6개가 안되면, 부족한 만큼 다른 번호로 채웁니다.
        # (여기서는 가장 빈도가 높은 번호들 중 예측되지 않은 번호를 추가하는 방식을 사용)
        if len(predicted_numbers) < 6:
            all_numbers = df[['번호1', '번호2', '번호3', '번호4', '번호5', '번호6']].values.flatten()
            counts = pd.Series(all_numbers).value_counts()
    
            extra_needed = 6 - len(predicted_numbers)
            for num in counts.index:
                if extra_needed == 0:
                    break
                if num not in predicted_numbers:
                    predicted_numbers.add(num)
                    extra_needed -= 1
        # 최종 예측 번호를 정렬하여 출력
        final_prediction = sorted(list(predicted_numbers))[:6]
        predicted_numbers_set.append(final_prediction)
    return predicted_numbers_set


def test_prediction(round_nums,
                    actual_numbers,
                    bonus,
                    predicted_numbers_set,
                    n_estimators=500,
                    random_state=500,
                    only_one=True,
                    verbose=0):
    if verbose>0:
        print("======================================")
        print(f"\n--- 참고: {round_nums}회 실제 번호 ---")
        print(f"번호: {actual_numbers}, 보너스: {bonus}")

    matched_len = 0

    for final_prediction in predicted_numbers_set:
        # 예측 결과와 실제 결과 비교
        matching_numbers = set(final_prediction).intersection(set(actual_numbers))
        if verbose > 0:
            print(f"\n--- 예측과 실제 결과 비교 ---")
            print(f"일치하는 번호: {sorted(list(matching_numbers))}")
            print(f"일치 개수: {len(matching_numbers)}")
            print(F"예측 번호: {final_prediction}")
            print(f"n_estimators: {n_estimators}")
            print(f"random_state: {random_state}")
        matched_len = len(matching_numbers)
        if only_one:
            break
    return matched_len


def list_to_dict(item_lists):
    dicts = {}
    for item in item_lists:
        dicts[item[0]] = (item[1], item[2])
    return dicts


print(f'completed to define. #1 [{datetime.now()}]')
# Out:
# completed to define. #1 [2025-06-13 00:51:55.787233]

# %%
verbose = 1

# 실제 번호
actual_numbers_or, _ = load_data_by_db(db_file_path='../db/metrics.db',
                                 last_round=1176,
                                 length=10, reverse=True)
actual_numbers = [actual_sets[1] for actual_sets in actual_numbers_or]

if verbose > 0:
    print('actual_numbers', type(actual_numbers), actual_numbers)

data_list_cnt = 3
data_length = 25
results_set=[]

print(f'completed to set env. [{datetime.now()}]')
# Out:
# actual_numbers <class 'list'> [[1, 2, 3, 4, 5, 6], [3, 4, 6, 8, 32, 42], [8, 11, 14, 17, 36, 39], [1, 5, 18, 20, 30, 35], [7, 9, 24, 40, 42, 44], [3, 6, 7, 11, 12, 17], [3, 13, 28, 34, 38, 42], [5, 12, 24, 26, 39, 42], [9, 21, 24, 30, 33, 37], [8, 23, 31, 35, 39, 40], [14, 23, 25, 27, 29, 42]]
# completed to set env. [2025-06-12 23:21:07.943367]

# %% [markdown]
# **Notice**
# - the random_state parameter is used to control the randomness of the algorithm, ensuring reproducibility of results.
# - the n_estimators parameter specifies the number of decision trees in the forest. This parameter is crucial as it directly impacts the model's performance and computational cost.

# %%
def predit_and_test_parts(round, bonus, h_data, n_estimators, random_state, trial=5, verbose=0):
    """ predit_and_test_parts """
    train_X = []
    test_X = []
    for i in range(len(h_data) - 1):
        train_X.append(h_data[i][1])
    test_X = h_data[len(h_data) - 1][1]
    predicted_numbers_set = predict(train_X=train_X,
                                    n_estimators=n_estimators,
                                    random_state=random_state,
                                    trial=trial,
                                    verbose=verbose)
    predict_len1=test_prediction(round,
                                 test_X,
                                 bonus,
                                 predicted_numbers_set,
                                 n_estimators,
                                 random_state,
                                 verbose)
    return predicted_numbers_set, predict_len1


def predict_and_test(round, bonus, h_data, n_estimators, random_state, trial, verbose=0):
    """ predict_and_test """
    _, predict_len = predit_and_test_parts(round, bonus, h_data, n_estimators, random_state, trial, 0)
    return predict_len


print(f'completed to define. #2 [{datetime.now()}]')
# Out:
# completed to define. #2 [2025-06-13 00:51:58.633636]

# %%
results_set = []

print(f'completed to reset results_set. #2 [{datetime.now()}]')
# Out:
# completed to reset results_set. #2 [2025-06-12 23:21:12.981096]

# %%
def main_predict(n_estimator,
                 last_round,
                 data_length,
                 random_state,
                 db_file_path,
                 trial,
                 verbose=0):
    """ main_predict """
    predict_lens = {}
    hist_data, first_bonus = load_data_by_db(db_file_path=db_file_path, last_round=last_round, length=data_length)
    for train_x in hist_data:
        train_x[1].insert(0, train_x[0])
    predicted_numbers_set, _ = predit_and_test_parts(round=last_round,
                                                     bonus=first_bonus,
                                                     h_data=hist_data,
                                                     n_estimators=n_estimator,
                                                     random_state=random_state,
                                                     trial=trial,
                                                     verbose=verbose)
    return predicted_numbers_set

print(f'completed to define. #3 [{datetime.now()}]')
# Out:
# completed to define. #3 [2025-06-13 00:52:03.179575]

# %%
### Prepare and train, predict
def main_process(version,
                 n_estimators,
                 last_rounds,
                 data_lengths,
                 random_state_gap=100,
                 random_state_begin=0,
                 random_state_end=300000,
                 db_file_path='../db/metrics.db',
                 write_to_db=False,
                 write_db_file_path='../db/metrics.db',
                 trial=5,
                 verbose=0):
    predict_lens = {}
    for n_estimator in n_estimators:
        predict_lens[n_estimator] = {}
        if n_estimator > 1:
            for last_round in last_rounds:
                cnt = 0
                for data_length in data_lengths:
                    hist_data, first_bonus = load_data_by_db(db_file_path=db_file_path, last_round=last_round, length=data_length)
                    for train_x in hist_data:
                        train_x[1].insert(0, train_x[0])
                    if data_length not in predict_lens[n_estimator]:
                        predict_lens[n_estimator][data_length] = {}
                    for random_state in range(random_state_begin, random_state_end, random_state_gap):
                        predict_len = predict_and_test(last_round, first_bonus, hist_data, n_estimator, random_state, trial, 0)
                        if n_estimator not in predict_lens:
                            predict_lens[n_estimator] = {}
                        if random_state not in predict_lens[n_estimator][data_length]:
                            predict_lens[n_estimator][data_length][random_state] = [[last_round], [predict_len]]
                        else:
                            predict_lens[n_estimator][data_length][random_state][0].append(last_round)
                            predict_lens[n_estimator][data_length][random_state][1].append(predict_len)
                        cnt += 1
                        if cnt % 1000 == 0:
                            print(f'proceed [now={datetime.now()}, n_estimator={n_estimator}, cnt={cnt}, last_round={last_round}, random_state={random_state}, data_length={data_length}]')
    return predict_lens

print(f'completed to define main_process. #7 [{datetime.now()}]')
# Out:
# completed to define main_process. #7 [2025-06-13 00:52:48.544781]

# %%
def print_predicts(predict_lens, sum_min=-1, sum_max=-1, verbose=0, write_to_file=False, write_to_db=False):
    result_set = []
    for n_estimator in predict_lens:
        for data_length in predict_lens[n_estimator]:
            for random_state in predict_lens[n_estimator][data_length]:
                sum_val = sum(predict_lens[n_estimator][data_length][random_state][1])
                if sum_min == -1 and sum_max == -1:
                    if verbose > 0:
                        print(n_estimator, data_length, random_state, predict_lens[n_estimator][data_length][random_state])
                    result_set.append((n_estimator, data_length, random_state, predict_lens[n_estimator][data_length][random_state], sum_val))
                else:
                    if sum_min > 0 and sum_max > 0 and sum_val >= sum_min and sum_val <= sum_max:
                        if verbose > 0:
                            print(n_estimator, data_length, random_state, predict_lens[n_estimator][data_length][random_state])
                        result_set.append((n_estimator, data_length, random_state, predict_lens[n_estimator][data_length][random_state], sum_val))
                    else:
                        if sum_min > 0 and sum_val >= sum_min:
                            if verbose > 0:
                                print(n_estimator, data_length, random_state, predict_lens[n_estimator][data_length][random_state])
                            result_set.append((n_estimator, data_length, random_state, predict_lens[n_estimator][data_length][random_state], sum_val))
                        elif sum_max > 0 and sum_val <= sum_max:
                            if verbose > 0:
                                print(n_estimator, data_length, random_state, predict_lens[n_estimator][data_length][random_state])
                            result_set.append((n_estimator, data_length, random_state, predict_lens[n_estimator][data_length][random_state], sum_val))
                if write_to_file:
                    with closing(open("metric_temp.txt", "at")) as fd:
                        fd.write(f'{n_estimator},{data_length},{random_state},')
                        fd.write(f'{"/".join([str(i) for i in predict_lens[n_estimator][data_length][random_state][0]])},')
                        fd.write(f'{"/".join([str(i) for i in predict_lens[n_estimator][data_length][random_state][0]])},')
                        fd.write(f'{sum_val}\n')
                if write_to_db:
                    db_datas = (n_estimator, data_length, random_state, predict_lens[n_estimator][data_length][random_state], sum_val)
                    insert_randomforest_db('../db/metrics.db',
                                           version=version,
                                           db_datas=db_datas,
                                           verbose=verbose)


    return result_set


print(f'completed to define print_predicts. #8 [{datetime.now()}]')
# Out:
# completed to define print_predicts. #8 [2025-06-13 00:52:05.861763]

# %%
def main(parameters, version, sum_min=-1, sum_max=-1, write_to_file=False, write_to_db=False, trial=5, verbose=0):
    print(f'start   [now={datetime.now()}]')    
    predict_lens = main_process(version=version,
                                n_estimators=parameters["n_estimators"],
                                last_rounds=parameters["last_rounds"],
                                data_lengths=parameters["data_lengths"],
                                random_state_gap=parameters["random_state_gap"],
                                random_state_begin=parameters["random_state_begin"],
                                random_state_end=parameters["random_state_end"],
                                trial=trial,
                                verbose=verbose)
    print(f'completed [now={datetime.now()}]')
    print(f'start to read and write data: [now={datetime.now()}]')
    result_set = print_predicts(predict_lens=predict_lens,
                                sum_min=sum_min,
                                sum_max=sum_max,
                                write_to_file=write_to_file,
                                write_to_db=write_to_db)
    print(f'complete to read and data: [now={datetime.now()}]')
    return result_set

print(f'completed to define main. #9 [{datetime.now()}]')
# Out:
# completed to define main. #9 [2025-06-13 00:59:42.920392]

# %%
parameters = {
    "n_estimators": [25, 50, 10],
    "data_lengths": [40],
    "random_state_gap": 1,
    "random_state_begin": 0,
    "random_state_end": 1000,
    "last_rounds": [1175, 1174, 1173],
}
version="T_01_02"
result_sets = main(parameters=parameters, sum_min=2, version=version)

# %%
parameters = {
    "n_estimators": [25, 10],
    "data_lengths": [40],
    "random_state_gap": 1,
    "random_state_begin": 0,
    "random_state_end": 1000,
    "last_rounds": [1175, 1174, 1173, 1172, 1171, 1170, 1169, 1168, 1167, 1166],
}
version="T_01_03"
result_sets = main(parameters=parameters, sum_min=2, version=version)
# Out:
# start   [now=2025-06-11 23:05:14.736151]
# proceed [now=2025-06-11 23:05:37.338800, cnt=1000, last_round=1176, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:06:03.904516, cnt=1000, last_round=1175, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:06:29.714422, cnt=1000, last_round=1174, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:06:55.629254, cnt=1000, last_round=1173, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:07:18.650509, cnt=1000, last_round=1172, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:07:44.495763, cnt=1000, last_round=1171, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:08:10.484503, cnt=1000, last_round=1170, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:08:33.761643, cnt=1000, last_round=1169, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:08:59.960513, cnt=1000, last_round=1168, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:09:14.003625, cnt=1000, last_round=1176, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:09:25.466348, cnt=1000, last_round=1175, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:09:36.846252, cnt=1000, last_round=1174, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:09:51.171436, cnt=1000, last_round=1173, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:10:02.531769, cnt=1000, last_round=1172, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:10:13.915938, cnt=1000, last_round=1171, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:10:28.298362, cnt=1000, last_round=1170, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:10:39.744095, cnt=1000, last_round=1169, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:10:51.191971, cnt=1000, last_round=1168, random_state=999, data_length=40]
# completed [now=2025-06-11 23:10:51.192141]

# %%
parameters = {
    "n_estimators": [25, 10],
    "data_lengths": [40],
    "random_state_gap": 1,
    "random_state_begin": 0,
    "random_state_end": 1000,
    "last_rounds": [1176, 1175, 1174],
}
version="T_01_04"
result_sets = main(parameters=parameters, sum_min=2, version=version)
# Out:
# start   [now=2025-06-11 23:20:22.639013]
# proceed [now=2025-06-11 23:20:48.674119, n_estimator=25, cnt=1000, last_round=1176, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:21:14.995542, n_estimator=25, cnt=1000, last_round=1175, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:21:37.827796, n_estimator=25, cnt=1000, last_round=1174, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:21:52.514248, n_estimator=10, cnt=1000, last_round=1176, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:22:03.630452, n_estimator=10, cnt=1000, last_round=1175, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:22:14.851538, n_estimator=10, cnt=1000, last_round=1174, random_state=999, data_length=40]
# completed [now=2025-06-11 23:22:14.851758]

# %%
parameters = {
    "n_estimators": [25, 10],
    "data_lengths": [40],
    "random_state_gap": 1,
    "random_state_begin": 0,
    "random_state_end": 1000,
    "last_rounds": [1175, 1175],
}
version="T_01_05"
result_sets = main(parameters=parameters, sum_min=2, version=version)
# Out:
# start   [now=2025-06-11 23:33:51.682807]
# proceed [now=2025-06-11 23:34:18.700060, n_estimator=25, cnt=1000, last_round=1176, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:34:42.910211, n_estimator=25, cnt=1000, last_round=1175, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:34:58.457405, n_estimator=10, cnt=1000, last_round=1176, random_state=999, data_length=40]
# proceed [now=2025-06-11 23:35:11.968236, n_estimator=10, cnt=1000, last_round=1175, random_state=999, data_length=40]
# completed [now=2025-06-11 23:35:11.968854]
# start to read data: [now=2025-06-11 23:35:11.968929]
# complete to read data: [now=2025-06-11 23:35:11.970196]
# start to write db: [now=2025-06-11 23:35:11.970231]
# complete to write db: [now=2025-06-11 23:35:34.319251]

# %%
parameters = {
    "n_estimators": [25, 10],
    "data_lengths": [40],
    "random_state_gap": 1,
    "random_state_begin": 0,
    "random_state_end": 1000,
    "last_rounds": [1175],
}
version="T_01_06"
result_sets = main(parameters=parameters, sum_min=2, version=version)

# %%
parameters = {
    "n_estimators": [25],
    "data_lengths": [400],
    "random_state_gap": 1,
    "random_state_begin": 0,
    "random_state_end": 3000,
    "last_rounds": [1175, 1174, 1173, 1172, 1171, 1170, 1169, 1168, 1167, 1166],
}
version="T_01_07"
trial=1
result_sets = main(parameters=parameters, sum_min=2, trial=trial, version=version)
# Out:
# start   [now=2025-06-12 00:18:32.976156]
# proceed [now=2025-06-12 00:19:31.586459, n_estimator=25, cnt=1000, last_round=1176, random_state=999, data_length=400]
# proceed [now=2025-06-12 00:20:31.094794, n_estimator=25, cnt=2000, last_round=1176, random_state=1999, data_length=400]
# proceed [now=2025-06-12 00:21:30.204987, n_estimator=25, cnt=3000, last_round=1176, random_state=2999, data_length=400]
# proceed [now=2025-06-12 00:22:28.500770, n_estimator=25, cnt=1000, last_round=1175, random_state=999, data_length=400]
# proceed [now=2025-06-12 00:23:29.680448, n_estimator=25, cnt=2000, last_round=1175, random_state=1999, data_length=400]
# proceed [now=2025-06-12 00:24:30.779908, n_estimator=25, cnt=3000, last_round=1175, random_state=2999, data_length=400]
# proceed [now=2025-06-12 00:25:27.806711, n_estimator=25, cnt=1000, last_round=1174, random_state=999, data_length=400]
# proceed [now=2025-06-12 00:26:23.534800, n_estimator=25, cnt=2000, last_round=1174, random_state=1999, data_length=400]
# proceed [now=2025-06-12 00:27:17.324144, n_estimator=25, cnt=3000, last_round=1174, random_state=2999, data_length=400]
# proceed [now=2025-06-12 00:28:18.984605, n_estimator=25, cnt=1000, last_round=1173, random_state=999, data_length=400]
# proceed [now=2025-06-12 00:29:21.255542, n_estimator=25, cnt=2000, last_round=1173, random_state=1999, data_length=400]
# proceed [now=2025-06-12 00:30:19.612567, n_estimator=25, cnt=3000, last_round=1173, random_state=2999, data_length=400]
# proceed [now=2025-06-12 00:31:21.774698, n_estimator=25, cnt=1000, last_round=1172, random_state=999, data_length=400]
# proceed [now=2025-06-12 00:32:20.878758, n_estimator=25, cnt=2000, last_round=1172, random_state=1999, data_length=400]
# proceed [now=2025-06-12 00:33:15.518860, n_estimator=25, cnt=3000, last_round=1172, random_state=2999, data_length=400]
# proceed [now=2025-06-12 00:34:17.743886, n_estimator=25, cnt=1000, last_round=1171, random_state=999, data_length=400]
# proceed [now=2025-06-12 00:35:18.624279, n_estimator=25, cnt=2000, last_round=1171, random_state=1999, data_length=400]
# proceed [now=2025-06-12 00:36:16.700184, n_estimator=25, cnt=3000, last_round=1171, random_state=2999, data_length=400]
# proceed [now=2025-06-12 00:37:17.955165, n_estimator=25, cnt=1000, last_round=1170, random_state=999, data_length=400]
# proceed [now=2025-06-12 00:38:15.814362, n_estimator=25, cnt=2000, last_round=1170, random_state=1999, data_length=400]
# proceed [now=2025-06-12 00:39:11.597815, n_estimator=25, cnt=3000, last_round=1170, random_state=2999, data_length=400]
# proceed [now=2025-06-12 00:40:13.011210, n_estimator=25, cnt=1000, last_round=1169, random_state=999, data_length=400]
# proceed [now=2025-06-12 00:41:14.748466, n_estimator=25, cnt=2000, last_round=1169, random_state=1999, data_length=400]
# proceed [now=2025-06-12 00:42:12.351950, n_estimator=25, cnt=3000, last_round=1169, random_state=2999, data_length=400]
# proceed [now=2025-06-12 00:43:15.926360, n_estimator=25, cnt=1000, last_round=1168, random_state=999, data_length=400]
# proceed [now=2025-06-12 00:44:17.648976, n_estimator=25, cnt=2000, last_round=1168, random_state=1999, data_length=400]
# proceed [now=2025-06-12 00:45:15.831565, n_estimator=25, cnt=3000, last_round=1168, random_state=2999, data_length=400]
# completed [now=2025-06-12 00:45:15.831727]
# completed [now=2025-06-12 00:45:15.831742]
# start to read data: [now=2025-06-12 00:45:15.831751]
# complete to read data: [now=2025-06-12 00:45:15.833542]
# start to write db: [now=2025-06-12 00:45:15.833578]
# complete to write db: [now=2025-06-12 00:46:01.647277]

# %%
parameters = {
    "n_estimators": [25,10],
    "data_lengths": [400],
    "random_state_gap": 10,
    "random_state_begin": 300000,
    "random_state_end": 400000,
    "last_rounds": [1175, 1174, 1173, 1172, 1171, 1170, 1169, 1168, 1167, 1166],
}
version="T_01_08"
result_sets = main(parameters=parameters, version=version, sum_min=0, sum_max=-1, trial=1, write_to_db=True)
# Out:
# start   [now=2025-06-12 16:01:48.633986]
# proceed [now=2025-06-12 16:02:52.170550, n_estimator=25, cnt=1000, last_round=1175, random_state=309990, data_length=400]
# proceed [now=2025-06-12 16:03:54.539848, n_estimator=25, cnt=2000, last_round=1175, random_state=319990, data_length=400]
# proceed [now=2025-06-12 16:04:56.995352, n_estimator=25, cnt=3000, last_round=1175, random_state=329990, data_length=400]
# proceed [now=2025-06-12 16:05:59.742052, n_estimator=25, cnt=4000, last_round=1175, random_state=339990, data_length=400]
# proceed [now=2025-06-12 16:07:02.568713, n_estimator=25, cnt=5000, last_round=1175, random_state=349990, data_length=400]
# proceed [now=2025-06-12 16:08:05.782773, n_estimator=25, cnt=6000, last_round=1175, random_state=359990, data_length=400]
# proceed [now=2025-06-12 16:09:08.845926, n_estimator=25, cnt=7000, last_round=1175, random_state=369990, data_length=400]
# proceed [now=2025-06-12 16:10:11.810140, n_estimator=25, cnt=8000, last_round=1175, random_state=379990, data_length=400]
# proceed [now=2025-06-12 16:11:15.049422, n_estimator=25, cnt=9000, last_round=1175, random_state=389990, data_length=400]
# proceed [now=2025-06-12 16:12:17.982747, n_estimator=25, cnt=10000, last_round=1175, random_state=399990, data_length=400]
# proceed [now=2025-06-12 16:13:20.937994, n_estimator=25, cnt=1000, last_round=1174, random_state=309990, data_length=400]
# proceed [now=2025-06-12 16:14:23.836575, n_estimator=25, cnt=2000, last_round=1174, random_state=319990, data_length=400]
# proceed [now=2025-06-12 16:15:26.755128, n_estimator=25, cnt=3000, last_round=1174, random_state=329990, data_length=400]
# proceed [now=2025-06-12 16:16:29.782396, n_estimator=25, cnt=4000, last_round=1174, random_state=339990, data_length=400]
# proceed [now=2025-06-12 16:17:32.844431, n_estimator=25, cnt=5000, last_round=1174, random_state=349990, data_length=400]
# proceed [now=2025-06-12 16:18:35.918440, n_estimator=25, cnt=6000, last_round=1174, random_state=359990, data_length=400]
# proceed [now=2025-06-12 16:19:38.992344, n_estimator=25, cnt=7000, last_round=1174, random_state=369990, data_length=400]
# proceed [now=2025-06-12 16:20:42.048721, n_estimator=25, cnt=8000, last_round=1174, random_state=379990, data_length=400]
# proceed [now=2025-06-12 16:21:45.167237, n_estimator=25, cnt=9000, last_round=1174, random_state=389990, data_length=400]
# proceed [now=2025-06-12 16:22:48.347836, n_estimator=25, cnt=10000, last_round=1174, random_state=399990, data_length=400]
# proceed [now=2025-06-12 16:23:51.405160, n_estimator=25, cnt=1000, last_round=1173, random_state=309990, data_length=400]
# proceed [now=2025-06-12 16:24:54.446393, n_estimator=25, cnt=2000, last_round=1173, random_state=319990, data_length=400]
# proceed [now=2025-06-12 16:25:57.191355, n_estimator=25, cnt=3000, last_round=1173, random_state=329990, data_length=400]
# proceed [now=2025-06-12 16:26:59.641805, n_estimator=25, cnt=4000, last_round=1173, random_state=339990, data_length=400]
# proceed [now=2025-06-12 16:28:02.109060, n_estimator=25, cnt=5000, last_round=1173, random_state=349990, data_length=400]
# proceed [now=2025-06-12 16:29:04.679092, n_estimator=25, cnt=6000, last_round=1173, random_state=359990, data_length=400]
# proceed [now=2025-06-12 16:30:07.169332, n_estimator=25, cnt=7000, last_round=1173, random_state=369990, data_length=400]
# proceed [now=2025-06-12 16:31:09.727911, n_estimator=25, cnt=8000, last_round=1173, random_state=379990, data_length=400]
# proceed [now=2025-06-12 16:32:12.340508, n_estimator=25, cnt=9000, last_round=1173, random_state=389990, data_length=400]
# proceed [now=2025-06-12 16:33:14.889666, n_estimator=25, cnt=10000, last_round=1173, random_state=399990, data_length=400]
# proceed [now=2025-06-12 16:34:17.631271, n_estimator=25, cnt=1000, last_round=1172, random_state=309990, data_length=400]
# proceed [now=2025-06-12 16:35:20.410110, n_estimator=25, cnt=2000, last_round=1172, random_state=319990, data_length=400]
# proceed [now=2025-06-12 16:36:23.749698, n_estimator=25, cnt=3000, last_round=1172, random_state=329990, data_length=400]
# proceed [now=2025-06-12 16:37:27.318364, n_estimator=25, cnt=4000, last_round=1172, random_state=339990, data_length=400]
# proceed [now=2025-06-12 16:38:30.684162, n_estimator=25, cnt=5000, last_round=1172, random_state=349990, data_length=400]
# proceed [now=2025-06-12 16:39:34.456337, n_estimator=25, cnt=6000, last_round=1172, random_state=359990, data_length=400]
# proceed [now=2025-06-12 16:40:38.113332, n_estimator=25, cnt=7000, last_round=1172, random_state=369990, data_length=400]
# proceed [now=2025-06-12 16:41:41.796154, n_estimator=25, cnt=8000, last_round=1172, random_state=379990, data_length=400]
# proceed [now=2025-06-12 16:42:45.475232, n_estimator=25, cnt=9000, last_round=1172, random_state=389990, data_length=400]
# proceed [now=2025-06-12 16:43:49.178638, n_estimator=25, cnt=10000, last_round=1172, random_state=399990, data_length=400]
# proceed [now=2025-06-12 16:44:52.337612, n_estimator=25, cnt=1000, last_round=1171, random_state=309990, data_length=400]
# proceed [now=2025-06-12 16:45:55.495092, n_estimator=25, cnt=2000, last_round=1171, random_state=319990, data_length=400]
# proceed [now=2025-06-12 16:46:58.736355, n_estimator=25, cnt=3000, last_round=1171, random_state=329990, data_length=400]
# proceed [now=2025-06-12 16:48:01.920349, n_estimator=25, cnt=4000, last_round=1171, random_state=339990, data_length=400]
# proceed [now=2025-06-12 16:49:05.160461, n_estimator=25, cnt=5000, last_round=1171, random_state=349990, data_length=400]
# proceed [now=2025-06-12 16:50:08.431286, n_estimator=25, cnt=6000, last_round=1171, random_state=359990, data_length=400]
# proceed [now=2025-06-12 16:51:11.747607, n_estimator=25, cnt=7000, last_round=1171, random_state=369990, data_length=400]
# proceed [now=2025-06-12 16:52:15.075891, n_estimator=25, cnt=8000, last_round=1171, random_state=379990, data_length=400]
# proceed [now=2025-06-12 16:53:18.412073, n_estimator=25, cnt=9000, last_round=1171, random_state=389990, data_length=400]
# proceed [now=2025-06-12 16:54:21.839400, n_estimator=25, cnt=10000, last_round=1171, random_state=399990, data_length=400]
# proceed [now=2025-06-12 16:55:26.026693, n_estimator=25, cnt=1000, last_round=1170, random_state=309990, data_length=400]
# proceed [now=2025-06-12 16:56:29.913831, n_estimator=25, cnt=2000, last_round=1170, random_state=319990, data_length=400]
# proceed [now=2025-06-12 16:57:33.538290, n_estimator=25, cnt=3000, last_round=1170, random_state=329990, data_length=400]
# proceed [now=2025-06-12 16:58:37.218592, n_estimator=25, cnt=4000, last_round=1170, random_state=339990, data_length=400]
# proceed [now=2025-06-12 16:59:41.048400, n_estimator=25, cnt=5000, last_round=1170, random_state=349990, data_length=400]
# proceed [now=2025-06-12 17:00:44.670081, n_estimator=25, cnt=6000, last_round=1170, random_state=359990, data_length=400]
# proceed [now=2025-06-12 17:01:48.316910, n_estimator=25, cnt=7000, last_round=1170, random_state=369990, data_length=400]
# proceed [now=2025-06-12 17:02:51.918177, n_estimator=25, cnt=8000, last_round=1170, random_state=379990, data_length=400]
# proceed [now=2025-06-12 17:03:55.494090, n_estimator=25, cnt=9000, last_round=1170, random_state=389990, data_length=400]
# proceed [now=2025-06-12 17:04:59.075456, n_estimator=25, cnt=10000, last_round=1170, random_state=399990, data_length=400]
# proceed [now=2025-06-12 17:06:02.275198, n_estimator=25, cnt=1000, last_round=1169, random_state=309990, data_length=400]
# proceed [now=2025-06-12 17:07:05.825273, n_estimator=25, cnt=2000, last_round=1169, random_state=319990, data_length=400]
# proceed [now=2025-06-12 17:08:09.327940, n_estimator=25, cnt=3000, last_round=1169, random_state=329990, data_length=400]
# proceed [now=2025-06-12 17:09:12.849457, n_estimator=25, cnt=4000, last_round=1169, random_state=339990, data_length=400]
# proceed [now=2025-06-12 17:10:16.328793, n_estimator=25, cnt=5000, last_round=1169, random_state=349990, data_length=400]
# proceed [now=2025-06-12 17:11:19.884611, n_estimator=25, cnt=6000, last_round=1169, random_state=359990, data_length=400]
# proceed [now=2025-06-12 17:12:23.483123, n_estimator=25, cnt=7000, last_round=1169, random_state=369990, data_length=400]
# proceed [now=2025-06-12 17:13:27.246823, n_estimator=25, cnt=8000, last_round=1169, random_state=379990, data_length=400]
# proceed [now=2025-06-12 17:14:30.634444, n_estimator=25, cnt=9000, last_round=1169, random_state=389990, data_length=400]
# proceed [now=2025-06-12 17:15:33.826182, n_estimator=25, cnt=10000, last_round=1169, random_state=399990, data_length=400]
# proceed [now=2025-06-12 17:16:36.456884, n_estimator=25, cnt=1000, last_round=1168, random_state=309990, data_length=400]
# proceed [now=2025-06-12 17:17:39.115613, n_estimator=25, cnt=2000, last_round=1168, random_state=319990, data_length=400]
# proceed [now=2025-06-12 17:18:41.737740, n_estimator=25, cnt=3000, last_round=1168, random_state=329990, data_length=400]
# proceed [now=2025-06-12 17:19:44.410114, n_estimator=25, cnt=4000, last_round=1168, random_state=339990, data_length=400]
# proceed [now=2025-06-12 17:20:47.138793, n_estimator=25, cnt=5000, last_round=1168, random_state=349990, data_length=400]
# proceed [now=2025-06-12 17:21:49.982454, n_estimator=25, cnt=6000, last_round=1168, random_state=359990, data_length=400]
# proceed [now=2025-06-12 17:22:52.815210, n_estimator=25, cnt=7000, last_round=1168, random_state=369990, data_length=400]
# proceed [now=2025-06-12 17:23:55.988525, n_estimator=25, cnt=8000, last_round=1168, random_state=379990, data_length=400]
# proceed [now=2025-06-12 17:24:59.282498, n_estimator=25, cnt=9000, last_round=1168, random_state=389990, data_length=400]
# proceed [now=2025-06-12 17:26:02.572533, n_estimator=25, cnt=10000, last_round=1168, random_state=399990, data_length=400]
# proceed [now=2025-06-12 17:27:05.249764, n_estimator=25, cnt=1000, last_round=1167, random_state=309990, data_length=400]
# proceed [now=2025-06-12 17:28:07.845305, n_estimator=25, cnt=2000, last_round=1167, random_state=319990, data_length=400]
# proceed [now=2025-06-12 17:29:10.409035, n_estimator=25, cnt=3000, last_round=1167, random_state=329990, data_length=400]
# proceed [now=2025-06-12 17:30:13.461242, n_estimator=25, cnt=4000, last_round=1167, random_state=339990, data_length=400]
# proceed [now=2025-06-12 17:31:16.599512, n_estimator=25, cnt=5000, last_round=1167, random_state=349990, data_length=400]
# proceed [now=2025-06-12 17:32:19.854758, n_estimator=25, cnt=6000, last_round=1167, random_state=359990, data_length=400]
# proceed [now=2025-06-12 17:33:23.225157, n_estimator=25, cnt=7000, last_round=1167, random_state=369990, data_length=400]
# proceed [now=2025-06-12 17:34:26.736189, n_estimator=25, cnt=8000, last_round=1167, random_state=379990, data_length=400]
# proceed [now=2025-06-12 17:35:30.050043, n_estimator=25, cnt=9000, last_round=1167, random_state=389990, data_length=400]
# proceed [now=2025-06-12 17:36:33.320639, n_estimator=25, cnt=10000, last_round=1167, random_state=399990, data_length=400]
# proceed [now=2025-06-12 17:37:36.301568, n_estimator=25, cnt=1000, last_round=1166, random_state=309990, data_length=400]
# proceed [now=2025-06-12 17:38:39.232958, n_estimator=25, cnt=2000, last_round=1166, random_state=319990, data_length=400]
# proceed [now=2025-06-12 17:39:42.119446, n_estimator=25, cnt=3000, last_round=1166, random_state=329990, data_length=400]
# proceed [now=2025-06-12 17:40:44.867973, n_estimator=25, cnt=4000, last_round=1166, random_state=339990, data_length=400]
# proceed [now=2025-06-12 17:41:47.269073, n_estimator=25, cnt=5000, last_round=1166, random_state=349990, data_length=400]
# proceed [now=2025-06-12 17:42:49.657789, n_estimator=25, cnt=6000, last_round=1166, random_state=359990, data_length=400]
# proceed [now=2025-06-12 17:43:52.150324, n_estimator=25, cnt=7000, last_round=1166, random_state=369990, data_length=400]
# proceed [now=2025-06-12 17:44:54.731155, n_estimator=25, cnt=8000, last_round=1166, random_state=379990, data_length=400]
# proceed [now=2025-06-12 17:45:57.475392, n_estimator=25, cnt=9000, last_round=1166, random_state=389990, data_length=400]
# proceed [now=2025-06-12 17:47:00.230212, n_estimator=25, cnt=10000, last_round=1166, random_state=399990, data_length=400]
# proceed [now=2025-06-12 17:47:29.661193, n_estimator=10, cnt=1000, last_round=1175, random_state=309990, data_length=400]
# proceed [now=2025-06-12 17:47:59.100877, n_estimator=10, cnt=2000, last_round=1175, random_state=319990, data_length=400]
# proceed [now=2025-06-12 17:48:28.765614, n_estimator=10, cnt=3000, last_round=1175, random_state=329990, data_length=400]
# proceed [now=2025-06-12 17:48:58.418896, n_estimator=10, cnt=4000, last_round=1175, random_state=339990, data_length=400]
# proceed [now=2025-06-12 17:49:27.986312, n_estimator=10, cnt=5000, last_round=1175, random_state=349990, data_length=400]
# proceed [now=2025-06-12 17:49:57.449353, n_estimator=10, cnt=6000, last_round=1175, random_state=359990, data_length=400]
# proceed [now=2025-06-12 17:50:27.002351, n_estimator=10, cnt=7000, last_round=1175, random_state=369990, data_length=400]
# proceed [now=2025-06-12 17:50:56.387936, n_estimator=10, cnt=8000, last_round=1175, random_state=379990, data_length=400]
# proceed [now=2025-06-12 17:51:26.029012, n_estimator=10, cnt=9000, last_round=1175, random_state=389990, data_length=400]
# proceed [now=2025-06-12 17:51:55.463263, n_estimator=10, cnt=10000, last_round=1175, random_state=399990, data_length=400]
# proceed [now=2025-06-12 17:52:25.056220, n_estimator=10, cnt=1000, last_round=1174, random_state=309990, data_length=400]
# proceed [now=2025-06-12 17:52:54.516459, n_estimator=10, cnt=2000, last_round=1174, random_state=319990, data_length=400]
# proceed [now=2025-06-12 17:53:24.060130, n_estimator=10, cnt=3000, last_round=1174, random_state=329990, data_length=400]
# proceed [now=2025-06-12 17:53:53.643674, n_estimator=10, cnt=4000, last_round=1174, random_state=339990, data_length=400]
# proceed [now=2025-06-12 17:54:23.254511, n_estimator=10, cnt=5000, last_round=1174, random_state=349990, data_length=400]
# proceed [now=2025-06-12 17:54:52.849569, n_estimator=10, cnt=6000, last_round=1174, random_state=359990, data_length=400]
# proceed [now=2025-06-12 17:55:22.441057, n_estimator=10, cnt=7000, last_round=1174, random_state=369990, data_length=400]
# proceed [now=2025-06-12 17:55:52.050310, n_estimator=10, cnt=8000, last_round=1174, random_state=379990, data_length=400]
# proceed [now=2025-06-12 17:56:21.636233, n_estimator=10, cnt=9000, last_round=1174, random_state=389990, data_length=400]
# proceed [now=2025-06-12 17:56:51.260663, n_estimator=10, cnt=10000, last_round=1174, random_state=399990, data_length=400]
# proceed [now=2025-06-12 17:57:20.892547, n_estimator=10, cnt=1000, last_round=1173, random_state=309990, data_length=400]
# proceed [now=2025-06-12 17:57:50.526254, n_estimator=10, cnt=2000, last_round=1173, random_state=319990, data_length=400]
# proceed [now=2025-06-12 17:58:20.140449, n_estimator=10, cnt=3000, last_round=1173, random_state=329990, data_length=400]
# proceed [now=2025-06-12 17:58:49.747104, n_estimator=10, cnt=4000, last_round=1173, random_state=339990, data_length=400]
# proceed [now=2025-06-12 17:59:19.373384, n_estimator=10, cnt=5000, last_round=1173, random_state=349990, data_length=400]
# proceed [now=2025-06-12 17:59:48.994554, n_estimator=10, cnt=6000, last_round=1173, random_state=359990, data_length=400]
# proceed [now=2025-06-12 18:00:18.642189, n_estimator=10, cnt=7000, last_round=1173, random_state=369990, data_length=400]
# proceed [now=2025-06-12 18:00:48.280317, n_estimator=10, cnt=8000, last_round=1173, random_state=379990, data_length=400]
# proceed [now=2025-06-12 18:01:17.946221, n_estimator=10, cnt=9000, last_round=1173, random_state=389990, data_length=400]
# proceed [now=2025-06-12 18:01:47.614676, n_estimator=10, cnt=10000, last_round=1173, random_state=399990, data_length=400]
# proceed [now=2025-06-12 18:02:17.368477, n_estimator=10, cnt=1000, last_round=1172, random_state=309990, data_length=400]
# proceed [now=2025-06-12 18:02:47.127712, n_estimator=10, cnt=2000, last_round=1172, random_state=319990, data_length=400]
# proceed [now=2025-06-12 18:03:16.885607, n_estimator=10, cnt=3000, last_round=1172, random_state=329990, data_length=400]
# proceed [now=2025-06-12 18:03:46.607491, n_estimator=10, cnt=4000, last_round=1172, random_state=339990, data_length=400]
# proceed [now=2025-06-12 18:04:16.338634, n_estimator=10, cnt=5000, last_round=1172, random_state=349990, data_length=400]
# proceed [now=2025-06-12 18:04:46.092761, n_estimator=10, cnt=6000, last_round=1172, random_state=359990, data_length=400]
# proceed [now=2025-06-12 18:05:15.848516, n_estimator=10, cnt=7000, last_round=1172, random_state=369990, data_length=400]
# proceed [now=2025-06-12 18:05:45.576481, n_estimator=10, cnt=8000, last_round=1172, random_state=379990, data_length=400]
# proceed [now=2025-06-12 18:06:15.280661, n_estimator=10, cnt=9000, last_round=1172, random_state=389990, data_length=400]
# proceed [now=2025-06-12 18:06:45.027559, n_estimator=10, cnt=10000, last_round=1172, random_state=399990, data_length=400]
# proceed [now=2025-06-12 18:07:14.719343, n_estimator=10, cnt=1000, last_round=1171, random_state=309990, data_length=400]
# proceed [now=2025-06-12 18:07:44.409137, n_estimator=10, cnt=2000, last_round=1171, random_state=319990, data_length=400]
# proceed [now=2025-06-12 18:08:14.127246, n_estimator=10, cnt=3000, last_round=1171, random_state=329990, data_length=400]
# proceed [now=2025-06-12 18:08:43.828735, n_estimator=10, cnt=4000, last_round=1171, random_state=339990, data_length=400]
# proceed [now=2025-06-12 18:09:13.434954, n_estimator=10, cnt=5000, last_round=1171, random_state=349990, data_length=400]
# proceed [now=2025-06-12 18:09:42.773328, n_estimator=10, cnt=6000, last_round=1171, random_state=359990, data_length=400]
# proceed [now=2025-06-12 18:10:12.144398, n_estimator=10, cnt=7000, last_round=1171, random_state=369990, data_length=400]
# proceed [now=2025-06-12 18:10:41.491971, n_estimator=10, cnt=8000, last_round=1171, random_state=379990, data_length=400]
# proceed [now=2025-06-12 18:11:10.854503, n_estimator=10, cnt=9000, last_round=1171, random_state=389990, data_length=400]
# proceed [now=2025-06-12 18:11:40.263261, n_estimator=10, cnt=10000, last_round=1171, random_state=399990, data_length=400]
# proceed [now=2025-06-12 18:12:09.672926, n_estimator=10, cnt=1000, last_round=1170, random_state=309990, data_length=400]
# proceed [now=2025-06-12 18:12:39.103209, n_estimator=10, cnt=2000, last_round=1170, random_state=319990, data_length=400]
# proceed [now=2025-06-12 18:13:08.673648, n_estimator=10, cnt=3000, last_round=1170, random_state=329990, data_length=400]
# proceed [now=2025-06-12 18:13:38.330438, n_estimator=10, cnt=4000, last_round=1170, random_state=339990, data_length=400]
# proceed [now=2025-06-12 18:14:07.958759, n_estimator=10, cnt=5000, last_round=1170, random_state=349990, data_length=400]
# proceed [now=2025-06-12 18:14:37.563103, n_estimator=10, cnt=6000, last_round=1170, random_state=359990, data_length=400]
# proceed [now=2025-06-12 18:15:07.234975, n_estimator=10, cnt=7000, last_round=1170, random_state=369990, data_length=400]
# proceed [now=2025-06-12 18:15:36.898551, n_estimator=10, cnt=8000, last_round=1170, random_state=379990, data_length=400]
# proceed [now=2025-06-12 18:16:06.573187, n_estimator=10, cnt=9000, last_round=1170, random_state=389990, data_length=400]
# proceed [now=2025-06-12 18:16:36.282476, n_estimator=10, cnt=10000, last_round=1170, random_state=399990, data_length=400]
# proceed [now=2025-06-12 18:17:06.190214, n_estimator=10, cnt=1000, last_round=1169, random_state=309990, data_length=400]
# proceed [now=2025-06-12 18:17:36.098694, n_estimator=10, cnt=2000, last_round=1169, random_state=319990, data_length=400]
# proceed [now=2025-06-12 18:18:05.999322, n_estimator=10, cnt=3000, last_round=1169, random_state=329990, data_length=400]
# proceed [now=2025-06-12 18:18:35.897559, n_estimator=10, cnt=4000, last_round=1169, random_state=339990, data_length=400]
# proceed [now=2025-06-12 18:19:05.852437, n_estimator=10, cnt=5000, last_round=1169, random_state=349990, data_length=400]
# proceed [now=2025-06-12 18:19:35.840828, n_estimator=10, cnt=6000, last_round=1169, random_state=359990, data_length=400]
# proceed [now=2025-06-12 18:20:05.813834, n_estimator=10, cnt=7000, last_round=1169, random_state=369990, data_length=400]
# proceed [now=2025-06-12 18:20:35.795182, n_estimator=10, cnt=8000, last_round=1169, random_state=379990, data_length=400]
# proceed [now=2025-06-12 18:21:05.777075, n_estimator=10, cnt=9000, last_round=1169, random_state=389990, data_length=400]
# proceed [now=2025-06-12 18:21:35.803636, n_estimator=10, cnt=10000, last_round=1169, random_state=399990, data_length=400]
# proceed [now=2025-06-12 18:22:05.776842, n_estimator=10, cnt=1000, last_round=1168, random_state=309990, data_length=400]
# proceed [now=2025-06-12 18:22:35.689099, n_estimator=10, cnt=2000, last_round=1168, random_state=319990, data_length=400]
# proceed [now=2025-06-12 18:23:05.552132, n_estimator=10, cnt=3000, last_round=1168, random_state=329990, data_length=400]
# proceed [now=2025-06-12 18:23:35.389906, n_estimator=10, cnt=4000, last_round=1168, random_state=339990, data_length=400]
# proceed [now=2025-06-12 18:24:05.274855, n_estimator=10, cnt=5000, last_round=1168, random_state=349990, data_length=400]
# proceed [now=2025-06-12 18:24:35.183074, n_estimator=10, cnt=6000, last_round=1168, random_state=359990, data_length=400]
# proceed [now=2025-06-12 18:25:05.091052, n_estimator=10, cnt=7000, last_round=1168, random_state=369990, data_length=400]
# proceed [now=2025-06-12 18:25:35.026822, n_estimator=10, cnt=8000, last_round=1168, random_state=379990, data_length=400]
# proceed [now=2025-06-12 18:26:04.973692, n_estimator=10, cnt=9000, last_round=1168, random_state=389990, data_length=400]
# proceed [now=2025-06-12 18:26:34.915024, n_estimator=10, cnt=10000, last_round=1168, random_state=399990, data_length=400]
# proceed [now=2025-06-12 18:27:04.901029, n_estimator=10, cnt=1000, last_round=1167, random_state=309990, data_length=400]
# proceed [now=2025-06-12 18:27:34.542018, n_estimator=10, cnt=2000, last_round=1167, random_state=319990, data_length=400]
# proceed [now=2025-06-12 18:28:04.184045, n_estimator=10, cnt=3000, last_round=1167, random_state=329990, data_length=400]
# proceed [now=2025-06-12 18:28:33.831832, n_estimator=10, cnt=4000, last_round=1167, random_state=339990, data_length=400]
# proceed [now=2025-06-12 18:29:03.434309, n_estimator=10, cnt=5000, last_round=1167, random_state=349990, data_length=400]
# proceed [now=2025-06-12 18:29:33.028129, n_estimator=10, cnt=6000, last_round=1167, random_state=359990, data_length=400]
# proceed [now=2025-06-12 18:30:02.618677, n_estimator=10, cnt=7000, last_round=1167, random_state=369990, data_length=400]
# proceed [now=2025-06-12 18:30:32.215353, n_estimator=10, cnt=8000, last_round=1167, random_state=379990, data_length=400]
# proceed [now=2025-06-12 18:31:01.819059, n_estimator=10, cnt=9000, last_round=1167, random_state=389990, data_length=400]
# proceed [now=2025-06-12 18:31:31.403784, n_estimator=10, cnt=10000, last_round=1167, random_state=399990, data_length=400]
# proceed [now=2025-06-12 18:32:01.087241, n_estimator=10, cnt=1000, last_round=1166, random_state=309990, data_length=400]
# proceed [now=2025-06-12 18:32:30.761619, n_estimator=10, cnt=2000, last_round=1166, random_state=319990, data_length=400]
# proceed [now=2025-06-12 18:33:00.433367, n_estimator=10, cnt=3000, last_round=1166, random_state=329990, data_length=400]
# proceed [now=2025-06-12 18:33:30.113590, n_estimator=10, cnt=4000, last_round=1166, random_state=339990, data_length=400]
# proceed [now=2025-06-12 18:33:59.879305, n_estimator=10, cnt=5000, last_round=1166, random_state=349990, data_length=400]
# proceed [now=2025-06-12 18:34:29.665415, n_estimator=10, cnt=6000, last_round=1166, random_state=359990, data_length=400]
# proceed [now=2025-06-12 18:34:59.467176, n_estimator=10, cnt=7000, last_round=1166, random_state=369990, data_length=400]
# proceed [now=2025-06-12 18:35:29.269779, n_estimator=10, cnt=8000, last_round=1166, random_state=379990, data_length=400]
# proceed [now=2025-06-12 18:35:59.058701, n_estimator=10, cnt=9000, last_round=1166, random_state=389990, data_length=400]
# proceed [now=2025-06-12 18:36:28.862561, n_estimator=10, cnt=10000, last_round=1166, random_state=399990, data_length=400]
# completed [now=2025-06-12 18:36:28.862758]
# start to read and write data: [now=2025-06-12 18:36:28.862772]
# complete to read and data: [now=2025-06-12 18:40:39.431254]

# %%
for result in result_sets:
    print(result)

# %%
parameters = {
    "n_estimators": [25,10],
    "data_lengths": [400],
    "random_state_gap": 10,
    "random_state_begin": 100000,
    "random_state_end": 150000,
    "last_rounds": [1175, 1174, 1173, 1172, 1171, 1170, 1169, 1168, 1167, 1166],
}
version="T_01_08"
result_sets = main(parameters=parameters, version=version, sum_min=0, sum_max=-1, trial=1, write_to_db=True)
# Out:
# start   [now=2025-06-12 14:40:37.246073]
# proceed [now=2025-06-12 14:41:42.718049, n_estimator=25, cnt=1000, last_round=1175, random_state=109990, data_length=400]
# proceed [now=2025-06-12 14:42:47.658780, n_estimator=25, cnt=2000, last_round=1175, random_state=119990, data_length=400]
# proceed [now=2025-06-12 14:43:50.521634, n_estimator=25, cnt=3000, last_round=1175, random_state=129990, data_length=400]
# proceed [now=2025-06-12 14:44:52.960051, n_estimator=25, cnt=4000, last_round=1175, random_state=139990, data_length=400]
# proceed [now=2025-06-12 14:45:55.507010, n_estimator=25, cnt=5000, last_round=1175, random_state=149990, data_length=400]
# proceed [now=2025-06-12 14:46:58.081716, n_estimator=25, cnt=1000, last_round=1174, random_state=109990, data_length=400]
# proceed [now=2025-06-12 14:48:00.428461, n_estimator=25, cnt=2000, last_round=1174, random_state=119990, data_length=400]
# proceed [now=2025-06-12 14:49:02.731608, n_estimator=25, cnt=3000, last_round=1174, random_state=129990, data_length=400]
# proceed [now=2025-06-12 14:50:05.041546, n_estimator=25, cnt=4000, last_round=1174, random_state=139990, data_length=400]
# proceed [now=2025-06-12 14:51:07.454148, n_estimator=25, cnt=5000, last_round=1174, random_state=149990, data_length=400]
# proceed [now=2025-06-12 14:52:10.630090, n_estimator=25, cnt=1000, last_round=1173, random_state=109990, data_length=400]
# proceed [now=2025-06-12 14:53:14.395471, n_estimator=25, cnt=2000, last_round=1173, random_state=119990, data_length=400]
# proceed [now=2025-06-12 14:54:18.133904, n_estimator=25, cnt=3000, last_round=1173, random_state=129990, data_length=400]
# proceed [now=2025-06-12 14:55:21.899081, n_estimator=25, cnt=4000, last_round=1173, random_state=139990, data_length=400]
# proceed [now=2025-06-12 14:56:25.596009, n_estimator=25, cnt=5000, last_round=1173, random_state=149990, data_length=400]
# proceed [now=2025-06-12 14:57:29.402960, n_estimator=25, cnt=1000, last_round=1172, random_state=109990, data_length=400]
# proceed [now=2025-06-12 14:58:33.233216, n_estimator=25, cnt=2000, last_round=1172, random_state=119990, data_length=400]
# proceed [now=2025-06-12 14:59:37.031408, n_estimator=25, cnt=3000, last_round=1172, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:00:40.887588, n_estimator=25, cnt=4000, last_round=1172, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:01:44.689795, n_estimator=25, cnt=5000, last_round=1172, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:02:48.449046, n_estimator=25, cnt=1000, last_round=1171, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:03:52.322798, n_estimator=25, cnt=2000, last_round=1171, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:04:56.045869, n_estimator=25, cnt=3000, last_round=1171, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:05:59.521044, n_estimator=25, cnt=4000, last_round=1171, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:07:03.049727, n_estimator=25, cnt=5000, last_round=1171, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:08:06.357093, n_estimator=25, cnt=1000, last_round=1170, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:09:09.828357, n_estimator=25, cnt=2000, last_round=1170, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:10:13.354289, n_estimator=25, cnt=3000, last_round=1170, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:11:17.065908, n_estimator=25, cnt=4000, last_round=1170, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:12:20.679191, n_estimator=25, cnt=5000, last_round=1170, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:13:24.059854, n_estimator=25, cnt=1000, last_round=1169, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:14:27.342207, n_estimator=25, cnt=2000, last_round=1169, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:15:30.721300, n_estimator=25, cnt=3000, last_round=1169, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:16:34.270253, n_estimator=25, cnt=4000, last_round=1169, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:17:37.889599, n_estimator=25, cnt=5000, last_round=1169, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:18:41.301675, n_estimator=25, cnt=1000, last_round=1168, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:19:44.975317, n_estimator=25, cnt=2000, last_round=1168, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:20:48.578813, n_estimator=25, cnt=3000, last_round=1168, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:21:52.029131, n_estimator=25, cnt=4000, last_round=1168, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:22:55.505725, n_estimator=25, cnt=5000, last_round=1168, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:23:58.803982, n_estimator=25, cnt=1000, last_round=1167, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:25:02.176421, n_estimator=25, cnt=2000, last_round=1167, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:26:05.626458, n_estimator=25, cnt=3000, last_round=1167, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:27:09.057799, n_estimator=25, cnt=4000, last_round=1167, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:28:12.539800, n_estimator=25, cnt=5000, last_round=1167, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:29:15.903444, n_estimator=25, cnt=1000, last_round=1166, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:30:19.147762, n_estimator=25, cnt=2000, last_round=1166, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:31:22.282977, n_estimator=25, cnt=3000, last_round=1166, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:32:25.410169, n_estimator=25, cnt=4000, last_round=1166, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:33:28.460093, n_estimator=25, cnt=5000, last_round=1166, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:33:58.009486, n_estimator=10, cnt=1000, last_round=1175, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:34:27.503009, n_estimator=10, cnt=2000, last_round=1175, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:34:56.955817, n_estimator=10, cnt=3000, last_round=1175, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:35:26.585734, n_estimator=10, cnt=4000, last_round=1175, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:35:56.030221, n_estimator=10, cnt=5000, last_round=1175, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:36:25.691852, n_estimator=10, cnt=1000, last_round=1174, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:36:55.382387, n_estimator=10, cnt=2000, last_round=1174, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:37:25.021729, n_estimator=10, cnt=3000, last_round=1174, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:37:54.636806, n_estimator=10, cnt=4000, last_round=1174, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:38:24.393191, n_estimator=10, cnt=5000, last_round=1174, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:38:54.047771, n_estimator=10, cnt=1000, last_round=1173, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:39:23.703860, n_estimator=10, cnt=2000, last_round=1173, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:39:53.365221, n_estimator=10, cnt=3000, last_round=1173, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:40:23.038374, n_estimator=10, cnt=4000, last_round=1173, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:40:52.702576, n_estimator=10, cnt=5000, last_round=1173, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:41:22.368023, n_estimator=10, cnt=1000, last_round=1172, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:41:52.105988, n_estimator=10, cnt=2000, last_round=1172, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:42:21.834805, n_estimator=10, cnt=3000, last_round=1172, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:42:51.569381, n_estimator=10, cnt=4000, last_round=1172, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:43:21.313951, n_estimator=10, cnt=5000, last_round=1172, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:43:51.077546, n_estimator=10, cnt=1000, last_round=1171, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:44:20.843672, n_estimator=10, cnt=2000, last_round=1171, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:44:50.599456, n_estimator=10, cnt=3000, last_round=1171, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:45:20.368974, n_estimator=10, cnt=4000, last_round=1171, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:45:50.175238, n_estimator=10, cnt=5000, last_round=1171, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:46:19.895154, n_estimator=10, cnt=1000, last_round=1170, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:46:49.633469, n_estimator=10, cnt=2000, last_round=1170, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:47:19.424288, n_estimator=10, cnt=3000, last_round=1170, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:47:49.202056, n_estimator=10, cnt=4000, last_round=1170, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:48:18.985844, n_estimator=10, cnt=5000, last_round=1170, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:48:48.732737, n_estimator=10, cnt=1000, last_round=1169, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:49:18.510755, n_estimator=10, cnt=2000, last_round=1169, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:49:48.282787, n_estimator=10, cnt=3000, last_round=1169, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:50:18.054213, n_estimator=10, cnt=4000, last_round=1169, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:50:47.853828, n_estimator=10, cnt=5000, last_round=1169, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:51:17.361035, n_estimator=10, cnt=1000, last_round=1168, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:51:46.743552, n_estimator=10, cnt=2000, last_round=1168, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:52:16.110090, n_estimator=10, cnt=3000, last_round=1168, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:52:45.490276, n_estimator=10, cnt=4000, last_round=1168, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:53:14.866194, n_estimator=10, cnt=5000, last_round=1168, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:53:44.221390, n_estimator=10, cnt=1000, last_round=1167, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:54:13.602075, n_estimator=10, cnt=2000, last_round=1167, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:54:42.980607, n_estimator=10, cnt=3000, last_round=1167, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:55:12.335340, n_estimator=10, cnt=4000, last_round=1167, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:55:41.843817, n_estimator=10, cnt=5000, last_round=1167, random_state=149990, data_length=400]
# proceed [now=2025-06-12 15:56:11.266154, n_estimator=10, cnt=1000, last_round=1166, random_state=109990, data_length=400]
# proceed [now=2025-06-12 15:56:40.714174, n_estimator=10, cnt=2000, last_round=1166, random_state=119990, data_length=400]
# proceed [now=2025-06-12 15:57:10.164703, n_estimator=10, cnt=3000, last_round=1166, random_state=129990, data_length=400]
# proceed [now=2025-06-12 15:57:39.646220, n_estimator=10, cnt=4000, last_round=1166, random_state=139990, data_length=400]
# proceed [now=2025-06-12 15:58:09.274025, n_estimator=10, cnt=5000, last_round=1166, random_state=149990, data_length=400]
# completed [now=2025-06-12 15:58:09.274235]
# completed [now=2025-06-12 15:58:09.274249]
# start to read data: [now=2025-06-12 15:58:09.274258]
# complete to read data: [now=2025-06-12 16:00:16.692904]
# start to write db: [now=2025-06-12 16:00:16.693020]
# complete to write db: [now=2025-06-12 16:00:16.693037]

# %%
parameters = {
    "n_estimators": [25,10],
    "data_lengths": [400],
    "random_state_gap": 10,
    "random_state_begin": 150000,
    "random_state_end": 200000,
    "last_rounds": [1175, 1174, 1173, 1172, 1171, 1170, 1169, 1168, 1167, 1166],
}
version="T_01_08"
result_sets = main(parameters=parameters, version=version, sum_min=0, sum_max=-1, trial=1, write_to_db=True)
# Out:
# start   [now=2025-06-12 19:17:33.396619]
# proceed [now=2025-06-12 19:18:36.171596, n_estimator=25, cnt=1000, last_round=1175, random_state=159990, data_length=400]
# proceed [now=2025-06-12 19:19:38.722645, n_estimator=25, cnt=2000, last_round=1175, random_state=169990, data_length=400]
# proceed [now=2025-06-12 19:20:41.331990, n_estimator=25, cnt=3000, last_round=1175, random_state=179990, data_length=400]
# proceed [now=2025-06-12 19:21:43.808543, n_estimator=25, cnt=4000, last_round=1175, random_state=189990, data_length=400]
# proceed [now=2025-06-12 19:22:46.226923, n_estimator=25, cnt=5000, last_round=1175, random_state=199990, data_length=400]
# proceed [now=2025-06-12 19:23:49.239496, n_estimator=25, cnt=1000, last_round=1174, random_state=159990, data_length=400]
# proceed [now=2025-06-12 19:24:52.270011, n_estimator=25, cnt=2000, last_round=1174, random_state=169990, data_length=400]
# proceed [now=2025-06-12 19:25:55.311937, n_estimator=25, cnt=3000, last_round=1174, random_state=179990, data_length=400]
# proceed [now=2025-06-12 19:26:58.319414, n_estimator=25, cnt=4000, last_round=1174, random_state=189990, data_length=400]
# proceed [now=2025-06-12 19:28:01.414404, n_estimator=25, cnt=5000, last_round=1174, random_state=199990, data_length=400]
# proceed [now=2025-06-12 19:29:04.767231, n_estimator=25, cnt=1000, last_round=1173, random_state=159990, data_length=400]
# proceed [now=2025-06-12 19:30:08.082290, n_estimator=25, cnt=2000, last_round=1173, random_state=169990, data_length=400]
# proceed [now=2025-06-12 19:31:11.499143, n_estimator=25, cnt=3000, last_round=1173, random_state=179990, data_length=400]
# proceed [now=2025-06-12 19:32:15.034691, n_estimator=25, cnt=4000, last_round=1173, random_state=189990, data_length=400]
# proceed [now=2025-06-12 19:33:18.475288, n_estimator=25, cnt=5000, last_round=1173, random_state=199990, data_length=400]
# proceed [now=2025-06-12 19:34:21.040089, n_estimator=25, cnt=1000, last_round=1172, random_state=159990, data_length=400]
# proceed [now=2025-06-12 19:35:23.610659, n_estimator=25, cnt=2000, last_round=1172, random_state=169990, data_length=400]
# proceed [now=2025-06-12 19:36:26.145847, n_estimator=25, cnt=3000, last_round=1172, random_state=179990, data_length=400]
# proceed [now=2025-06-12 19:37:28.725150, n_estimator=25, cnt=4000, last_round=1172, random_state=189990, data_length=400]
# proceed [now=2025-06-12 19:38:31.394334, n_estimator=25, cnt=5000, last_round=1172, random_state=199990, data_length=400]
# proceed [now=2025-06-12 19:39:34.512231, n_estimator=25, cnt=1000, last_round=1171, random_state=159990, data_length=400]
# proceed [now=2025-06-12 19:40:37.572594, n_estimator=25, cnt=2000, last_round=1171, random_state=169990, data_length=400]
# proceed [now=2025-06-12 19:41:40.670800, n_estimator=25, cnt=3000, last_round=1171, random_state=179990, data_length=400]
# proceed [now=2025-06-12 19:42:43.566184, n_estimator=25, cnt=4000, last_round=1171, random_state=189990, data_length=400]
# proceed [now=2025-06-12 19:43:46.467881, n_estimator=25, cnt=5000, last_round=1171, random_state=199990, data_length=400]
# proceed [now=2025-06-12 19:44:49.436728, n_estimator=25, cnt=1000, last_round=1170, random_state=159990, data_length=400]
# proceed [now=2025-06-12 19:45:52.455615, n_estimator=25, cnt=2000, last_round=1170, random_state=169990, data_length=400]
# proceed [now=2025-06-12 19:46:55.473880, n_estimator=25, cnt=3000, last_round=1170, random_state=179990, data_length=400]
# proceed [now=2025-06-12 19:47:58.517465, n_estimator=25, cnt=4000, last_round=1170, random_state=189990, data_length=400]
# proceed [now=2025-06-12 19:49:01.508658, n_estimator=25, cnt=5000, last_round=1170, random_state=199990, data_length=400]
# proceed [now=2025-06-12 19:50:04.442861, n_estimator=25, cnt=1000, last_round=1169, random_state=159990, data_length=400]
# proceed [now=2025-06-12 19:51:07.427524, n_estimator=25, cnt=2000, last_round=1169, random_state=169990, data_length=400]
# proceed [now=2025-06-12 19:52:10.484265, n_estimator=25, cnt=3000, last_round=1169, random_state=179990, data_length=400]
# proceed [now=2025-06-12 19:53:13.534477, n_estimator=25, cnt=4000, last_round=1169, random_state=189990, data_length=400]
# proceed [now=2025-06-12 19:54:16.535391, n_estimator=25, cnt=5000, last_round=1169, random_state=199990, data_length=400]
# proceed [now=2025-06-12 19:55:19.474865, n_estimator=25, cnt=1000, last_round=1168, random_state=159990, data_length=400]
# proceed [now=2025-06-12 19:56:22.269435, n_estimator=25, cnt=2000, last_round=1168, random_state=169990, data_length=400]
# proceed [now=2025-06-12 19:57:25.142633, n_estimator=25, cnt=3000, last_round=1168, random_state=179990, data_length=400]
# proceed [now=2025-06-12 19:58:27.934017, n_estimator=25, cnt=4000, last_round=1168, random_state=189990, data_length=400]
# proceed [now=2025-06-12 19:59:30.693653, n_estimator=25, cnt=5000, last_round=1168, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:00:33.125324, n_estimator=25, cnt=1000, last_round=1167, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:01:35.676407, n_estimator=25, cnt=2000, last_round=1167, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:02:38.251581, n_estimator=25, cnt=3000, last_round=1167, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:03:40.801415, n_estimator=25, cnt=4000, last_round=1167, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:04:43.329805, n_estimator=25, cnt=5000, last_round=1167, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:05:45.793935, n_estimator=25, cnt=1000, last_round=1166, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:06:48.370409, n_estimator=25, cnt=2000, last_round=1166, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:07:51.051890, n_estimator=25, cnt=3000, last_round=1166, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:08:53.733194, n_estimator=25, cnt=4000, last_round=1166, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:09:56.403665, n_estimator=25, cnt=5000, last_round=1166, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:10:26.083778, n_estimator=10, cnt=1000, last_round=1175, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:10:55.557362, n_estimator=10, cnt=2000, last_round=1175, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:11:24.932573, n_estimator=10, cnt=3000, last_round=1175, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:11:54.302796, n_estimator=10, cnt=4000, last_round=1175, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:12:23.729257, n_estimator=10, cnt=5000, last_round=1175, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:12:53.043090, n_estimator=10, cnt=1000, last_round=1174, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:13:22.369424, n_estimator=10, cnt=2000, last_round=1174, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:13:51.892091, n_estimator=10, cnt=3000, last_round=1174, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:14:21.476568, n_estimator=10, cnt=4000, last_round=1174, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:14:51.096903, n_estimator=10, cnt=5000, last_round=1174, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:15:20.429759, n_estimator=10, cnt=1000, last_round=1173, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:15:49.744889, n_estimator=10, cnt=2000, last_round=1173, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:16:19.097357, n_estimator=10, cnt=3000, last_round=1173, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:16:48.443691, n_estimator=10, cnt=4000, last_round=1173, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:17:17.814953, n_estimator=10, cnt=5000, last_round=1173, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:17:47.487655, n_estimator=10, cnt=1000, last_round=1172, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:18:17.196818, n_estimator=10, cnt=2000, last_round=1172, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:18:46.888399, n_estimator=10, cnt=3000, last_round=1172, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:19:16.566398, n_estimator=10, cnt=4000, last_round=1172, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:19:46.300371, n_estimator=10, cnt=5000, last_round=1172, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:20:16.031962, n_estimator=10, cnt=1000, last_round=1171, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:20:45.754733, n_estimator=10, cnt=2000, last_round=1171, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:21:15.564576, n_estimator=10, cnt=3000, last_round=1171, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:21:45.341825, n_estimator=10, cnt=4000, last_round=1171, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:22:15.097934, n_estimator=10, cnt=5000, last_round=1171, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:22:44.980725, n_estimator=10, cnt=1000, last_round=1170, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:23:14.871868, n_estimator=10, cnt=2000, last_round=1170, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:23:44.799870, n_estimator=10, cnt=3000, last_round=1170, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:24:14.733295, n_estimator=10, cnt=4000, last_round=1170, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:24:44.672081, n_estimator=10, cnt=5000, last_round=1170, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:25:14.444965, n_estimator=10, cnt=1000, last_round=1169, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:25:44.242711, n_estimator=10, cnt=2000, last_round=1169, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:26:14.024799, n_estimator=10, cnt=3000, last_round=1169, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:26:43.812789, n_estimator=10, cnt=4000, last_round=1169, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:27:13.623243, n_estimator=10, cnt=5000, last_round=1169, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:27:43.518435, n_estimator=10, cnt=1000, last_round=1168, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:28:13.370286, n_estimator=10, cnt=2000, last_round=1168, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:28:43.266109, n_estimator=10, cnt=3000, last_round=1168, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:29:13.158574, n_estimator=10, cnt=4000, last_round=1168, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:29:43.017736, n_estimator=10, cnt=5000, last_round=1168, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:30:12.806510, n_estimator=10, cnt=1000, last_round=1167, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:30:42.608339, n_estimator=10, cnt=2000, last_round=1167, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:31:12.215536, n_estimator=10, cnt=3000, last_round=1167, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:31:41.692527, n_estimator=10, cnt=4000, last_round=1167, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:32:11.143140, n_estimator=10, cnt=5000, last_round=1167, random_state=199990, data_length=400]
# proceed [now=2025-06-12 20:32:41.099818, n_estimator=10, cnt=1000, last_round=1166, random_state=159990, data_length=400]
# proceed [now=2025-06-12 20:33:10.780795, n_estimator=10, cnt=2000, last_round=1166, random_state=169990, data_length=400]
# proceed [now=2025-06-12 20:33:40.470249, n_estimator=10, cnt=3000, last_round=1166, random_state=179990, data_length=400]
# proceed [now=2025-06-12 20:34:10.127627, n_estimator=10, cnt=4000, last_round=1166, random_state=189990, data_length=400]
# proceed [now=2025-06-12 20:34:39.879958, n_estimator=10, cnt=5000, last_round=1166, random_state=199990, data_length=400]
# completed [now=2025-06-12 20:34:39.880174]
# start to read and write data: [now=2025-06-12 20:34:39.880188]
# complete to read and data: [now=2025-06-12 20:36:42.953415]

# %%
parameters = {
    "n_estimators": [25,10],
    "data_lengths": [400],
    "random_state_gap": 10,
    "random_state_begin": 50000,
    "random_state_end": 100000,
    "last_rounds": [1175, 1174, 1173, 1172, 1171, 1170, 1169, 1168, 1167, 1166],
}
version="T_01_08"
result_sets = main(parameters=parameters, version=version, sum_min=0, sum_max=-1, trial=1, write_to_db=True)
# Out:
# start   [now=2025-06-12 21:14:33.995039]
# proceed [now=2025-06-12 21:15:19.547135, n_estimator=25, cnt=1000, last_round=1175, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:16:08.253959, n_estimator=25, cnt=2000, last_round=1175, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:16:54.371636, n_estimator=25, cnt=3000, last_round=1175, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:17:40.349232, n_estimator=25, cnt=4000, last_round=1175, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:18:29.254669, n_estimator=25, cnt=5000, last_round=1175, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:19:15.281548, n_estimator=25, cnt=1000, last_round=1174, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:20:01.278225, n_estimator=25, cnt=2000, last_round=1174, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:20:50.293894, n_estimator=25, cnt=3000, last_round=1174, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:21:36.015618, n_estimator=25, cnt=4000, last_round=1174, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:22:22.232654, n_estimator=25, cnt=5000, last_round=1174, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:23:11.857713, n_estimator=25, cnt=1000, last_round=1173, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:23:57.777111, n_estimator=25, cnt=2000, last_round=1173, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:24:43.820878, n_estimator=25, cnt=3000, last_round=1173, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:25:33.396264, n_estimator=25, cnt=4000, last_round=1173, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:26:19.563420, n_estimator=25, cnt=5000, last_round=1173, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:27:05.609242, n_estimator=25, cnt=1000, last_round=1172, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:27:55.302716, n_estimator=25, cnt=2000, last_round=1172, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:28:41.223163, n_estimator=25, cnt=3000, last_round=1172, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:29:27.157944, n_estimator=25, cnt=4000, last_round=1172, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:30:13.058803, n_estimator=25, cnt=5000, last_round=1172, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:31:02.933834, n_estimator=25, cnt=1000, last_round=1171, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:31:49.020782, n_estimator=25, cnt=2000, last_round=1171, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:32:35.061689, n_estimator=25, cnt=3000, last_round=1171, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:33:24.636450, n_estimator=25, cnt=4000, last_round=1171, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:34:10.631154, n_estimator=25, cnt=5000, last_round=1171, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:34:56.652747, n_estimator=25, cnt=1000, last_round=1170, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:35:46.292766, n_estimator=25, cnt=2000, last_round=1170, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:36:32.320199, n_estimator=25, cnt=3000, last_round=1170, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:37:18.380983, n_estimator=25, cnt=4000, last_round=1170, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:38:08.005269, n_estimator=25, cnt=5000, last_round=1170, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:38:53.913381, n_estimator=25, cnt=1000, last_round=1169, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:39:39.781542, n_estimator=25, cnt=2000, last_round=1169, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:40:29.289675, n_estimator=25, cnt=3000, last_round=1169, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:41:15.210829, n_estimator=25, cnt=4000, last_round=1169, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:42:01.097919, n_estimator=25, cnt=5000, last_round=1169, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:42:47.073361, n_estimator=25, cnt=1000, last_round=1168, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:43:36.940039, n_estimator=25, cnt=2000, last_round=1168, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:44:22.892420, n_estimator=25, cnt=3000, last_round=1168, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:45:08.331260, n_estimator=25, cnt=4000, last_round=1168, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:46:00.544053, n_estimator=25, cnt=5000, last_round=1168, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:46:47.444412, n_estimator=25, cnt=1000, last_round=1167, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:47:33.619583, n_estimator=25, cnt=2000, last_round=1167, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:48:23.273085, n_estimator=25, cnt=3000, last_round=1167, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:49:09.302259, n_estimator=25, cnt=4000, last_round=1167, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:49:55.463406, n_estimator=25, cnt=5000, last_round=1167, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:50:45.076949, n_estimator=25, cnt=1000, last_round=1166, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:51:31.093302, n_estimator=25, cnt=2000, last_round=1166, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:52:17.214773, n_estimator=25, cnt=3000, last_round=1166, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:53:07.280889, n_estimator=25, cnt=4000, last_round=1166, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:53:53.222060, n_estimator=25, cnt=5000, last_round=1166, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:54:16.084504, n_estimator=10, cnt=1000, last_round=1175, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:54:35.344539, n_estimator=10, cnt=2000, last_round=1175, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:54:58.205526, n_estimator=10, cnt=3000, last_round=1175, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:55:17.422431, n_estimator=10, cnt=4000, last_round=1175, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:55:40.249721, n_estimator=10, cnt=5000, last_round=1175, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:56:03.316230, n_estimator=10, cnt=1000, last_round=1174, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:56:22.726265, n_estimator=10, cnt=2000, last_round=1174, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:56:45.663607, n_estimator=10, cnt=3000, last_round=1174, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:57:05.072069, n_estimator=10, cnt=4000, last_round=1174, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:57:27.900886, n_estimator=10, cnt=5000, last_round=1174, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:57:50.776789, n_estimator=10, cnt=1000, last_round=1173, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:58:10.043981, n_estimator=10, cnt=2000, last_round=1173, random_state=69990, data_length=400]
# proceed [now=2025-06-12 21:58:33.148137, n_estimator=10, cnt=3000, last_round=1173, random_state=79990, data_length=400]
# proceed [now=2025-06-12 21:58:52.369334, n_estimator=10, cnt=4000, last_round=1173, random_state=89990, data_length=400]
# proceed [now=2025-06-12 21:59:15.249447, n_estimator=10, cnt=5000, last_round=1173, random_state=99990, data_length=400]
# proceed [now=2025-06-12 21:59:37.873033, n_estimator=10, cnt=1000, last_round=1172, random_state=59990, data_length=400]
# proceed [now=2025-06-12 21:59:56.992799, n_estimator=10, cnt=2000, last_round=1172, random_state=69990, data_length=400]
# proceed [now=2025-06-12 22:00:19.619886, n_estimator=10, cnt=3000, last_round=1172, random_state=79990, data_length=400]
# proceed [now=2025-06-12 22:00:38.596217, n_estimator=10, cnt=4000, last_round=1172, random_state=89990, data_length=400]
# proceed [now=2025-06-12 22:01:01.190902, n_estimator=10, cnt=5000, last_round=1172, random_state=99990, data_length=400]
# proceed [now=2025-06-12 22:01:23.728872, n_estimator=10, cnt=1000, last_round=1171, random_state=59990, data_length=400]
# proceed [now=2025-06-12 22:01:42.669194, n_estimator=10, cnt=2000, last_round=1171, random_state=69990, data_length=400]
# proceed [now=2025-06-12 22:02:05.235032, n_estimator=10, cnt=3000, last_round=1171, random_state=79990, data_length=400]
# proceed [now=2025-06-12 22:02:24.224848, n_estimator=10, cnt=4000, last_round=1171, random_state=89990, data_length=400]
# proceed [now=2025-06-12 22:02:46.773302, n_estimator=10, cnt=5000, last_round=1171, random_state=99990, data_length=400]
# proceed [now=2025-06-12 22:03:05.686160, n_estimator=10, cnt=1000, last_round=1170, random_state=59990, data_length=400]
# proceed [now=2025-06-12 22:03:28.424952, n_estimator=10, cnt=2000, last_round=1170, random_state=69990, data_length=400]
# proceed [now=2025-06-12 22:03:50.994427, n_estimator=10, cnt=3000, last_round=1170, random_state=79990, data_length=400]
# proceed [now=2025-06-12 22:04:10.127884, n_estimator=10, cnt=4000, last_round=1170, random_state=89990, data_length=400]
# proceed [now=2025-06-12 22:04:32.959549, n_estimator=10, cnt=5000, last_round=1170, random_state=99990, data_length=400]
# proceed [now=2025-06-12 22:04:52.039452, n_estimator=10, cnt=1000, last_round=1169, random_state=59990, data_length=400]
# proceed [now=2025-06-12 22:05:14.638422, n_estimator=10, cnt=2000, last_round=1169, random_state=69990, data_length=400]
# proceed [now=2025-06-12 22:05:37.155527, n_estimator=10, cnt=3000, last_round=1169, random_state=79990, data_length=400]
# proceed [now=2025-06-12 22:05:56.110792, n_estimator=10, cnt=4000, last_round=1169, random_state=89990, data_length=400]
# proceed [now=2025-06-12 22:06:18.778551, n_estimator=10, cnt=5000, last_round=1169, random_state=99990, data_length=400]
# proceed [now=2025-06-12 22:06:37.677079, n_estimator=10, cnt=1000, last_round=1168, random_state=59990, data_length=400]
# proceed [now=2025-06-12 22:07:00.183693, n_estimator=10, cnt=2000, last_round=1168, random_state=69990, data_length=400]
# proceed [now=2025-06-12 22:07:22.669053, n_estimator=10, cnt=3000, last_round=1168, random_state=79990, data_length=400]
# proceed [now=2025-06-12 22:07:41.608478, n_estimator=10, cnt=4000, last_round=1168, random_state=89990, data_length=400]
# proceed [now=2025-06-12 22:08:00.481135, n_estimator=10, cnt=5000, last_round=1168, random_state=99990, data_length=400]
# proceed [now=2025-06-12 22:08:24.887226, n_estimator=10, cnt=1000, last_round=1167, random_state=59990, data_length=400]
# proceed [now=2025-06-12 22:08:44.146629, n_estimator=10, cnt=2000, last_round=1167, random_state=69990, data_length=400]
# proceed [now=2025-06-12 22:09:06.277010, n_estimator=10, cnt=3000, last_round=1167, random_state=79990, data_length=400]
# proceed [now=2025-06-12 22:09:28.519835, n_estimator=10, cnt=4000, last_round=1167, random_state=89990, data_length=400]
# proceed [now=2025-06-12 22:09:47.788086, n_estimator=10, cnt=5000, last_round=1167, random_state=99990, data_length=400]
# proceed [now=2025-06-12 22:10:09.911215, n_estimator=10, cnt=1000, last_round=1166, random_state=59990, data_length=400]
# proceed [now=2025-06-12 22:10:29.144829, n_estimator=10, cnt=2000, last_round=1166, random_state=69990, data_length=400]
# proceed [now=2025-06-12 22:10:51.284867, n_estimator=10, cnt=3000, last_round=1166, random_state=79990, data_length=400]
# proceed [now=2025-06-12 22:11:13.442215, n_estimator=10, cnt=4000, last_round=1166, random_state=89990, data_length=400]
# proceed [now=2025-06-12 22:11:33.207640, n_estimator=10, cnt=5000, last_round=1166, random_state=99990, data_length=400]
# completed [now=2025-06-12 22:11:33.207791]
# start to read and write data: [now=2025-06-12 22:11:33.207806]
# complete to read and data: [now=2025-06-12 22:13:45.007284]

# %%
parameters = {
    "n_estimators": [25,10],
    "data_lengths": [400],
    "random_state_gap": 10,
    "random_state_begin": 0,
    "random_state_end": 50000,
    "last_rounds": [1175, 1174, 1173, 1172, 1171, 1170, 1169, 1168, 1167, 1166],
}
version="T_01_08"
result_sets = main(parameters=parameters, version=version, sum_min=0, sum_max=-1, trial=1, write_to_db=True)
# Out:
# start   [now=2025-06-12 22:20:51.525562]
# proceed [now=2025-06-12 22:21:37.785743, n_estimator=25, cnt=1000, last_round=1175, random_state=9990, data_length=400]
# proceed [now=2025-06-12 22:22:27.019867, n_estimator=25, cnt=2000, last_round=1175, random_state=19990, data_length=400]
# proceed [now=2025-06-12 22:23:13.264175, n_estimator=25, cnt=3000, last_round=1175, random_state=29990, data_length=400]
# proceed [now=2025-06-12 22:23:59.746643, n_estimator=25, cnt=4000, last_round=1175, random_state=39990, data_length=400]
# proceed [now=2025-06-12 22:24:49.414732, n_estimator=25, cnt=5000, last_round=1175, random_state=49990, data_length=400]
# proceed [now=2025-06-12 22:25:36.239075, n_estimator=25, cnt=1000, last_round=1174, random_state=9990, data_length=400]
# proceed [now=2025-06-12 22:26:22.980424, n_estimator=25, cnt=2000, last_round=1174, random_state=19990, data_length=400]
# proceed [now=2025-06-12 22:27:12.514231, n_estimator=25, cnt=3000, last_round=1174, random_state=29990, data_length=400]
# proceed [now=2025-06-12 22:27:59.404379, n_estimator=25, cnt=4000, last_round=1174, random_state=39990, data_length=400]
# proceed [now=2025-06-12 22:28:49.455699, n_estimator=25, cnt=5000, last_round=1174, random_state=49990, data_length=400]
# proceed [now=2025-06-12 22:29:35.754269, n_estimator=25, cnt=1000, last_round=1173, random_state=9990, data_length=400]
# proceed [now=2025-06-12 22:30:21.717733, n_estimator=25, cnt=2000, last_round=1173, random_state=19990, data_length=400]
# proceed [now=2025-06-12 22:31:10.633674, n_estimator=25, cnt=3000, last_round=1173, random_state=29990, data_length=400]
# proceed [now=2025-06-12 22:31:56.911333, n_estimator=25, cnt=4000, last_round=1173, random_state=39990, data_length=400]
# proceed [now=2025-06-12 22:32:43.643785, n_estimator=25, cnt=5000, last_round=1173, random_state=49990, data_length=400]
# proceed [now=2025-06-12 22:33:33.396134, n_estimator=25, cnt=1000, last_round=1172, random_state=9990, data_length=400]
# proceed [now=2025-06-12 22:34:20.723753, n_estimator=25, cnt=2000, last_round=1172, random_state=19990, data_length=400]
# proceed [now=2025-06-12 22:35:07.397638, n_estimator=25, cnt=3000, last_round=1172, random_state=29990, data_length=400]
# proceed [now=2025-06-12 22:35:57.575944, n_estimator=25, cnt=4000, last_round=1172, random_state=39990, data_length=400]
# proceed [now=2025-06-12 22:36:44.573512, n_estimator=25, cnt=5000, last_round=1172, random_state=49990, data_length=400]
# proceed [now=2025-06-12 22:37:31.247791, n_estimator=25, cnt=1000, last_round=1171, random_state=9990, data_length=400]
# proceed [now=2025-06-12 22:38:21.611726, n_estimator=25, cnt=2000, last_round=1171, random_state=19990, data_length=400]
# proceed [now=2025-06-12 22:39:09.435536, n_estimator=25, cnt=3000, last_round=1171, random_state=29990, data_length=400]
# proceed [now=2025-06-12 22:39:59.533015, n_estimator=25, cnt=4000, last_round=1171, random_state=39990, data_length=400]
# proceed [now=2025-06-12 22:40:47.524097, n_estimator=25, cnt=5000, last_round=1171, random_state=49990, data_length=400]
# proceed [now=2025-06-12 22:41:35.156578, n_estimator=25, cnt=1000, last_round=1170, random_state=9990, data_length=400]
# proceed [now=2025-06-12 22:42:26.356853, n_estimator=25, cnt=2000, last_round=1170, random_state=19990, data_length=400]
# proceed [now=2025-06-12 22:43:13.481923, n_estimator=25, cnt=3000, last_round=1170, random_state=29990, data_length=400]
# proceed [now=2025-06-12 22:44:00.576021, n_estimator=25, cnt=4000, last_round=1170, random_state=39990, data_length=400]
# proceed [now=2025-06-12 22:44:51.267309, n_estimator=25, cnt=5000, last_round=1170, random_state=49990, data_length=400]
# proceed [now=2025-06-12 22:45:40.171325, n_estimator=25, cnt=1000, last_round=1169, random_state=9990, data_length=400]
# proceed [now=2025-06-12 22:46:31.405556, n_estimator=25, cnt=2000, last_round=1169, random_state=19990, data_length=400]
# proceed [now=2025-06-12 22:47:18.916696, n_estimator=25, cnt=3000, last_round=1169, random_state=29990, data_length=400]
# proceed [now=2025-06-12 22:48:06.343738, n_estimator=25, cnt=4000, last_round=1169, random_state=39990, data_length=400]
# proceed [now=2025-06-12 22:48:57.515891, n_estimator=25, cnt=5000, last_round=1169, random_state=49990, data_length=400]
# proceed [now=2025-06-12 22:49:45.047632, n_estimator=25, cnt=1000, last_round=1168, random_state=9990, data_length=400]
# proceed [now=2025-06-12 22:50:35.708691, n_estimator=25, cnt=2000, last_round=1168, random_state=19990, data_length=400]
# proceed [now=2025-06-12 22:51:23.363410, n_estimator=25, cnt=3000, last_round=1168, random_state=29990, data_length=400]
# proceed [now=2025-06-12 22:52:10.770409, n_estimator=25, cnt=4000, last_round=1168, random_state=39990, data_length=400]
# proceed [now=2025-06-12 22:53:02.255523, n_estimator=25, cnt=5000, last_round=1168, random_state=49990, data_length=400]
# proceed [now=2025-06-12 22:53:49.506737, n_estimator=25, cnt=1000, last_round=1167, random_state=9990, data_length=400]
# proceed [now=2025-06-12 22:54:40.442439, n_estimator=25, cnt=2000, last_round=1167, random_state=19990, data_length=400]
# proceed [now=2025-06-12 22:55:28.591696, n_estimator=25, cnt=3000, last_round=1167, random_state=29990, data_length=400]
# proceed [now=2025-06-12 22:56:16.630332, n_estimator=25, cnt=4000, last_round=1167, random_state=39990, data_length=400]
# proceed [now=2025-06-12 22:57:07.453358, n_estimator=25, cnt=5000, last_round=1167, random_state=49990, data_length=400]
# proceed [now=2025-06-12 22:57:54.612587, n_estimator=25, cnt=1000, last_round=1166, random_state=9990, data_length=400]
# proceed [now=2025-06-12 22:58:44.566324, n_estimator=25, cnt=2000, last_round=1166, random_state=19990, data_length=400]
# proceed [now=2025-06-12 22:59:31.760637, n_estimator=25, cnt=3000, last_round=1166, random_state=29990, data_length=400]
# proceed [now=2025-06-12 23:00:18.634253, n_estimator=25, cnt=4000, last_round=1166, random_state=39990, data_length=400]
# proceed [now=2025-06-12 23:01:08.196797, n_estimator=25, cnt=5000, last_round=1166, random_state=49990, data_length=400]
# proceed [now=2025-06-12 23:01:28.193387, n_estimator=10, cnt=1000, last_round=1175, random_state=9990, data_length=400]
# proceed [now=2025-06-12 23:01:51.163143, n_estimator=10, cnt=2000, last_round=1175, random_state=19990, data_length=400]
# proceed [now=2025-06-12 23:02:11.120917, n_estimator=10, cnt=3000, last_round=1175, random_state=29990, data_length=400]
# proceed [now=2025-06-12 23:02:34.526547, n_estimator=10, cnt=4000, last_round=1175, random_state=39990, data_length=400]
# proceed [now=2025-06-12 23:02:57.656363, n_estimator=10, cnt=5000, last_round=1175, random_state=49990, data_length=400]
# proceed [now=2025-06-12 23:03:18.272773, n_estimator=10, cnt=1000, last_round=1174, random_state=9990, data_length=400]
# proceed [now=2025-06-12 23:03:41.825789, n_estimator=10, cnt=2000, last_round=1174, random_state=19990, data_length=400]
# proceed [now=2025-06-12 23:04:05.443388, n_estimator=10, cnt=3000, last_round=1174, random_state=29990, data_length=400]
# proceed [now=2025-06-12 23:04:25.718932, n_estimator=10, cnt=4000, last_round=1174, random_state=39990, data_length=400]
# proceed [now=2025-06-12 23:04:49.860761, n_estimator=10, cnt=5000, last_round=1174, random_state=49990, data_length=400]
# proceed [now=2025-06-12 23:05:13.983268, n_estimator=10, cnt=1000, last_round=1173, random_state=9990, data_length=400]
# proceed [now=2025-06-12 23:05:34.491102, n_estimator=10, cnt=2000, last_round=1173, random_state=19990, data_length=400]
# proceed [now=2025-06-12 23:05:57.736172, n_estimator=10, cnt=3000, last_round=1173, random_state=29990, data_length=400]
# proceed [now=2025-06-12 23:06:17.924328, n_estimator=10, cnt=4000, last_round=1173, random_state=39990, data_length=400]
# proceed [now=2025-06-12 23:06:40.917003, n_estimator=10, cnt=5000, last_round=1173, random_state=49990, data_length=400]
# proceed [now=2025-06-12 23:07:04.178168, n_estimator=10, cnt=1000, last_round=1172, random_state=9990, data_length=400]
# proceed [now=2025-06-12 23:07:24.822105, n_estimator=10, cnt=2000, last_round=1172, random_state=19990, data_length=400]
# proceed [now=2025-06-12 23:07:48.037456, n_estimator=10, cnt=3000, last_round=1172, random_state=29990, data_length=400]
# proceed [now=2025-06-12 23:08:11.389010, n_estimator=10, cnt=4000, last_round=1172, random_state=39990, data_length=400]
# proceed [now=2025-06-12 23:08:31.703904, n_estimator=10, cnt=5000, last_round=1172, random_state=49990, data_length=400]
# proceed [now=2025-06-12 23:08:55.426153, n_estimator=10, cnt=1000, last_round=1171, random_state=9990, data_length=400]
# proceed [now=2025-06-12 23:09:19.482974, n_estimator=10, cnt=2000, last_round=1171, random_state=19990, data_length=400]
# proceed [now=2025-06-12 23:09:40.392555, n_estimator=10, cnt=3000, last_round=1171, random_state=29990, data_length=400]
# proceed [now=2025-06-12 23:10:03.189100, n_estimator=10, cnt=4000, last_round=1171, random_state=39990, data_length=400]
# proceed [now=2025-06-12 23:10:23.193548, n_estimator=10, cnt=5000, last_round=1171, random_state=49990, data_length=400]
# proceed [now=2025-06-12 23:10:46.658768, n_estimator=10, cnt=1000, last_round=1170, random_state=9990, data_length=400]
# proceed [now=2025-06-12 23:11:09.692856, n_estimator=10, cnt=2000, last_round=1170, random_state=19990, data_length=400]
# proceed [now=2025-06-12 23:11:30.361306, n_estimator=10, cnt=3000, last_round=1170, random_state=29990, data_length=400]
# proceed [now=2025-06-12 23:11:53.472123, n_estimator=10, cnt=4000, last_round=1170, random_state=39990, data_length=400]
# proceed [now=2025-06-12 23:12:16.394056, n_estimator=10, cnt=5000, last_round=1170, random_state=49990, data_length=400]
# proceed [now=2025-06-12 23:12:36.442620, n_estimator=10, cnt=1000, last_round=1169, random_state=9990, data_length=400]
# proceed [now=2025-06-12 23:12:59.464825, n_estimator=10, cnt=2000, last_round=1169, random_state=19990, data_length=400]
# proceed [now=2025-06-12 23:13:19.578407, n_estimator=10, cnt=3000, last_round=1169, random_state=29990, data_length=400]
# proceed [now=2025-06-12 23:13:42.498114, n_estimator=10, cnt=4000, last_round=1169, random_state=39990, data_length=400]
# proceed [now=2025-06-12 23:14:05.493378, n_estimator=10, cnt=5000, last_round=1169, random_state=49990, data_length=400]
# proceed [now=2025-06-12 23:14:26.032745, n_estimator=10, cnt=1000, last_round=1168, random_state=9990, data_length=400]
# proceed [now=2025-06-12 23:14:49.254707, n_estimator=10, cnt=2000, last_round=1168, random_state=19990, data_length=400]
# proceed [now=2025-06-12 23:15:12.605957, n_estimator=10, cnt=3000, last_round=1168, random_state=29990, data_length=400]
# proceed [now=2025-06-12 23:15:32.753973, n_estimator=10, cnt=4000, last_round=1168, random_state=39990, data_length=400]
# proceed [now=2025-06-12 23:15:56.510493, n_estimator=10, cnt=5000, last_round=1168, random_state=49990, data_length=400]
# proceed [now=2025-06-12 23:16:17.118703, n_estimator=10, cnt=1000, last_round=1167, random_state=9990, data_length=400]
# proceed [now=2025-06-12 23:16:40.250884, n_estimator=10, cnt=2000, last_round=1167, random_state=19990, data_length=400]
# proceed [now=2025-06-12 23:17:03.454550, n_estimator=10, cnt=3000, last_round=1167, random_state=29990, data_length=400]
# proceed [now=2025-06-12 23:17:23.489347, n_estimator=10, cnt=4000, last_round=1167, random_state=39990, data_length=400]
# proceed [now=2025-06-12 23:17:46.416327, n_estimator=10, cnt=5000, last_round=1167, random_state=49990, data_length=400]
# proceed [now=2025-06-12 23:18:09.497719, n_estimator=10, cnt=1000, last_round=1166, random_state=9990, data_length=400]
# proceed [now=2025-06-12 23:18:29.566569, n_estimator=10, cnt=2000, last_round=1166, random_state=19990, data_length=400]
# proceed [now=2025-06-12 23:18:52.589087, n_estimator=10, cnt=3000, last_round=1166, random_state=29990, data_length=400]
# proceed [now=2025-06-12 23:19:12.747085, n_estimator=10, cnt=4000, last_round=1166, random_state=39990, data_length=400]
# proceed [now=2025-06-12 23:19:35.987043, n_estimator=10, cnt=5000, last_round=1166, random_state=49990, data_length=400]
# completed [now=2025-06-12 23:19:35.987184]
# start to read and write data: [now=2025-06-12 23:19:35.987199]

# %%
parameters = {
    "n_estimators": [25,10],
    "data_lengths": [400],
    "random_state_gap": 10,
    "random_state_begin": 400000,
    "random_state_end": 450000,
    "last_rounds": [1175, 1174, 1173, 1172, 1171, 1170, 1169, 1168, 1167, 1166],
}
version="T_01_08"
result_sets = main(parameters=parameters, version=version, sum_min=0, sum_max=-1, trial=1, write_to_db=True)
# Out:
# start   [now=2025-06-12 23:22:16.667982]
# proceed [now=2025-06-12 23:23:03.381821, n_estimator=25, cnt=1000, last_round=1175, random_state=409990, data_length=400]
# proceed [now=2025-06-12 23:23:51.569630, n_estimator=25, cnt=2000, last_round=1175, random_state=419990, data_length=400]
# proceed [now=2025-06-12 23:24:38.801259, n_estimator=25, cnt=3000, last_round=1175, random_state=429990, data_length=400]
# proceed [now=2025-06-12 23:25:28.975733, n_estimator=25, cnt=4000, last_round=1175, random_state=439990, data_length=400]
# proceed [now=2025-06-12 23:26:16.313665, n_estimator=25, cnt=5000, last_round=1175, random_state=449990, data_length=400]
# proceed [now=2025-06-12 23:27:02.797789, n_estimator=25, cnt=1000, last_round=1174, random_state=409990, data_length=400]
# proceed [now=2025-06-12 23:27:52.023784, n_estimator=25, cnt=2000, last_round=1174, random_state=419990, data_length=400]
# proceed [now=2025-06-12 23:28:38.219156, n_estimator=25, cnt=3000, last_round=1174, random_state=429990, data_length=400]
# proceed [now=2025-06-12 23:29:25.074165, n_estimator=25, cnt=4000, last_round=1174, random_state=439990, data_length=400]
# proceed [now=2025-06-12 23:30:14.606112, n_estimator=25, cnt=5000, last_round=1174, random_state=449990, data_length=400]
# proceed [now=2025-06-12 23:31:00.991861, n_estimator=25, cnt=1000, last_round=1173, random_state=409990, data_length=400]
# proceed [now=2025-06-12 23:31:46.641356, n_estimator=25, cnt=2000, last_round=1173, random_state=419990, data_length=400]
# proceed [now=2025-06-12 23:32:35.133456, n_estimator=25, cnt=3000, last_round=1173, random_state=429990, data_length=400]
# proceed [now=2025-06-12 23:33:20.797145, n_estimator=25, cnt=4000, last_round=1173, random_state=439990, data_length=400]
# proceed [now=2025-06-12 23:34:06.234893, n_estimator=25, cnt=5000, last_round=1173, random_state=449990, data_length=400]
# proceed [now=2025-06-12 23:34:54.748315, n_estimator=25, cnt=1000, last_round=1172, random_state=409990, data_length=400]
# proceed [now=2025-06-12 23:35:40.196616, n_estimator=25, cnt=2000, last_round=1172, random_state=419990, data_length=400]
# proceed [now=2025-06-12 23:36:25.598773, n_estimator=25, cnt=3000, last_round=1172, random_state=429990, data_length=400]
# proceed [now=2025-06-12 23:37:13.968384, n_estimator=25, cnt=4000, last_round=1172, random_state=439990, data_length=400]
# proceed [now=2025-06-12 23:37:59.410175, n_estimator=25, cnt=5000, last_round=1172, random_state=449990, data_length=400]
# proceed [now=2025-06-12 23:38:44.900436, n_estimator=25, cnt=1000, last_round=1171, random_state=409990, data_length=400]
# proceed [now=2025-06-12 23:39:33.291363, n_estimator=25, cnt=2000, last_round=1171, random_state=419990, data_length=400]
# proceed [now=2025-06-12 23:40:18.859322, n_estimator=25, cnt=3000, last_round=1171, random_state=429990, data_length=400]
# proceed [now=2025-06-12 23:41:04.312019, n_estimator=25, cnt=4000, last_round=1171, random_state=439990, data_length=400]
# proceed [now=2025-06-12 23:41:53.978278, n_estimator=25, cnt=5000, last_round=1171, random_state=449990, data_length=400]
# proceed [now=2025-06-12 23:42:40.096845, n_estimator=25, cnt=1000, last_round=1170, random_state=409990, data_length=400]
# proceed [now=2025-06-12 23:43:27.787595, n_estimator=25, cnt=2000, last_round=1170, random_state=419990, data_length=400]
# proceed [now=2025-06-12 23:44:18.265345, n_estimator=25, cnt=3000, last_round=1170, random_state=429990, data_length=400]
# proceed [now=2025-06-12 23:45:06.073260, n_estimator=25, cnt=4000, last_round=1170, random_state=439990, data_length=400]
# proceed [now=2025-06-12 23:45:53.458795, n_estimator=25, cnt=5000, last_round=1170, random_state=449990, data_length=400]
# proceed [now=2025-06-12 23:46:46.725424, n_estimator=25, cnt=1000, last_round=1169, random_state=409990, data_length=400]
# proceed [now=2025-06-12 23:47:36.096017, n_estimator=25, cnt=2000, last_round=1169, random_state=419990, data_length=400]
# proceed [now=2025-06-12 23:48:30.554495, n_estimator=25, cnt=3000, last_round=1169, random_state=429990, data_length=400]
# proceed [now=2025-06-12 23:49:21.327857, n_estimator=25, cnt=4000, last_round=1169, random_state=439990, data_length=400]
# proceed [now=2025-06-12 23:50:14.053726, n_estimator=25, cnt=5000, last_round=1169, random_state=449990, data_length=400]
# proceed [now=2025-06-12 23:51:02.643044, n_estimator=25, cnt=1000, last_round=1168, random_state=409990, data_length=400]
# proceed [now=2025-06-12 23:51:54.269155, n_estimator=25, cnt=2000, last_round=1168, random_state=419990, data_length=400]
# proceed [now=2025-06-12 23:52:47.706406, n_estimator=25, cnt=3000, last_round=1168, random_state=429990, data_length=400]
# proceed [now=2025-06-12 23:53:47.917515, n_estimator=25, cnt=4000, last_round=1168, random_state=439990, data_length=400]
# proceed [now=2025-06-12 23:54:43.984533, n_estimator=25, cnt=5000, last_round=1168, random_state=449990, data_length=400]
# proceed [now=2025-06-12 23:55:42.780846, n_estimator=25, cnt=1000, last_round=1167, random_state=409990, data_length=400]
# proceed [now=2025-06-12 23:56:43.063956, n_estimator=25, cnt=2000, last_round=1167, random_state=419990, data_length=400]
# proceed [now=2025-06-12 23:57:39.803629, n_estimator=25, cnt=3000, last_round=1167, random_state=429990, data_length=400]
# proceed [now=2025-06-12 23:58:40.252947, n_estimator=25, cnt=4000, last_round=1167, random_state=439990, data_length=400]
# proceed [now=2025-06-12 23:59:40.622809, n_estimator=25, cnt=5000, last_round=1167, random_state=449990, data_length=400]
# proceed [now=2025-06-13 00:00:36.703200, n_estimator=25, cnt=1000, last_round=1166, random_state=409990, data_length=400]
# proceed [now=2025-06-13 00:01:35.893841, n_estimator=25, cnt=2000, last_round=1166, random_state=419990, data_length=400]
# proceed [now=2025-06-13 00:02:31.447326, n_estimator=25, cnt=3000, last_round=1166, random_state=429990, data_length=400]
# proceed [now=2025-06-13 00:03:22.825086, n_estimator=25, cnt=4000, last_round=1166, random_state=439990, data_length=400]
# proceed [now=2025-06-13 00:04:21.757811, n_estimator=25, cnt=5000, last_round=1166, random_state=449990, data_length=400]
# proceed [now=2025-06-13 00:04:49.098427, n_estimator=10, cnt=1000, last_round=1175, random_state=409990, data_length=400]
# proceed [now=2025-06-13 00:05:13.429004, n_estimator=10, cnt=2000, last_round=1175, random_state=419990, data_length=400]
# proceed [now=2025-06-13 00:05:42.393989, n_estimator=10, cnt=3000, last_round=1175, random_state=429990, data_length=400]
# proceed [now=2025-06-13 00:06:09.732726, n_estimator=10, cnt=4000, last_round=1175, random_state=439990, data_length=400]
# proceed [now=2025-06-13 00:06:37.320799, n_estimator=10, cnt=5000, last_round=1175, random_state=449990, data_length=400]
# proceed [now=2025-06-13 00:07:01.737641, n_estimator=10, cnt=1000, last_round=1174, random_state=409990, data_length=400]
# proceed [now=2025-06-13 00:07:28.677110, n_estimator=10, cnt=2000, last_round=1174, random_state=419990, data_length=400]
# proceed [now=2025-06-13 00:07:57.129229, n_estimator=10, cnt=3000, last_round=1174, random_state=429990, data_length=400]
# proceed [now=2025-06-13 00:08:23.370635, n_estimator=10, cnt=4000, last_round=1174, random_state=439990, data_length=400]
# proceed [now=2025-06-13 00:08:45.473974, n_estimator=10, cnt=5000, last_round=1174, random_state=449990, data_length=400]
# proceed [now=2025-06-13 00:09:12.932189, n_estimator=10, cnt=1000, last_round=1173, random_state=409990, data_length=400]
# proceed [now=2025-06-13 00:09:40.895029, n_estimator=10, cnt=2000, last_round=1173, random_state=419990, data_length=400]
# proceed [now=2025-06-13 00:10:11.392238, n_estimator=10, cnt=3000, last_round=1173, random_state=429990, data_length=400]
# proceed [now=2025-06-13 00:10:36.656794, n_estimator=10, cnt=4000, last_round=1173, random_state=439990, data_length=400]
# proceed [now=2025-06-13 00:11:04.246141, n_estimator=10, cnt=5000, last_round=1173, random_state=449990, data_length=400]
# proceed [now=2025-06-13 00:11:31.905641, n_estimator=10, cnt=1000, last_round=1172, random_state=409990, data_length=400]
# proceed [now=2025-06-13 00:11:59.874415, n_estimator=10, cnt=2000, last_round=1172, random_state=419990, data_length=400]
# proceed [now=2025-06-13 00:12:27.880662, n_estimator=10, cnt=3000, last_round=1172, random_state=429990, data_length=400]
# proceed [now=2025-06-13 00:12:52.575811, n_estimator=10, cnt=4000, last_round=1172, random_state=439990, data_length=400]
# proceed [now=2025-06-13 00:13:20.123077, n_estimator=10, cnt=5000, last_round=1172, random_state=449990, data_length=400]
# proceed [now=2025-06-13 00:13:46.334735, n_estimator=10, cnt=1000, last_round=1171, random_state=409990, data_length=400]
# proceed [now=2025-06-13 00:14:08.675103, n_estimator=10, cnt=2000, last_round=1171, random_state=419990, data_length=400]
# proceed [now=2025-06-13 00:14:33.552191, n_estimator=10, cnt=3000, last_round=1171, random_state=429990, data_length=400]
# proceed [now=2025-06-13 00:15:00.637284, n_estimator=10, cnt=4000, last_round=1171, random_state=439990, data_length=400]
# proceed [now=2025-06-13 00:15:28.436373, n_estimator=10, cnt=5000, last_round=1171, random_state=449990, data_length=400]
# proceed [now=2025-06-13 00:15:53.861458, n_estimator=10, cnt=1000, last_round=1170, random_state=409990, data_length=400]
# proceed [now=2025-06-13 00:16:21.716213, n_estimator=10, cnt=2000, last_round=1170, random_state=419990, data_length=400]
# proceed [now=2025-06-13 00:16:49.136849, n_estimator=10, cnt=3000, last_round=1170, random_state=429990, data_length=400]
# proceed [now=2025-06-13 00:17:17.046975, n_estimator=10, cnt=4000, last_round=1170, random_state=439990, data_length=400]
# proceed [now=2025-06-13 00:17:41.321766, n_estimator=10, cnt=5000, last_round=1170, random_state=449990, data_length=400]
# proceed [now=2025-06-13 00:18:09.157323, n_estimator=10, cnt=1000, last_round=1169, random_state=409990, data_length=400]
# proceed [now=2025-06-13 00:18:37.169596, n_estimator=10, cnt=2000, last_round=1169, random_state=419990, data_length=400]
# proceed [now=2025-06-13 00:19:05.622067, n_estimator=10, cnt=3000, last_round=1169, random_state=429990, data_length=400]
# proceed [now=2025-06-13 00:19:34.001523, n_estimator=10, cnt=4000, last_round=1169, random_state=439990, data_length=400]
# proceed [now=2025-06-13 00:19:55.783069, n_estimator=10, cnt=5000, last_round=1169, random_state=449990, data_length=400]
# proceed [now=2025-06-13 00:20:22.649857, n_estimator=10, cnt=1000, last_round=1168, random_state=409990, data_length=400]
# proceed [now=2025-06-13 00:20:50.322933, n_estimator=10, cnt=2000, last_round=1168, random_state=419990, data_length=400]
# proceed [now=2025-06-13 00:21:14.567417, n_estimator=10, cnt=3000, last_round=1168, random_state=429990, data_length=400]
# proceed [now=2025-06-13 00:21:42.572405, n_estimator=10, cnt=4000, last_round=1168, random_state=439990, data_length=400]
# proceed [now=2025-06-13 00:22:11.477683, n_estimator=10, cnt=5000, last_round=1168, random_state=449990, data_length=400]
# proceed [now=2025-06-13 00:22:39.683578, n_estimator=10, cnt=1000, last_round=1167, random_state=409990, data_length=400]
# proceed [now=2025-06-13 00:23:03.462943, n_estimator=10, cnt=2000, last_round=1167, random_state=419990, data_length=400]
# proceed [now=2025-06-13 00:23:31.813347, n_estimator=10, cnt=3000, last_round=1167, random_state=429990, data_length=400]
# proceed [now=2025-06-13 00:23:59.810235, n_estimator=10, cnt=4000, last_round=1167, random_state=439990, data_length=400]
# proceed [now=2025-06-13 00:24:27.390032, n_estimator=10, cnt=5000, last_round=1167, random_state=449990, data_length=400]
# proceed [now=2025-06-13 00:24:51.537813, n_estimator=10, cnt=1000, last_round=1166, random_state=409990, data_length=400]
# proceed [now=2025-06-13 00:25:19.443583, n_estimator=10, cnt=2000, last_round=1166, random_state=419990, data_length=400]
# proceed [now=2025-06-13 00:25:44.741261, n_estimator=10, cnt=3000, last_round=1166, random_state=429990, data_length=400]
# proceed [now=2025-06-13 00:26:09.366597, n_estimator=10, cnt=4000, last_round=1166, random_state=439990, data_length=400]
# proceed [now=2025-06-13 00:26:30.583338, n_estimator=10, cnt=5000, last_round=1166, random_state=449990, data_length=400]
# completed [now=2025-06-13 00:26:30.583498]
# start to read and write data: [now=2025-06-13 00:26:30.583514]
# complete to read and data: [now=2025-06-13 00:28:56.448125]

# %%
parameters = {
    "n_estimators": [25,10],
    "data_lengths": [400],
    "random_state_gap": 10,
    "random_state_begin": 450000,
    "random_state_end": 460000,
    "last_rounds": [1175, 1174, 1173, 1172, 1171, 1170, 1169, 1168, 1167, 1166],
}
version="T_01_08"
result_sets = main(parameters=parameters, version=version, sum_min=0, sum_max=-1, trial=1, write_to_db=True)
# Out:
# start   [now=2025-06-13 00:59:50.486471]
# proceed [now=2025-06-13 01:00:46.825518, n_estimator=25, cnt=1000, last_round=1175, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:01:34.498249, n_estimator=25, cnt=1000, last_round=1174, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:02:31.797651, n_estimator=25, cnt=1000, last_round=1173, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:03:33.416927, n_estimator=25, cnt=1000, last_round=1172, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:04:29.439487, n_estimator=25, cnt=1000, last_round=1171, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:05:26.612134, n_estimator=25, cnt=1000, last_round=1170, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:06:23.117099, n_estimator=25, cnt=1000, last_round=1169, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:07:16.167696, n_estimator=25, cnt=1000, last_round=1168, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:08:11.279749, n_estimator=25, cnt=1000, last_round=1167, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:09:04.399608, n_estimator=25, cnt=1000, last_round=1166, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:09:30.879888, n_estimator=10, cnt=1000, last_round=1175, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:09:57.021262, n_estimator=10, cnt=1000, last_round=1174, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:10:20.056703, n_estimator=10, cnt=1000, last_round=1173, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:10:46.035747, n_estimator=10, cnt=1000, last_round=1172, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:11:12.275513, n_estimator=10, cnt=1000, last_round=1171, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:11:35.466580, n_estimator=10, cnt=1000, last_round=1170, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:12:00.386076, n_estimator=10, cnt=1000, last_round=1169, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:12:23.269422, n_estimator=10, cnt=1000, last_round=1168, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:12:43.868681, n_estimator=10, cnt=1000, last_round=1167, random_state=459990, data_length=400]
# proceed [now=2025-06-13 01:13:05.643942, n_estimator=10, cnt=1000, last_round=1166, random_state=459990, data_length=400]
# completed [now=2025-06-13 01:13:05.644101]
# start to read and write data: [now=2025-06-13 01:13:05.644116]
# complete to read and data: [now=2025-06-13 01:13:32.596878]

# %%
parameters = {
    "n_estimators": [25,10],
    "data_lengths": [400],
    "random_state_gap": 1,
    "random_state_begin": 300000,
    "random_state_end": 301000,
    "last_rounds": [1175],
}
version="T_01_99"
result_sets = main(parameters=parameters, version=version, sum_min=0, sum_max=-1, trial=1, write_to_db=True)
# Out:
# start   [now=2025-06-12 11:24:56.202755]
# proceed [now=2025-06-12 11:25:59.665769, n_estimator=25, cnt=1000, last_round=1175, random_state=300999, data_length=400]
# proceed [now=2025-06-12 11:26:29.527030, n_estimator=10, cnt=1000, last_round=1175, random_state=300999, data_length=400]
# completed [now=2025-06-12 11:26:29.527225]
# completed [now=2025-06-12 11:26:29.527241]
# start to read data: [now=2025-06-12 11:26:29.527249]
# complete to read data: [now=2025-06-12 11:26:54.347066]
# start to write db: [now=2025-06-12 11:26:54.347180]
# complete to write db: [now=2025-06-12 11:26:54.347199]

# %%
## SQL Query

# %%
for result in result_set:
    if result[4] > 6:
        print(result)

# %%
print(f'check answer : [{datetime.now()}]')
for result in results_set:
    if result[2][0] > 3 or result[2][1] > 3:
        print(result)
# Out:
# check answer : [2025-06-09 11:35:00.484062]

# %%
n_estimators=45
begin_pos=0
end_pos=600000
print(f'start   [now={datetime.now()}]')
for minus_value in [2, 1, 0]:
    cnt = 0
    for random_state in range(begin_pos, end_pos, 100):
        predict_lens = predict_and_test(minus_value, n_estimators, random_state, 0)
        if predict_lens[0] > 2 and predict_lens[1] > 2:
            results_set.append((n_estimators, random_state, predict_lens, minus_value))
            print('found = ', n_estimators, random_state, predict_lens, minus_value)
        cnt += 1
        if cnt % 1000 == 0:
            print(f'proceed [now={datetime.now()}, {cnt}]')        
print(f'completed [now={datetime.now()}]')

# %%
n_estimators=6
begin_pos=100000
end_pos=500000
print(f'start   [now={datetime.now()}]')
for minus_value in [8, 7, 6, 5, 4, 3, 2, 1]:
    cnt = 0
    for random_state in range(begin_pos, end_pos, 100):
        predict_lens = predict_and_test(minus_value, n_estimators, random_state, 0)
        if predict_lens[0] > 1 and predict_lens[1] > 1 and predict_lens[2] > 1:
            results_set.append((n_estimators, random_state, predict_lens, minus_value))
            print('found = ', n_estimators, random_state, predict_lens, minus_value)
        cnt += 1
        if cnt % 1000 == 0:
            print(f'proceed [now={datetime.now()}, {cnt}]')        
print(f'completed [now={datetime.now()}]')

# %% [markdown]
# ```
# (25, 219100, [3, 4], 0)
# (25, 560100, [3, 4], 0)
# (25, 322300, [3, 4], 5)
# (25, 520500, [3, 4], 5)
# (25, 148700, [3, 4], 6)
# (25, 283500, [3, 4], 6)
# (25, 358100, [3, 4], 6)
# (25, 451600, [4, 3], 6)
# (25, 489000, [4, 3], 6)
# (25, 295500, [3, 4], 7)
# (25, 241500, [3, 4], 8)
# (45, 52100, [3, 4], 6)
# (45, 587300, [3, 4], 4)
# (10, 102500, [3, 4], 7)
# (10, 113700, [4, 4], 6)
# (10, 164200, [3, 4], 1)
# (10, 225300, [3, 4], 8)
# (10, 371400, [3, 4], 8)
# (10, 255700, [3, 4], 7)
# (10, 15200, [3, 4], 7)
# (10, 63300, [3, 4], 6)
# (6, 131400, [3, 4], 5)
# (6, 195200, [4, 3], 5)
# (6, 406100, [4, 3], 8)
# (6, 325200, [4, 3], 7)
# (6, 353200, [4, 3], 7)
# (6, 473900, [4, 4], 6)
# (6, 363000, [4, 3], 5)
# [
# (25, 451600, [4, 3], 6),
# (25, 489000, [4, 3], 6),
# (6, 473900, [4, 4], 6),
# (10, 113700, [4, 4], 6),
# (10, 15200, [3, 4], 7),
# ]
#
# ```

# %%
for result in results_set:
    if result[2][0] > 3 or result[2][1] > 3:
        print(result)

# %%
datas = [
    [45,208000,4,3,5],
    [45,101700,4,3,2],
    [45,101700,4,3,2],
    [45,185400,4,3,2],
    [45,96800,4,3,1],
    [45,58600,3,3,0],
    ]
datas = [
    (25, 451600, [4, 3], 6),
    (25, 489000, [4, 3], 6),
    (6, 473900, [4, 4], 6),
    (10, 113700, [4, 4], 6),
    (10, 15200, [3, 4], 7),
    ]
for data in datas:
    n_estimators=data[0]
    random_state=data[1]
    minus_value=data[3]
    results=[]
    print(f'start [now={datetime.now()}]')
    data_pos=1
    h_data=lotto_history_data[r_pos[data_pos][0]:r_pos[data_pos][1]-minus_value]
    predicted_numbers_set = predict(lotto_history_data=h_data,
                                    n_estimators=n_estimators,
                                    random_state=random_state,
                                    verbose=0)
    predict_len1=test_prediction(round_nums[data_pos],
                                 actual_numbers[data_pos],
                                 bonus[data_pos],
                                 predicted_numbers_set,
                                 n_estimators,
                                 random_state,
                                 verbose=1)
    data_pos=2
    h_data=lotto_history_data[r_pos[data_pos][0]:r_pos[data_pos][1]-minus_value]
    predicted_numbers_set = predict(lotto_history_data=h_data,
                                    n_estimators=n_estimators,
                                    random_state=random_state,
                                    verbose=0)
    predict_len2 = test_prediction(round_nums[data_pos],
                                   actual_numbers[data_pos],
                                   bonus[data_pos],
                                   predicted_numbers_set,
                                   n_estimators,
                                   random_state,
                                   verbose=1)
print(f'completed [now={datetime.now()}]')

# %%
# datas = [
#     [45,208000,4,3,5],
#     [45,101700,4,3,2],
#     [45,185400,4,3,2],
#     [45,96800,4,3,1],
#     [45,58600,3,3,0],
#     ]
datas = [
    (25, 451600, [4, 3], 6),
    (25, 489000, [4, 3], 6),
    (6, 473900, [4, 4], 6),
    (10, 113700, [4, 4], 6),
    (10, 15200, [3, 4], 7),
    ]
print(f'start [now={datetime.now()}]')
results=[]
for data in datas:
    n_estimators=data[0]
    random_state=data[1]
    minus_value=data[3]    
    data_pos=0
    h_data=lotto_history_data[r_pos[data_pos][0]:r_pos[data_pos][1]-minus_value]
    predicted_numbers_set = predict(lotto_history_data=h_data,
                                    n_estimators=n_estimators,
                                    random_state=random_state,
                                    verbose=0)
    results.append(predicted_numbers_set[0])
    predict_len2 = test_prediction(round_nums[data_pos],
                                   actual_numbers[1],
                                   bonus[data_pos],
                                   predicted_numbers_set,
                                   n_estimators,
                                   random_state,
                                   verbose=1)
print(f'completed [now={datetime.now()}]')
print('Predicted Numbers.')
for result in results:
    print(result)

# %%
print(results)

# %% [markdown]
# ```
# [
# [45,208000,4,3,5],
# [45,101700,4,3,2],
# [45,101700,4,3,2],
# [45,185400,4,3,2],
# [45,96800,4,3,1],
#     [45,58600,3,3,0],
# ]
# ```

# %%
n_estimators=10
random_state=5000
data_pos=1
h_data=lotto_history_data[r_pos[data_pos][0]:r_pos[data_pos][1]]
predicted_numbers_set = predict(lotto_history_data=h_data,
                                n_estimators=n_estimators,
                                random_state=random_state,
                                verbose=0
                               )
test_prediction(round_nums[data_pos],
                actual_numbers[data_pos],
                bonus[data_pos],
                predicted_numbers_set,
                n_estimators,
                random_state)
data_pos=2
h_data=lotto_history_data[r_pos[data_pos][0]:r_pos[data_pos][1]]
predicted_numbers_set = predict(lotto_history_data=h_data,
                                n_estimators=n_estimators,
                                random_state=random_state,
                                verbose=0)
test_prediction(round_nums[data_pos],
                actual_numbers[data_pos],
                bonus[data_pos],
                predicted_numbers_set,
                n_estimators,
                random_state)

# %%
[
    ([14, 17, 23, 27, 34, 36], [14, 17, 36], (45, 1000), (1160, 1173),
    ([13, 16, 23, 27, 34, 36], [36], (45, 1300), (1160, 1173)),
    ([11, 15, 21, 30, 36, 39], [11, 36, 39], (45, 1000), (1160, 1173),

]

# %%
params = [
    ['25', '400', '168060', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '1,3,1,2,0,1,4,4,0,1', '17', 'T_01_08'],
    ['25', '400', '680', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '1,1,1,1,2,1,4,4,1,1', '17', 'T_01_08'],
    ['10', '400', '338000', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '3,3,1,0,3,0,1,3,3,2', '19', 'T_01_08'],
    ['25', '400', '116690', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '1,3,2,2,3,0,3,2,1,1', '18', 'T_01_08'],
    ['25', '400', '143050', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '1,3,3,3,2,0,3,1,1,1', '18', 'T_01_08'],
    ['10', '400', '129920', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '2,0,2,3,2,3,1,3,1,1', '18', 'T_01_08'],
    ['25', '400', '319350', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '1,3,1,3,1,1,3,3,2,0', '18', 'T_01_08'],
    ['10', '400', '374630', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '3,3,1,2,3,0,2,2,2,0', '18', 'T_01_08'],
    ['25', '400', '381150', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '1,3,1,1,2,0,3,3,2,1', '17', 'T_01_08'],
    ['10', '400', '373380', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '1,3,1,2,0,3,2,3,1,1', '17', 'T_01_08'],
    ['10', '400', '397710', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '1,3,2,1,1,0,2,3,3,1', '17', 'T_01_08'],
    ['10', '400', '73700', '1175,1174,1173,1172,1171,1170,1169,1168,1167,1166', '2,3,1,1,1,2,3,0,3,1', '17', 'T_01_08'],
]

predicted_numbers_set = []

db_file_path = '../db/metrics.db'

for param in params:
    predicted_numbers = main_predict(n_estimator=int(param[0]),
                                     last_round=1176,
                                     data_length=int(param[1]),
                                     random_state=int(param[2]),
                                     db_file_path=db_file_path,
                                     trial=1,
                                     verbose=0)
    predicted_numbers_set.append(predicted_numbers)

for numbers in predicted_numbers_set:
    print(numbers)
# Out:
# [[9, 14, 20, 26, 29, 39]]
# [[9, 14, 22, 27, 30, 37]]
# [[10, 17, 22, 29, 36, 40]]
# [[7, 13, 17, 24, 29, 36]]
# [[6, 12, 18, 24, 28, 38]]
# [[10, 17, 22, 29, 34, 40]]
# [[8, 13, 22, 26, 29, 37]]
# [[9, 13, 23, 30, 34, 40]]
# [[8, 13, 20, 26, 30, 38]]
# [[8, 12, 19, 23, 28, 38]]
# [[10, 16, 23, 29, 33, 38]]
# [[8, 17, 21, 28, 35, 41]]

# %%
#test
