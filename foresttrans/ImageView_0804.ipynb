# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "./img"
file_list = os.listdir(path)

file_list = [file for file in file_list if file.endswith(".png")]
file_list.sort()
for file_name in file_list:
    img = Image.open(f'./img/{file_name}')
    img_np = np.array(img) ## 행렬로 변환된 이미지
    plt.imshow(img_np) ## 행렬 이미지를 다시 이미지로 변경해 디스플레이
    plt.show() ## 이미지 인터프린터에 출력
    print(file_name)

# %%
file_list = ["Line_1_1_average_1.png", "Line_1_10_average_1.png"]

file_list = [file for file in file_list if file.endswith(".png")]
file_list.sort()
for file_name in file_list:
    img = Image.open(f'./img/{file_name}')
    img_np = np.array(img) ## 행렬로 변환된 이미지
    plt.imshow(img_np) ## 행렬 이미지를 다시 이미지로 변경해 디스플레이
    plt.show() ## 이미지 인터프린터에 출력
    print(file_name)
# Out:
# Line_1_10_average_1.png
# Line_1_1_average_1.png

# %%
file_list = ["Line_1_1_average_10.png", "Line_1_10_average_10.png"]

file_list = [file for file in file_list if file.endswith(".png")]
file_list.sort()
for file_name in file_list:
    img = Image.open(f'./img/{file_name}')
    img_np = np.array(img) ## 행렬로 변환된 이미지
    plt.imshow(img_np) ## 행렬 이미지를 다시 이미지로 변경해 디스플레이
    plt.show() ## 이미지 인터프린터에 출력
    print(file_name)
# Out:
# Line_1_10_average_10.png
# Line_1_1_average_10.png

# %%
file_list = ["Line_1_1_average_20.png", "Line_1_10_average_20.png"]

file_list = [file for file in file_list if file.endswith(".png")]
file_list.sort()
for file_name in file_list:
    img = Image.open(f'./img/{file_name}')
    img_np = np.array(img) ## 행렬로 변환된 이미지
    plt.imshow(img_np) ## 행렬 이미지를 다시 이미지로 변경해 디스플레이
    plt.show() ## 이미지 인터프린터에 출력
    print(file_name)
# Out:
# Line_1_10_average_20.png
# Line_1_1_average_20.png

# %%
file_list = ["Line_1_1_average_30.png", "Line_1_10_average_30.png"]

file_list = [file for file in file_list if file.endswith(".png")]
file_list.sort()
for file_name in file_list:
    img = Image.open(f'./img/{file_name}')
    img_np = np.array(img) ## 행렬로 변환된 이미지
    plt.imshow(img_np) ## 행렬 이미지를 다시 이미지로 변경해 디스플레이
    plt.show() ## 이미지 인터프린터에 출력
    print(file_name)
# Out:
# Line_1_10_average_30.png
# Line_1_1_average_30.png

# %%
file_list = ["Line_1_10_average_1.png",
             "Line_1_10_average_2.png",
             "Line_1_10_average_5.png",
             "Line_1_10_average_10.png",
             "Line_1_10_average_15.png",
             "Line_1_10_average_20.png",
            ]

file_list = [file for file in file_list if file.endswith(".png")]
file_list.sort()
for file_name in file_list:
    img = Image.open(f'./img/{file_name}')
    img_np = np.array(img) ## 행렬로 변환된 이미지
    plt.imshow(img_np) ## 행렬 이미지를 다시 이미지로 변경해 디스플레이
    plt.show() ## 이미지 인터프린터에 출력
    print(file_name)
# Out:
# Line_1_10_average_1.png
# Line_1_10_average_10.png
# Line_1_10_average_15.png
# Line_1_10_average_2.png
# Line_1_10_average_20.png
# Line_1_10_average_5.png
