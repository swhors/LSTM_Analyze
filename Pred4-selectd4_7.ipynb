# %% [markdown]
# # Prediction with LSTM model (v.4.4.7)
# <p style='text-align: right;'>with selectd4.csv</p>
#
# * history
#   * 2025/05/23 PM06:02 : 3번째 모델의 3번째 데이터를 사용
#   * 2025/05/27

# %%
# !pip install scikit-learn
# !pip install tensorflow
from datetime import datetime
print(f'restart kernel... {datetime.now()}')

# %%
def restart_kernel():
    # Restart the kernet after libraries are loaded.
    import IPython
    from datetime import datetime
    print(f'restart kernel... {datetime.now()}')
    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

restart_kernel()
# Out:
# restart kernel... 2025-05-30 11:51:28.081295

# %%
# load dependacies
import os
import time
import resource
from datetime import datetime
from lib.globalvar import *
from lib.data_loader import DataLoader
from lib.small_predict import predict_small, print_predict_small
from lib.activation import ActivationOutput, RecurrentActivation
from lib.small_predict import build_and_predict, gen_multi_model, save_model, generate_metric
from lib.common_env_sets import lstm_units, dense_units, steps, metrics, dropout
from lib.common_env_sets import learning_rate, last_lstm_return_sequences
from lib.common_env_sets import loss, output_dense_activation, epochs, rand_seed


print(f"imported library. ({datetime.now()})")
# Out:
# imported library. (2025-05-30 11:51:54.150932)

# %%
##
## 모델링 환경 설정
##
window=1 # default = 1 , help = "time stamps"
data_dir='./csv/selectd4.csv'
    
mode='predict' # help = "back-test or predict")

mode2='sampling' # help = "greed or sampling")
verb='verbose' # help = "verbose or not_verb")
    
trial=20 # help = "how much trials to generate")
training_length=0.95 # default = 0.9)
epoch=20 # default = 3
batch=1 # default = 1
model_type='lstm4' # help = "lstm1 or lstm2")
hid_dim = 50
from_pos = 0
last = [[1, 5, 18, 20, 30, 35],
        [7, 9, 24, 40, 42, 44],
        [3, 6, 7, 11, 12, 17],
        [3, 13, 28, 34, 38, 42],
        [5, 12, 24, 29, 32, 42]]
print(f"finished to set environemnt. ({datetime.now()})")
MAX_MODEL_CNT = 3

write_to_db = True
# Out:
# finished to set environemnt. (2025-05-30 11:51:57.309924)

# %%
dataset_dicts = {
    1: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=0,
                  verbose=False
                  ),
    2: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=300,
                  verbose=False
                  )
    }
#print(f'test_X = {dataset_dicts[1].test_X}')
print(f'completed to load data. {datetime.now()}')
# Out:
# completed to load data. 2025-05-30 11:52:00.175644

# %%
###########
## layers
## LSTM Neural 계층 선언
###########
datasets = [dataset_dicts[1], # 0
            dataset_dicts[2], # 1
           ]

lstm_args = {14: {"model":{"learning_rate": learning_rate[0],
                           "dropout": dropout[0],
                           "steps": steps[0], # last output elements count
                           "metrics": metrics[1],
                           "last_lstm_return_sequences": last_lstm_return_sequences[0],
                           "lstm_units": lstm_units[2],
                           "dense_units": dense_units[2],
                           "output_dense_activation": output_dense_activation[3],
                           "loss": loss[0],
                           "return_state": False,
                           "rand_seed": rand_seed[0] # rand_seed[0]
                           },
                 "train": {"epochs": epochs[2],
                           "is_shuffle": False,
                           "batch": 1,
                           "steps_per_epoch": 0 #100
                           },
                 "dataset": datasets[0]
                 },
             34: {"model":{"learning_rate": learning_rate[0],
                           "dropout": dropout[0],
                           "steps": steps[0], # last output elements count
                           "metrics": metrics[1],
                           "last_lstm_return_sequences": last_lstm_return_sequences[1],
                           "lstm_units": lstm_units[2],
                           "dense_units": dense_units[2],
                           "output_dense_activation": output_dense_activation[3],
                           "loss": loss[0],
                           "return_state": False,
                           "rand_seed": rand_seed[0] # rand_seed[0]
                           },
                 "train": {"epochs": epochs[2],
                           "is_shuffle": False,
                           "batch": 1,
                           "steps_per_epoch": 0 #100
                           },
                 "dataset": datasets[0]
                 },
             }


print(f'completed to set env for all models. {datetime.now()}')
# Out:
# completed to set env for all models. 2025-05-30 11:52:02.241654

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 13
model_version_end = 26
args = {'test_id': 'P4_4_5_1_3',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 13~26
# CPU 시간: 4.140574 초
# 메모리 사용량: 616432 KB
# generate_metric.02 args["version"]=13
# ********************
# working model_version = 13  2025-05-30 11:52:17.270017
# ********************
# start to train all models. 2025-05-30 11:52:17.270046
# 14's training. status=start 2025-05-30 11:52:17.270061
# 14's training. status=end 2025-05-30 11:53:05.177639
# 34's training. status=start 2025-05-30 11:53:05.177734
# 34's training. status=end 2025-05-30 11:53:55.584900
# completed to train all models. 2025-05-30 11:53:55.584996
# train to create model(13). 2025-05-30 11:53:58.585085
# CPU 시간: 124.398535 초
# 메모리 사용량: 1029168 KB
# generate_metric.02 args["version"]=14
# ********************
# working model_version = 14  2025-05-30 11:54:26.835919
# ********************
# start to train all models. 2025-05-30 11:54:26.835946
# 14's training. status=start 2025-05-30 11:54:26.835957
# 14's training. status=end 2025-05-30 11:55:16.172768
# 34's training. status=start 2025-05-30 11:55:16.172868
# 34's training. status=end 2025-05-30 11:56:07.438266
# completed to train all models. 2025-05-30 11:56:07.438366
# train to create model(14). 2025-05-30 11:56:10.438446
# CPU 시간: 245.139697 초
# 메모리 사용량: 1217120 KB
# generate_metric.02 args["version"]=15
# ********************
# working model_version = 15  2025-05-30 11:56:38.737616
# ********************
# start to train all models. 2025-05-30 11:56:38.737652
# 14's training. status=start 2025-05-30 11:56:38.737669
# 14's training. status=end 2025-05-30 11:57:27.891622
# 34's training. status=start 2025-05-30 11:57:27.891725
# 34's training. status=end 2025-05-30 11:58:17.071187
# completed to train all models. 2025-05-30 11:58:17.071287
# train to create model(15). 2025-05-30 11:58:20.071381
# CPU 시간: 367.145982 초
# 메모리 사용량: 1401984 KB
# generate_metric.02 args["version"]=16
# ********************
# working model_version = 16  2025-05-30 11:58:47.895126
# ********************
# start to train all models. 2025-05-30 11:58:47.895163
# 14's training. status=start 2025-05-30 11:58:47.895181
# 14's training. status=end 2025-05-30 11:59:37.605099
# 34's training. status=start 2025-05-30 11:59:37.605197
# 34's training. status=end 2025-05-30 12:00:28.880217
# completed to train all models. 2025-05-30 12:00:28.880315
# train to create model(16). 2025-05-30 12:00:31.880404
# CPU 시간: 489.565864 초
# 메모리 사용량: 1586432 KB
# generate_metric.02 args["version"]=17
# ********************
# working model_version = 17  2025-05-30 12:00:59.544316
# ********************
# start to train all models. 2025-05-30 12:00:59.544352
# 14's training. status=start 2025-05-30 12:00:59.544368
# 14's training. status=end 2025-05-30 12:01:48.083049
# 34's training. status=start 2025-05-30 12:01:48.083182
# 34's training. status=end 2025-05-30 12:02:39.216652
# completed to train all models. 2025-05-30 12:02:39.216751
# train to create model(17). 2025-05-30 12:02:42.216838
# CPU 시간: 612.043874 초
# 메모리 사용량: 1774544 KB
# generate_metric.02 args["version"]=18
# ********************
# working model_version = 18  2025-05-30 12:03:10.386676
# ********************
# start to train all models. 2025-05-30 12:03:10.386712
# 14's training. status=start 2025-05-30 12:03:10.386728
# 14's training. status=end 2025-05-30 12:03:59.234823
# 34's training. status=start 2025-05-30 12:03:59.234916
# 34's training. status=end 2025-05-30 12:04:49.423858
# completed to train all models. 2025-05-30 12:04:49.423962
# train to create model(18). 2025-05-30 12:04:52.424046
# CPU 시간: 735.120113 초
# 메모리 사용량: 1958464 KB
# generate_metric.02 args["version"]=19
# ********************
# working model_version = 19  2025-05-30 12:05:20.244479
# ********************
# start to train all models. 2025-05-30 12:05:20.244514
# 14's training. status=start 2025-05-30 12:05:20.244530
# 14's training. status=end 2025-05-30 12:06:10.126570
# 34's training. status=start 2025-05-30 12:06:10.126671
# 34's training. status=end 2025-05-30 12:07:01.566598
# completed to train all models. 2025-05-30 12:07:01.566695
# train to create model(19). 2025-05-30 12:07:04.566773
# CPU 시간: 856.787302 초
# 메모리 사용량: 2290272 KB
# generate_metric.02 args["version"]=20
# ********************
# working model_version = 20  2025-05-30 12:07:32.734547
# ********************
# start to train all models. 2025-05-30 12:07:32.734582
# 14's training. status=start 2025-05-30 12:07:32.734598
# 14's training. status=end 2025-05-30 12:08:24.935134
# 34's training. status=start 2025-05-30 12:08:24.935233
# 34's training. status=end 2025-05-30 12:09:14.746291
# completed to train all models. 2025-05-30 12:09:14.746390
# train to create model(20). 2025-05-30 12:09:17.746468
# CPU 시간: 980.492841 초
# 메모리 사용량: 2330864 KB
# generate_metric.02 args["version"]=21
# ********************
# working model_version = 21  2025-05-30 12:09:46.187970
# ********************
# start to train all models. 2025-05-30 12:09:46.188006
# 14's training. status=start 2025-05-30 12:09:46.188023
# 14's training. status=end 2025-05-30 12:10:36.195805
# 34's training. status=start 2025-05-30 12:10:36.195905
# 34's training. status=end 2025-05-30 12:11:28.283261
# completed to train all models. 2025-05-30 12:11:28.283560
# train to create model(21). 2025-05-30 12:11:31.283644
# CPU 시간: 1104.149995 초
# 메모리 사용량: 2514528 KB
# generate_metric.02 args["version"]=22
# ********************
# working model_version = 22  2025-05-30 12:12:00.623902
# ********************
# start to train all models. 2025-05-30 12:12:00.623937
# 14's training. status=start 2025-05-30 12:12:00.623953
# 14's training. status=end 2025-05-30 12:12:49.564321
# 34's training. status=start 2025-05-30 12:12:49.564430
# 34's training. status=end 2025-05-30 12:13:39.402144
# completed to train all models. 2025-05-30 12:13:39.402244
# train to create model(22). 2025-05-30 12:13:42.402324
# CPU 시간: 1225.79082 초
# 메모리 사용량: 2839904 KB
# generate_metric.02 args["version"]=23
# ********************
# working model_version = 23  2025-05-30 12:14:10.299152
# ********************
# start to train all models. 2025-05-30 12:14:10.299188
# 14's training. status=start 2025-05-30 12:14:10.299204
# 14's training. status=end 2025-05-30 12:15:03.425876
# 34's training. status=start 2025-05-30 12:15:03.425972
# 34's training. status=end 2025-05-30 12:15:54.727425
# completed to train all models. 2025-05-30 12:15:54.727529
# train to create model(23). 2025-05-30 12:15:57.727616
# CPU 시간: 1351.78529 초
# 메모리 사용량: 3002176 KB
# generate_metric.02 args["version"]=24
# ********************
# working model_version = 24  2025-05-30 12:16:26.492568
# ********************
# start to train all models. 2025-05-30 12:16:26.492603
# 14's training. status=start 2025-05-30 12:16:26.492620
# 14's training. status=end 2025-05-30 12:17:16.392989
# 34's training. status=start 2025-05-30 12:17:16.393280
# 34's training. status=end 2025-05-30 12:18:05.345828
# completed to train all models. 2025-05-30 12:18:05.345928
# train to create model(24). 2025-05-30 12:18:08.346014
# CPU 시간: 1473.328794 초
# 메모리 사용량: 3215552 KB
# generate_metric.02 args["version"]=25
# ********************
# working model_version = 25  2025-05-30 12:18:37.047769
# ********************
# start to train all models. 2025-05-30 12:18:37.047805
# 14's training. status=start 2025-05-30 12:18:37.047821
# 14's training. status=end 2025-05-30 12:19:25.626903
# 34's training. status=start 2025-05-30 12:19:25.627002
# 34's training. status=end 2025-05-30 12:20:20.123078
# completed to train all models. 2025-05-30 12:20:20.123194
# train to create model(25). 2025-05-30 12:20:23.123279
# CPU 시간: 1598.080202 초
# 메모리 사용량: 3380336 KB
# generate_metric.02 args["version"]=26
# ********************
# working model_version = 26  2025-05-30 12:20:51.060578
# ********************
# start to train all models. 2025-05-30 12:20:51.060613
# 14's training. status=start 2025-05-30 12:20:51.060629
# 14's training. status=end 2025-05-30 12:21:41.250424
# 34's training. status=start 2025-05-30 12:21:41.250517
# 34's training. status=end 2025-05-30 12:22:31.041623
# completed to train all models. 2025-05-30 12:22:31.041722
# train to create model(26). 2025-05-30 12:22:34.041813
# CPU 시간: 1719.584036 초
# 메모리 사용량: 3588608 KB

# %%
## end
