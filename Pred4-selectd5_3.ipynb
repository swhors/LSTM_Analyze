# %% [markdown]
# # Prediction with LSTM model (v4.5.3)
# <p style='text-align: right;'>with selectd5.csv</p>
#
# * history
#   * 2025/05/23 PM06:02 : 3번째 모델의 3번째 데이터를 사용
#   * 2025/05/27
#   * 2025/05/30 : v4.5.1 작성 시작
#   * 2025/06/04 : v4.5.2 last update
#   * 2025/06/04 : v4.5.3 작성

# %%
# !pip install scikit-learn
# !pip install tensorflow
# !pip install numpy pandas keras scikit-learn matplotlib scikeras
from datetime import datetime
print(f'restart kernel... {datetime.now()}')

# %%
def restart_kernel():
    # Restart the kernet after libraries are loaded.
    import IPython
    from datetime import datetime
    print(f'restart kernel... {datetime.now()}')
    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

restart_kernel()

import os
import sys
from datetime import datetime
cwd = os.getcwd()
sys.path.append(cwd)
print(sys.path)
# Out:
# restart kernel... 2025-06-04 13:35:20.751728
# ['/home/swhors/jupyter-workspace/LSTM/$PWD', '/home/swhors/jupyter-workspace/finance', '/home/swhors/jupyter-workspace/finance/venv/lib/python3.11/site-paches', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '', '/home/swhors/jupyter-workspace/finance/venv/lib/python3.11/site-packages', '/home/swhors/jupyter-workspace/LSTM']

# %%
# load dependacies
import os
import time
import resource
from datetime import datetime
from lib.globalvar import *
from lib.data_loader import DataLoader
from lib.small_predict import predict_small, print_predict_small
from lib.activation import ActivationOutput, RecurrentActivation
from lib.small_predict import build_and_predict, gen_multi_model, save_model, generate_metric
from lib.common_env_sets import lstm_units, dense_units, steps, metrics, dropout
from lib.common_env_sets import learning_rate, last_lstm_return_sequences
from lib.common_env_sets import loss, output_dense_activation, epochs, rand_seed


print(f"imported library. ({datetime.now()})")
# Out:
# imported library. (2025-06-04 18:04:37.881999)

# %%
##
## 모델링 환경 설정
##
window=1 # default = 1 , help = "time stamps"
data_dir='./csv/selectd5.csv'
    
mode='predict' # help = "back-test or predict")

mode2='sampling' # help = "greed or sampling")
verb='verbose' # help = "verbose or not_verb")
    
training_length=0.95 # default = 0.9)
from_pos = 0
last = [[8, 11, 14, 17, 36, 39],
        [1, 5, 18, 20, 30, 35],
        [7, 9, 24, 40, 42, 44],
        [3, 6, 7, 11, 12, 17],
        [3, 13, 28, 34, 38, 42],
        [5, 12, 24, 29, 32, 42]]
print(f"finished to set environemnt. ({datetime.now()})")
# Out:
# finished to set environemnt. (2025-06-04 18:04:54.712613)

# %%
dataset_dicts = {
    1: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=0,
                  verbose=False
                  ),
    2: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=300,
                  verbose=False
                  )
    }

print(f'completed to load data. {datetime.now()}')
# Out:
# completed to load data. 2025-06-04 18:04:56.858909

# %%
###########
## layers
## LSTM Neural 계층 선언
###########
datasets = [dataset_dicts[1], # 0
            dataset_dicts[2], # 1
           ]

lstm_args = {44: {"model":{"learning_rate": learning_rate[0],
                           "dropout": dropout[0],
                           "steps": steps[0], # last output elements count
                           "metrics": metrics[0],
                           "last_lstm_return_sequences": last_lstm_return_sequences[1],
                           "lstm_units": lstm_units[2],
                           "dense_units": dense_units[2],
                           "output_dense_activation": output_dense_activation[3],
                           "loss": loss[0],
                           "return_state": False,
                           "rand_seed": rand_seed[0] # rand_seed[0]
                           },
                 "train": {"epochs": epochs[3],
                           "is_shuffle": False,
                           "batch": 1,
                           "steps_per_epoch": 0 #100
                           },
                 "dataset": datasets[0]
                 },
             }

print(f'completed to set env for all models. {datetime.now()}')
# Out:
# completed to set env for all models. 2025-06-04 18:04:58.751876

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_3_1',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 1~12
# CPU 시간: 4.598177 초
# 메모리 사용량: 623568 KB
# generate_metric.02 args["version"]=1
# ********************
# working model_version = 1  2025-06-04 18:05:01.196228
# ********************
# start to train all models. 2025-06-04 18:05:01.196258
# 44's training. status=start 2025-06-04 18:05:01.196273
# 44's training. status=end 2025-06-04 18:06:30.494595
# completed to train all models. 2025-06-04 18:06:30.494697
# train to create model(1). 2025-06-04 18:06:33.494783
# CPU 시간: 109.024278 초
# 메모리 사용량: 868320 KB
# generate_metric.02 args["version"]=2
# ********************
# working model_version = 2  2025-06-04 18:06:53.514667
# ********************
# start to train all models. 2025-06-04 18:06:53.514702
# 44's training. status=start 2025-06-04 18:06:53.514718
# 44's training. status=end 2025-06-04 18:08:25.758314
# completed to train all models. 2025-06-04 18:08:25.758414
# train to create model(2). 2025-06-04 18:08:28.758500
# CPU 시간: 215.218432 초
# 메모리 사용량: 1040672 KB
# generate_metric.02 args["version"]=3
# ********************
# working model_version = 3  2025-06-04 18:08:47.714024
# ********************
# start to train all models. 2025-06-04 18:08:47.714060
# 44's training. status=start 2025-06-04 18:08:47.714077
# 44's training. status=end 2025-06-04 18:10:19.076340
# completed to train all models. 2025-06-04 18:10:19.076443
# train to create model(3). 2025-06-04 18:10:22.076521
# CPU 시간: 322.862051 초
# 메모리 사용량: 1135584 KB
# generate_metric.02 args["version"]=4
# ********************
# working model_version = 4  2025-06-04 18:10:41.067903
# ********************
# start to train all models. 2025-06-04 18:10:41.067934
# 44's training. status=start 2025-06-04 18:10:41.067950
# 44's training. status=end 2025-06-04 18:12:13.230747
# completed to train all models. 2025-06-04 18:12:13.230849
# train to create model(4). 2025-06-04 18:12:16.230930
# CPU 시간: 430.099914 초
# 메모리 사용량: 1227440 KB
# generate_metric.02 args["version"]=5
# ********************
# working model_version = 5  2025-06-04 18:12:36.558908
# ********************
# start to train all models. 2025-06-04 18:12:36.558944
# 44's training. status=start 2025-06-04 18:12:36.558960
# 44's training. status=end 2025-06-04 18:14:04.182371
# completed to train all models. 2025-06-04 18:14:04.182472
# train to create model(5). 2025-06-04 18:14:07.182570
# CPU 시간: 534.991899 초
# 메모리 사용량: 1318944 KB
# generate_metric.02 args["version"]=6
# ********************
# working model_version = 6  2025-06-04 18:14:26.181500
# ********************
# start to train all models. 2025-06-04 18:14:26.181534
# 44's training. status=start 2025-06-04 18:14:26.181550
# 44's training. status=end 2025-06-04 18:15:58.774883
# completed to train all models. 2025-06-04 18:15:58.774980
# train to create model(6). 2025-06-04 18:16:01.775059
# CPU 시간: 641.520663 초
# 메모리 사용량: 1345136 KB
# generate_metric.02 args["version"]=7
# ********************
# working model_version = 7  2025-06-04 18:16:22.094503
# ********************
# start to train all models. 2025-06-04 18:16:22.094538
# 44's training. status=start 2025-06-04 18:16:22.094568
# 44's training. status=end 2025-06-04 18:17:53.625365
# completed to train all models. 2025-06-04 18:17:53.625460
# train to create model(7). 2025-06-04 18:17:56.625544
# CPU 시간: 748.338 초
# 메모리 사용량: 1506528 KB
# generate_metric.02 args["version"]=8
# ********************
# working model_version = 8  2025-06-04 18:18:16.941248
# ********************
# start to train all models. 2025-06-04 18:18:16.941282
# 44's training. status=start 2025-06-04 18:18:16.941298
# 44's training. status=end 2025-06-04 18:19:49.982356
# completed to train all models. 2025-06-04 18:19:49.982487
# train to create model(8). 2025-06-04 18:19:52.982578
# CPU 시간: 854.196137 초
# 메모리 사용량: 1598704 KB
# generate_metric.02 args["version"]=9
# ********************
# working model_version = 9  2025-06-04 18:20:12.333895
# ********************
# start to train all models. 2025-06-04 18:20:12.333929
# 44's training. status=start 2025-06-04 18:20:12.333945
# 44's training. status=end 2025-06-04 18:21:42.808893
# completed to train all models. 2025-06-04 18:21:42.808989
# train to create model(9). 2025-06-04 18:21:45.809075
# CPU 시간: 961.115786 초
# 메모리 사용량: 1762672 KB
# generate_metric.02 args["version"]=10
# ********************
# working model_version = 10  2025-06-04 18:22:07.674762
# ********************
# start to train all models. 2025-06-04 18:22:07.674796
# 44's training. status=start 2025-06-04 18:22:07.674812
# 44's training. status=end 2025-06-04 18:23:37.694949
# completed to train all models. 2025-06-04 18:23:37.695051
# train to create model(10). 2025-06-04 18:23:40.695134
# CPU 시간: 1067.248739 초
# 메모리 사용량: 1783888 KB
# generate_metric.02 args["version"]=11
# ********************
# working model_version = 11  2025-06-04 18:23:59.609119
# ********************
# start to train all models. 2025-06-04 18:23:59.609152
# 44's training. status=start 2025-06-04 18:23:59.609167
# 44's training. status=end 2025-06-04 18:25:28.897260
# completed to train all models. 2025-06-04 18:25:28.897361
# train to create model(11). 2025-06-04 18:25:31.897444
# CPU 시간: 1172.78462 초
# 메모리 사용량: 1952464 KB
# generate_metric.02 args["version"]=12
# ********************
# working model_version = 12  2025-06-04 18:25:50.829935
# ********************
# start to train all models. 2025-06-04 18:25:50.829969
# 44's training. status=start 2025-06-04 18:25:50.829985
# 44's training. status=end 2025-06-04 18:27:21.367338
# completed to train all models. 2025-06-04 18:27:21.367635
# train to create model(12). 2025-06-04 18:27:24.367723
# CPU 시간: 1280.641409 초
# 메모리 사용량: 1952464 KB

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_3_2',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 1~12
# CPU 시간: 1282.09783 초
# 메모리 사용량: 1952464 KB
# generate_metric.02 args["version"]=1
# ********************
# working model_version = 1  2025-06-04 18:27:44.806930
# ********************
# start to train all models. 2025-06-04 18:27:44.806952
# 44's training. status=start 2025-06-04 18:27:44.806962
# 44's training. status=end 2025-06-04 18:29:13.357047
# completed to train all models. 2025-06-04 18:29:13.357155
# train to create model(1). 2025-06-04 18:29:16.357244
# CPU 시간: 1387.944229 초
# 메모리 사용량: 1998432 KB
# generate_metric.02 args["version"]=2
# ********************
# working model_version = 2  2025-06-04 18:29:36.221851
# ********************
# start to train all models. 2025-06-04 18:29:36.221884
# 44's training. status=start 2025-06-04 18:29:36.221900
# 44's training. status=end 2025-06-04 18:31:06.603795
# completed to train all models. 2025-06-04 18:31:06.603897
# train to create model(2). 2025-06-04 18:31:09.603983
# CPU 시간: 1493.268859 초
# 메모리 사용량: 2165936 KB
# generate_metric.02 args["version"]=3
# ********************
# working model_version = 3  2025-06-04 18:31:28.677246
# ********************
# start to train all models. 2025-06-04 18:31:28.677280
# 44's training. status=start 2025-06-04 18:31:28.677296
# 44's training. status=end 2025-06-04 18:33:02.958051
# completed to train all models. 2025-06-04 18:33:02.958153
# train to create model(3). 2025-06-04 18:33:05.958230
# CPU 시간: 1601.395457 초
# 메모리 사용량: 2199088 KB
# generate_metric.02 args["version"]=4
# ********************
# working model_version = 4  2025-06-04 18:33:25.865116
# ********************
# start to train all models. 2025-06-04 18:33:25.865151
# 44's training. status=start 2025-06-04 18:33:25.865168
# 44's training. status=end 2025-06-04 18:35:58.958559
# completed to train all models. 2025-06-04 18:35:58.958684
# train to create model(4). 2025-06-04 18:36:01.958774
# CPU 시간: 1707.449619 초
# 메모리 사용량: 2349696 KB
# generate_metric.02 args["version"]=5
# ********************
# working model_version = 5  2025-06-04 18:36:22.027286
# ********************
# start to train all models. 2025-06-04 18:36:22.027321
# 44's training. status=start 2025-06-04 18:36:22.027337
# 44's training. status=end 2025-06-04 18:37:54.933207
# completed to train all models. 2025-06-04 18:37:54.933312
# train to create model(5). 2025-06-04 18:37:57.933392
# CPU 시간: 1813.67055 초
# 메모리 사용량: 2515040 KB
# generate_metric.02 args["version"]=6
# ********************
# working model_version = 6  2025-06-04 18:38:16.991740
# ********************
# start to train all models. 2025-06-04 18:38:16.991775
# 44's training. status=start 2025-06-04 18:38:16.991792
# 44's training. status=end 2025-06-04 18:39:52.110462
# completed to train all models. 2025-06-04 18:39:52.110581
# train to create model(6). 2025-06-04 18:39:55.110668
# CPU 시간: 1925.026906 초
# 메모리 사용량: 2670544 KB
# generate_metric.02 args["version"]=7
# ********************
# working model_version = 7  2025-06-04 18:40:14.507176
# ********************
# start to train all models. 2025-06-04 18:40:14.507208
# 44's training. status=start 2025-06-04 18:40:14.507224
# 44's training. status=end 2025-06-04 18:41:44.792828
# completed to train all models. 2025-06-04 18:41:44.792933
# train to create model(7). 2025-06-04 18:41:47.793019
# CPU 시간: 2031.431254 초
# 메모리 사용량: 2670544 KB
# generate_metric.02 args["version"]=8
# ********************
# working model_version = 8  2025-06-04 18:42:06.866600
# ********************
# start to train all models. 2025-06-04 18:42:06.866635
# 44's training. status=start 2025-06-04 18:42:06.866651
# 44's training. status=end 2025-06-04 18:43:39.435116
# completed to train all models. 2025-06-04 18:43:39.435406
# train to create model(8). 2025-06-04 18:43:42.435492
# CPU 시간: 2137.93176 초
# 메모리 사용량: 2785504 KB
# generate_metric.02 args["version"]=9
# ********************
# working model_version = 9  2025-06-04 18:44:01.475293
# ********************
# start to train all models. 2025-06-04 18:44:01.475328
# 44's training. status=start 2025-06-04 18:44:01.475344
# 44's training. status=end 2025-06-04 18:45:33.924663
# completed to train all models. 2025-06-04 18:45:33.924767
# train to create model(9). 2025-06-04 18:45:36.924853
# CPU 시간: 2244.582312 초
# 메모리 사용량: 2939136 KB
# generate_metric.02 args["version"]=10
# ********************
# working model_version = 10  2025-06-04 18:45:56.047071
# ********************
# start to train all models. 2025-06-04 18:45:56.047107
# 44's training. status=start 2025-06-04 18:45:56.047123
# 44's training. status=end 2025-06-04 18:47:33.312896
# completed to train all models. 2025-06-04 18:47:33.312993
# train to create model(10). 2025-06-04 18:47:36.313077
# CPU 시간: 2355.280164 초
# 메모리 사용량: 2957040 KB
# generate_metric.02 args["version"]=11
# ********************
# working model_version = 11  2025-06-04 18:47:55.449503
# ********************
# start to train all models. 2025-06-04 18:47:55.449539
# 44's training. status=start 2025-06-04 18:47:55.449555
# 44's training. status=end 2025-06-04 18:49:26.766958
# completed to train all models. 2025-06-04 18:49:26.767065
# train to create model(11). 2025-06-04 18:49:29.767146
# CPU 시간: 2461.90656 초
# 메모리 사용량: 2979280 KB
# generate_metric.02 args["version"]=12
# ********************
# working model_version = 12  2025-06-04 18:49:49.255806
# ********************
# start to train all models. 2025-06-04 18:49:49.255840
# 44's training. status=start 2025-06-04 18:49:49.255855
# 44's training. status=end 2025-06-04 18:51:23.087931
# completed to train all models. 2025-06-04 18:51:23.088027
# train to create model(12). 2025-06-04 18:51:26.088105
# CPU 시간: 2568.948328 초
# 메모리 사용량: 3132864 KB

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_3_3',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_3_4',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_3_5',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_3_6',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_3_7',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_3_8',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_5_3_9',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args_01)

# %%
## end
