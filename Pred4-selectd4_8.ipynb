# %% [markdown]
# # Prediction with LSTM model (v.4.4.8)
# <p style='text-align: right;'>with selectd4.csv</p>
#
# * history
#   * 2025/05/23 PM06:02 : 3번째 모델의 3번째 데이터를 사용
#   * 2025/05/27

# %%
# !pip install scikit-learn
# !pip install tensorflow
from datetime import datetime
print(f'restart kernel... {datetime.now()}')

# %%
def restart_kernel():
    # Restart the kernet after libraries are loaded.
    import IPython
    from datetime import datetime
    print(f'restart kernel... {datetime.now()}')
    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

restart_kernel()
# Out:
# restart kernel... 2025-05-30 16:59:51.375960

# %%
# load dependacies
import os
import time
import resource
from datetime import datetime
from lib.globalvar import *
from lib.data_loader import DataLoader
from lib.small_predict import predict_small, print_predict_small
from lib.activation import ActivationOutput, RecurrentActivation
from lib.small_predict import build_and_predict, gen_multi_model, save_model, generate_metric
from lib.common_env_sets import lstm_units, dense_units, steps, metrics, dropout
from lib.common_env_sets import learning_rate, last_lstm_return_sequences
from lib.common_env_sets import loss, output_dense_activation, epochs, rand_seed


print(f"imported library. ({datetime.now()})")
# Out:
# imported library. (2025-05-30 17:00:15.925667)

# %%
##
## 모델링 환경 설정
##
window=1 # default = 1 , help = "time stamps"
data_dir='./csv/selectd4.csv'
    
mode='predict' # help = "back-test or predict")

mode2='sampling' # help = "greed or sampling")
verb='verbose' # help = "verbose or not_verb")
    
training_length=0.95 # default = 0.9)
from_pos = 0
last = [[1, 5, 18, 20, 30, 35],
        [7, 9, 24, 40, 42, 44],
        [3, 6, 7, 11, 12, 17],
        [3, 13, 28, 34, 38, 42],
        [5, 12, 24, 29, 32, 42]]
print(f"finished to set environemnt. ({datetime.now()})")
# Out:
# finished to set environemnt. (2025-05-30 17:00:16.687114)

# %%
dataset_dicts = {
    1: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=0,
                  verbose=False
                  ),
    2: DataLoader(data_dir=data_dir,
                  training_length=training_length,
                  window_prev=window,
                  mode=mode,
                  from_pos=300,
                  verbose=False
                  )
    }

print(f'completed to load data. {datetime.now()}')
# Out:
# completed to load data. 2025-05-30 17:00:19.532140

# %%
###########
## layers
## LSTM Neural 계층 선언
###########
datasets = [dataset_dicts[1], # 0
            dataset_dicts[2], # 1
           ]

lstm_args = {14: {"model":{"learning_rate": learning_rate[0],
                           "dropout": dropout[0],
                           "steps": steps[0], # last output elements count
                           "metrics": metrics[1],
                           "last_lstm_return_sequences": last_lstm_return_sequences[0],
                           "lstm_units": lstm_units[2],
                           "dense_units": dense_units[2],
                           "output_dense_activation": output_dense_activation[3],
                           "loss": loss[0],
                           "return_state": False,
                           "rand_seed": rand_seed[0] # rand_seed[0]
                           },
                 "train": {"epochs": epochs[2],
                           "is_shuffle": False,
                           "batch": 1,
                           "steps_per_epoch": 0 #100
                           },
                 "dataset": datasets[0]
                 },
             44: {"model":{"learning_rate": learning_rate[0],
                           "dropout": dropout[0],
                           "steps": steps[0], # last output elements count
                           "metrics": metrics[0],
                           "last_lstm_return_sequences": last_lstm_return_sequences[1],
                           "lstm_units": lstm_units[2],
                           "dense_units": dense_units[2],
                           "output_dense_activation": output_dense_activation[3],
                           "loss": loss[0],
                           "return_state": False,
                           "rand_seed": rand_seed[0] # rand_seed[0]
                           },
                 "train": {"epochs": epochs[3],
                           "is_shuffle": False,
                           "batch": 1,
                           "steps_per_epoch": 0 #100
                           },
                 "dataset": datasets[0]
                 },
             }


print(f'completed to set env for all models. {datetime.now()}')
# Out:
# completed to set env for all models. 2025-05-30 17:00:20.709280

# %%
#
# max_model_limit 정보만큼 반복적으로 매트릭을 생성합니다.
#
model_version_from = 1
model_version_end = 12
args = {'test_id': 'P4_4_8_6',
        'version': model_version_from,
        'write_to_db': True,
        'last': last,
        'mode2': mode2,
        'gen_num': 5,
        'round_limit': 40,
        'db_file_name': "./db/metrics.db"
        }
generate_metric(args=args,
                from_version=model_version_from,
                to_version=model_version_end,
                lstm_args=lstm_args)
# Out:
# Test Start: 1~12
# CPU 시간: 4.156458 초
# 메모리 사용량: 614592 KB
# generate_metric.02 args["version"]=1
# ********************
# working model_version = 1  2025-05-30 17:00:22.981393
# ********************
# start to train all models. 2025-05-30 17:00:22.981422
# 14's training. status=start 2025-05-30 17:00:22.981438
# 14's training. status=end 2025-05-30 17:01:10.906876
# 44's training. status=start 2025-05-30 17:01:10.906974
# 44's training. status=end 2025-05-30 17:02:41.373679
# completed to train all models. 2025-05-30 17:02:41.373779
# train to create model(1). 2025-05-30 17:02:44.373867
# CPU 시간: 171.26306399999999 초
# 메모리 사용량: 1036592 KB
# generate_metric.02 args["version"]=2
# ********************
# working model_version = 2  2025-05-30 17:03:12.243665
# ********************
# start to train all models. 2025-05-30 17:03:12.243699
# 14's training. status=start 2025-05-30 17:03:12.243716
# 14's training. status=end 2025-05-30 17:04:01.648690
# 44's training. status=start 2025-05-30 17:04:01.648787
# 44's training. status=end 2025-05-30 17:05:34.643931
# completed to train all models. 2025-05-30 17:05:34.644029
# train to create model(2). 2025-05-30 17:05:37.644109
# CPU 시간: 338.560723 초
# 메모리 사용량: 1218688 KB
# generate_metric.02 args["version"]=3
# ********************
# working model_version = 3  2025-05-30 17:06:05.368125
# ********************
# start to train all models. 2025-05-30 17:06:05.368162
# 14's training. status=start 2025-05-30 17:06:05.368181
# 14's training. status=end 2025-05-30 17:06:56.992828
# 44's training. status=start 2025-05-30 17:06:56.992921
# 44's training. status=end 2025-05-30 17:08:26.619779
# completed to train all models. 2025-05-30 17:08:26.619877
# train to create model(3). 2025-05-30 17:08:29.619960
# CPU 시간: 506.700733 초
# 메모리 사용량: 1404016 KB
# generate_metric.02 args["version"]=4
# ********************
# working model_version = 4  2025-05-30 17:08:58.444455
# ********************
# start to train all models. 2025-05-30 17:08:58.444481
# 14's training. status=start 2025-05-30 17:08:58.444491
# 14's training. status=end 2025-05-30 17:09:48.021014
# 44's training. status=start 2025-05-30 17:09:48.021113
# 44's training. status=end 2025-05-30 17:11:18.441653
# completed to train all models. 2025-05-30 17:11:18.441744
# train to create model(4). 2025-05-30 17:11:21.441829
# CPU 시간: 674.810527 초
# 메모리 사용량: 1591376 KB
# generate_metric.02 args["version"]=5
# ********************
# working model_version = 5  2025-05-30 17:11:48.978467
# ********************
# start to train all models. 2025-05-30 17:11:48.978494
# 14's training. status=start 2025-05-30 17:11:48.978504
# 14's training. status=end 2025-05-30 17:12:37.951693
# 44's training. status=start 2025-05-30 17:12:37.951784
# 44's training. status=end 2025-05-30 17:14:12.161792
# completed to train all models. 2025-05-30 17:14:12.161916
# train to create model(5). 2025-05-30 17:14:15.162020
# CPU 시간: 844.55834 초
# 메모리 사용량: 1775456 KB
# generate_metric.02 args["version"]=6
# ********************
# working model_version = 6  2025-05-30 17:14:43.333194
# ********************
# start to train all models. 2025-05-30 17:14:43.333230
# 14's training. status=start 2025-05-30 17:14:43.333246
# 14's training. status=end 2025-05-30 17:15:33.221183
# 44's training. status=start 2025-05-30 17:15:33.221287
# 44's training. status=end 2025-05-30 17:17:07.025919
# completed to train all models. 2025-05-30 17:17:07.026044
# train to create model(6). 2025-05-30 17:17:10.026127
# CPU 시간: 1013.014102 초
# 메모리 사용량: 1963264 KB
# generate_metric.02 args["version"]=7
# ********************
# working model_version = 7  2025-05-30 17:17:38.191308
# ********************
# start to train all models. 2025-05-30 17:17:38.191343
# 14's training. status=start 2025-05-30 17:17:38.191359
# 14's training. status=end 2025-05-30 17:18:27.924844
# 44's training. status=start 2025-05-30 17:18:27.924944
# 44's training. status=end 2025-05-30 17:19:57.907818
# completed to train all models. 2025-05-30 17:19:57.907913
# train to create model(7). 2025-05-30 17:20:00.907991
# CPU 시간: 1181.667041 초
# 메모리 사용량: 2289328 KB
# generate_metric.02 args["version"]=8
# ********************
# working model_version = 8  2025-05-30 17:20:30.743522
# ********************
# start to train all models. 2025-05-30 17:20:30.743559
# 14's training. status=start 2025-05-30 17:20:30.743575
# 14's training. status=end 2025-05-30 17:21:21.963747
# 44's training. status=start 2025-05-30 17:21:21.964034
# 44's training. status=end 2025-05-30 17:22:52.553936
# completed to train all models. 2025-05-30 17:22:52.554030
# train to create model(8). 2025-05-30 17:22:55.554109
# CPU 시간: 1349.088491 초
# 메모리 사용량: 2478576 KB
# generate_metric.02 args["version"]=9
# ********************
# working model_version = 9  2025-05-30 17:23:23.103246
# ********************
# start to train all models. 2025-05-30 17:23:23.103271
# 14's training. status=start 2025-05-30 17:23:23.103282
# 14's training. status=end 2025-05-30 17:24:11.814746
# 44's training. status=start 2025-05-30 17:24:11.814849
# 44's training. status=end 2025-05-30 17:25:47.430772
# completed to train all models. 2025-05-30 17:25:47.430871
# train to create model(9). 2025-05-30 17:25:50.430952
# CPU 시간: 1519.531153 초
# 메모리 사용량: 2638496 KB
# generate_metric.02 args["version"]=10
# ********************
# working model_version = 10  2025-05-30 17:26:18.971950
# ********************
# start to train all models. 2025-05-30 17:26:18.971975
# 14's training. status=start 2025-05-30 17:26:18.971985
# 14's training. status=end 2025-05-30 17:27:09.042205
# 44's training. status=start 2025-05-30 17:27:09.042303
# 44's training. status=end 2025-05-30 17:28:41.240682
# completed to train all models. 2025-05-30 17:28:41.240774
# train to create model(10). 2025-05-30 17:28:44.240851
# CPU 시간: 1688.158162 초
# 메모리 사용량: 2855312 KB
# generate_metric.02 args["version"]=11
# ********************
# working model_version = 11  2025-05-30 17:29:11.781268
# ********************
# start to train all models. 2025-05-30 17:29:11.781302
# 14's training. status=start 2025-05-30 17:29:11.781318
# 14's training. status=end 2025-05-30 17:30:04.861606
# 44's training. status=start 2025-05-30 17:30:04.861700
# 44's training. status=end 2025-05-30 17:31:37.062704
# completed to train all models. 2025-05-30 17:31:37.062816
# train to create model(11). 2025-05-30 17:31:40.062904
# CPU 시간: 1859.719855 초
# 메모리 사용량: 2899392 KB
# generate_metric.02 args["version"]=12
# ********************
# working model_version = 12  2025-05-30 17:32:09.639453
# ********************
# start to train all models. 2025-05-30 17:32:09.639488
# 14's training. status=start 2025-05-30 17:32:09.639504
# 14's training. status=end 2025-05-30 17:32:59.681628
# 44's training. status=start 2025-05-30 17:32:59.681720
# 44's training. status=end 2025-05-30 17:34:30.687808
# completed to train all models. 2025-05-30 17:34:30.687904
# train to create model(12). 2025-05-30 17:34:33.687980
# CPU 시간: 2028.134532 초
# 메모리 사용량: 3223264 KB

# %%
## end
