# %% [markdown]
# ```
# previous model_version=3
# open model version file 2025-05-26 16:25:18.948401
# start to train all models. 2025-05-26 16:25:18.948490
# 1's training. status=start 2025-05-26 16:25:18.948689
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# lstm unit : 3, (45, 'sigmoid')
# lstm unit : 4, (45, 'elu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential, built=True>
# num_epoch=50/<class 'int'>
# 1's training. status=end 2025-05-26 16:26:15.629444
# 2's training. status=start 2025-05-26 16:26:15.629542
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_1, built=True>
# num_epoch=20/<class 'int'>
# 2's training. status=end 2025-05-26 16:26:34.824341
# 3's training. status=start 2025-05-26 16:26:34.824441
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# loss = binary_crossentropy
# verbose=0
# model=<Sequential name=sequential_2, built=True>
# num_epoch=50/<class 'int'>
# 3's training. status=end 2025-05-26 16:27:20.069959
# 4's training. status=start 2025-05-26 16:27:20.070059
# lstm unit : 1, (45, 'selu')
# lstm unit : 2, (45, 'selu')
# lstm unit : 3, (45, 'selu')
# lstm unit : 4, (45, 'selu')
# lstm unit : 5, (45, 'selu')
# lstm unit : 6, (45, 'selu')
# lstm unit : 7, (45, 'selu')
# lstm unit : 8, (45, 'sigmoid')
# lstm unit : 9, (45, 'sigmoid')
# lstm unit : 10, (45, 'elu')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_3, built=True>
# num_epoch=50/<class 'int'>
# 4's training. status=end 2025-05-26 16:28:01.162411
# 5's training. status=start 2025-05-26 16:28:01.162506
# lstm unit : 1, (45, 'tanh')
# lstm unit : 2, (45, 'tanh')
# lstm unit : 3, (45, 'tanh')
# lstm unit : 4, (45, 'tanh')
# lstm unit : 5, (45, 'tanh')
# lstm unit : 6, (45, 'tanh')
# lstm unit : 7, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_4, built=True>
# num_epoch=50/<class 'int'>
# 5's training. status=end 2025-05-26 16:28:34.001726
# 6's training. status=start 2025-05-26 16:28:34.001844
# lstm unit : 1, (45, 'tanh')
# loss = mse
# verbose=0
# model=<Sequential name=sequential_5, built=True>
# num_epoch=50/<class 'int'>
# 6's training. status=end 2025-05-26 16:28:51.833469
# completed to train all models. 2025-05-26 16:28:51.833894
# check to create model(4). 2025-05-26 16:28:51.834288
# ```

# %% [markdown]
# ```
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# predicted time : round=0 date=2025-05-26 16:29:22.784590
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# predicted time : round=1 date=2025-05-26 16:29:23.484697
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# predicted time : round=2 date=2025-05-26 16:29:24.193492
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# predicted time : round=3 date=2025-05-26 16:29:24.898420
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# predicted time : round
# 57066|15|24|4|6|2025-05-26 18:24:47.098663|30,20,23,1,24,28|1,20,30|3
# 57071|15|24|4|11|2025-05-26 18:24:47.098663|41,20,40,5,43,1|1,5,20|3
# 57077|15|24|4|17|2025-05-26 18:24:47.098663|1,10,35,7,4,18|1,18,35|3
# 61985|16|24|4|5|2025-05-26 18:29:40.489229|15,12,18,26,5,20|5,18,20|3
# sqlite>
# ```

# %% [markdown]
# ```
# sqlite> select * from metrics where round=34 and model_id=1 and matched_size>=3;
# 13939|6|34|1|19|2025-05-26 16:48:05.486475|2,5,20,35,44,45|5,20,35|3
# 18855|7|34|1|15|2025-05-26 17:22:10.168624|1,18,20,28,33,44|1,18,20|3
# 23775|8|34|1|15|2025-05-26 17:29:42.032618|1,2,5,16,18,32|1,5,18|3
# 23778|8|34|1|18|2025-05-26 17:29:42.032618|41,45,43,5,30,18|5,18,30|3
# 28684|9|34|1|4|2025-05-26 17:36:57.452948|8,18,30,16,43,1|1,18,30|3
# 33614|10|34|1|14|2025-05-26 17:43:07.751751|30,7,18,20,40,1|1,18,20,30|4
# 43451|12|34|1|11|2025-05-26 17:55:48.749533|12,29,18,35,32,20|18,20,35|3
# 48366|13|34|1|6|2025-05-26 18:15:04.516456|27,30,42,19,35,18|18,30,35|3
# 48367|13|34|1|7|2025-05-26 18:15:04.516456|1,18,20,26,39,40|1,18,20|3
# 53289|14|34|1|9|2025-05-26 18:19:40.531900|35,5,20,17,38,30|5,20,30,35|4
# 63127|16|34|1|7|2025-05-26 18:29:47.655957|5,14,18,20,29,45|5,18,20|3
# sqlite>
# ```

# %%
```
P4_6_1_4|1|118|4|1|2025-06-05 18:04:24.012138|3,5,7,19,21,32||0 , 87
P4_6_1_4|1|489|4|1|2025-06-05 18:05:22.978392|22,23,28,30,34,36|36|1, 173
P4_6_1_4|1|919|4|1|2025-06-05 18:06:29.230481|11,17,19,29,40,41|11,17|2, 157
P4_6_1_4|1|999|4|1|2025-06-05 18:06:42.339549|1,4,12,15,19,43||0, 94
P4_6_1_6|1|602|6|1|2025-06-06 02:04:49.460566|3,5,30,31,39,43|39|1, 151
```

[3, 5, 7, 19, 21, 32] 87
[22, 23, 28, 30, 34, 36] 173
[11, 17, 19, 29, 40, 41] 157
[1, 4, 12, 15, 19, 43] 94
[3, 5, 30, 31, 39, 43] 151
[[3,5,7,19,21,32],
[22,23,28,30,34,36],
[11,17,19,29,40,41],
[1,4,12,15,19,43],
]3,5,30,31,39,43]]

# %%
from datetime import datetime
sel_date = datetime(2025, 6, 21, 20, 35)
print(sel_date)
rands_seed = (sel_date.timestamp() / 10000000)
print(sel_date.timestamp())
print(rands_seed)
# Out:
# 2025-06-21 20:35:00
# 1750505700.0
# 175.05057
